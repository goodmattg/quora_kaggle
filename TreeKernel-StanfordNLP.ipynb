# %%
import pandas as pd
import numpy as np
from pycorenlp import StanfordCoreNLP 
from collections import defaultdict
import re, time, bisect, math
import itertools as it

# %%
nlp = StanfordCoreNLP('http://localhost:9000')

# %%
def _getNLPToks_(rawSentence):
    output = nlp.annotate(rawSentence, properties={
      'annotators': 'tokenize,ssplit,pos,parse',
      'outputFormat': 'json'
      })
    return output['sentences'][0]['parse'].split("\n")

# %%
def tree(): return defaultdict(tree) # example of autovivification

# %% [markdown]
# ## Parse StanfordNLP output to Generate Tree

# %%
def _leadingSpaces_(target):
    return len(target) - len(target.lstrip())

def _findParent_(curIndent, parid, treeRef):
    tmpid = parid
    while (curIndent <= treeRef[tmpid]['indent']):
        tmpid = treeRef[tmpid]['parid']
    return tmpid

# %%
def _generateTree_(rawTokens, treeRef):
    
    # ----------------------------- CLEARED ---------------------------------# 
    
    # (token
    REGEX_OPEN = r"^\s*\(([a-zA-Z0-9_']*)\s*$"
    
    # (token (tok1 tok2) (tok3 tok4) .... (tokx toky))
    REGEX_COMP = r"^\s*\(([a-zA-Z0-9_']+)\s*((?:[(]([a-zA-Z0-9_;.,?'!]+)\s*([a-zA-Z0-9_;\.,?!']+)[)]\s*)+)"
    
    # (, ,) as stand-alone. Used for match() not search()
    REGEX_PUNC = r"^\s*\([,!?.'\"]\s*[,!?.'\"]\)"

    # (tok1 tok2) as stand-alone
    REGEX_SOLO_PAIR = r"^\s*\(([a-zA-Z0-9_']+)\s*([a-zA-Z0-9_']+)\)"
        
    # (tok1 tok2) used in search()
    REGEX_ISOL_IN_COMP = r"\(([a-zA-Z0-9_;.,?!']+)\s*([a-zA-Z0-9_;.,?!']+)\)"
    # (punc punc) used in search()
    REGEX_PUNC_SOLO = r"\([,!?.'\"]\s*[,!?.'\"]\)"

    
    # manually insert Root token 
    treeRef[len(treeRef)] = {'curid':0, 
                             'parid':-1, 
                             'posOrTok':'ROOT', 
                             'indent':0,
                            'children':[],
                            'childrenTok':[]}
    ID_CTR = 1
    
    for tok in rawTokens[1:]:
        
        curIndent = _leadingSpaces_(tok) # the current indent level
        parid = _findParent_(curIndent, ID_CTR-1, treeRef) # determine parid
        
        # CHECK FOR COMPOSITE TOKENS
        checkChild = re.match(REGEX_COMP, tok)
        if (checkChild):
            treeRef[ID_CTR] = {'curid':ID_CTR, 
                               'parid':parid, 
                               'posOrTok':checkChild.group(1), 
                               'indent':curIndent,
                              'children':[],
                              'childrenTok':[]}
            upCTR = ID_CTR
            ID_CTR += 1
            # Eliminate further punctuation

            subCheck = re.sub(REGEX_PUNC_SOLO,'',checkChild.group(2))
            subs = re.findall(REGEX_ISOL_IN_COMP, subCheck) 
            for ch in subs:
                # THE INDENTING IS WRONG HERE - THE HEIRARCHY IS MESSED UP - check test output
                treeRef[ID_CTR] = {'curid':ID_CTR, 
                                   'parid':upCTR, 
                                   'posOrTok':ch[0], 
                                   'indent':curIndent+2,
                                  'children':[],
                                  'childrenTok':[]}
                ID_CTR += 1
                treeRef[ID_CTR] = {'curid':ID_CTR, 
                                   'parid':ID_CTR-1, 
                                   'posOrTok':ch[1], 
                                   'indent':curIndent+2,
                                  'children':[],
                                  'childrenTok':[]}
                ID_CTR += 1
            continue
           

            
        checkSingle = re.match(REGEX_SOLO_PAIR, tok)
        if (checkSingle):
            treeRef[ID_CTR] = {'curid':ID_CTR, 
                               'parid':parid, 
                               'posOrTok':checkSingle.group(1), 
                               'indent':curIndent+2,
                              'children':[],
                              'childrenTok':[]}
            ID_CTR += 1
            treeRef[ID_CTR] = {'curid':ID_CTR, 
                               'parid':ID_CTR-1, 
                               'posOrTok':checkSingle.group(2), 
                               'indent':curIndent+2,
                              'children':[],
                              'childrenTok':[]}
            ID_CTR += 1
            continue
        
        
        checkPunc = re.match(REGEX_PUNC, tok)
        if (checkPunc): # ignore punctuation
            continue

        checkMatch = re.match(REGEX_OPEN, tok)
        if (checkMatch):
            treeRef[ID_CTR] = {'curid':ID_CTR, 
                               'parid':parid, 
                               'posOrTok':checkMatch.group(1), 
                               'indent':curIndent,
                              'children':[],
                              'childrenTok':[]}
            ID_CTR += 1
            continue

    return

# %%
'''
_generateTree_() method only provides tree (dict representation) listing parents. 
This is a naive method to add a "children" field to the tree - necessary for optimal Tree Kernel methods.
'''

# Switching to 2-pass O(N)
def _flipTree_(treeRef):
    # Pass 1 fill in children
    for k,v in treeRef.items():
        if (k > 0):
            bisect.insort(treeRef[v['parid']]['children'], k)
    # Pass 2 map children to tokens
    for k,v in treeRef.items():
        if (k > 0):
            treeRef[k]['childrenTok'] = [treeRef[ch]['posOrTok'] for ch in treeRef[k]['children']]
    treeRef[0]['childrenTok'] = treeRef[1]['posOrTok']

# %% [markdown]
# ## Tree Kernel Helper Functions

# %%
def _isLeaf_(tree, parentNode):
    return (len(tree[parentNode]['children']) == 0)

def _isPreterminal_(tree, parentNode):
    for idx in tree[parentNode]['children']:
        if not _isLeaf_(tree, idx):
            return False
    return True

# %% [markdown]
# ## Implementation of the Collins-Duffy Kernel

# %%
'''
Implementation of the Colins-Duffy or Subset-Tree (SST) Kernel
'''

def _cdHelper_(tree1, tree2, node1, node2, store, lam):    
    # No duplicate computations
    if store[node1, node2] >= 0:
        return
    
    # Leaves yield similarity score by definition
    if (_isLeaf_(tree1, node1) or _isLeaf_(tree2, node2)):
        store[node1, node2] = 0
        return
    
    # same parent node
    if tree1[node1]['posOrTok'] == tree2[node2]['posOrTok']: 
        # same children tokens
        if tree1[node1]['childrenTok'] == tree2[node2]['childrenTok']:
            # Check if both nodes are pre-terminal
            if _isPreterminal_(tree1, node1) and _isPreterminal_(tree2, node2):
                store[node1, node2] = lam
                return
            # Not pre-terminal. Recurse among the children of both token trees. 
            else:              
                nChildren = len(tree1[node1]['children'])
                runningTotal = 0
                for idx in range(nChildren):
                     # index ->  node_id
                    tmp_n1 = tree1[node1]['children'][idx]
                    tmp_n2 = tree2[node2]['children'][idx]
                    # Recursively run helper
                    _cdHelper_(tree1, tree2, tmp_n1, tmp_n2, store, lam) 
                    runningTotal += (1 + store[tmp_n1, tmp_n2])
                    
                store[node1, node2] = lam * runningTotal
                return
        else:
            store[node1, node2] = 0
    else: # parent nodes are different 
        store[node1, node2] = 0
        return 

def _cdKernel_(tree1, tree2, lam):
    # Fill the initial state of the store 
    store = np.empty((len(tree1), len(tree2)))
    store.fill(-1)
    
    # O(N^2) to compute the tree dot product
    for i in range(len(tree1)):
        for j in range(len(tree2)):
            _cdHelper_(tree1, tree2, i, j, store, lam)
            
    return store.sum()
            
'''
Returns a tuple w/ format: (raw, normalized)
If NORMALIZE_FLAG set to False, tuple[1] = -1
'''    
def _CollinsDuffy_(tree1, tree2, lam, NORMALIZE_FLAG):
    raw_score = _cdKernel_(tree1, tree2, lam)
    if (NORMALIZE_FLAG):
        t1_score = _cdKernel_(tree1, tree1, lam)
        t2_score = _cdKernel_(tree2, tree2, lam)
        return (raw_score,(raw_score / math.sqrt(t1_score * t2_score)))
    else:
        return (raw_score,-1)

# %% [markdown]
# ## Implementation of the PT Kernel (Moschitti '06)

# %%
'''
Implementation of the Partial Tree (PT) Kernel from:
"Efficient Convolution Kernels for Dependency and Constituent Syntactic Trees"
by Alessandro Moschitti
'''

'''
The delta function is stolen from the Collins-Duffy kernel
''' 
    
def _deltaP_(tree1, tree2, seq1, seq2, store, lam, mu, p):
                
#     # Enumerate subsequences of length p+1 for each child set
#     leftSeqs = list(it.combinations(tree1[node1]['children'], seqLen))
#     rightSeqs = list(it.combinations(tree2[node2]['children'], seqLen))
    if p == 0:
        return 0

    # generate delta(a,b)
    _delta_(tree1, tree2, seq1[-1], seq2[-1], store, lam, mu)
    
    if store[seq1[-1], seq2[-1]] == 0:
        return 0
    else:
        runningTot = 0
        for i in range(p-1, len(seq1)-1):
            for r in range(p-1, len(seq2)-1):
                scaleFactor = pow(lam, len(seq1[:-1])-i+len(seq2[:-1])-r)
                dp = _deltaP_(tree1, tree2, seq1[:i], seq2[:r], store, lam, mu, p-1)
                runningTot += (scaleFactor * dp)
                
        return runningTot
                
def _delta_(tree1, tree2, node1, node2, store, lam, mu):    
#     print("Evaluating Delta: (%d,%d)" % (node1, node2))
    
    # No duplicate computations
    if store[node1, node2] >= 0:
        return
    
    # Leaves yield similarity score by definition
    if (_isLeaf_(tree1, node1) or _isLeaf_(tree2, node2)):
        store[node1, node2] = 0
        return
    
    # same parent node
    if tree1[node1]['posOrTok'] == tree2[node2]['posOrTok']: 
        # establishes p_max
        childmin = min(len(tree1[node1]['children']), len(tree2[node2]['children']))
        deltaTot = 0
        for p in range(1,childmin+1):
            # compute delta_p
            deltaTot += _deltaP_(tree1, tree2,
                                 tree1[node1]['children'], 
                                 tree2[node2]['children'], store, lam, mu, p) 
        
        store[node1, node2] = mu * (pow(lam,2) + deltaTot)
        return

    else: 
        # parent nodes are different 
        store[node1, node2] = 0
        return 

def _ptKernel_(tree1, tree2, lam, mu):
    # Fill the initial state of the store 
    store = np.empty((len(tree1), len(tree2)))
    store.fill(-1)
    
    # O(N^2) to compute the tree dot product
    for i in range(len(tree1)):
        for j in range(len(tree2)):
            _delta_(tree1, tree2, i, j, store, lam, mu)
            
    return store.sum()
             
'''
Returns a tuple w/ format: (raw, normalized)
If NORMALIZE_FLAG set to False, tuple[1] = -1
'''    
def _MoschittiPT_(tree1, tree2, lam, mu, NORMALIZE_FLAG):
    raw_score = _ptKernel_(tree1, tree2, lam, mu)
    if (NORMALIZE_FLAG):
        t1_score = _ptKernel_(tree1, tree1, lam, mu)
        t2_score = _ptKernel_(tree2, tree2, lam, mu)
        return (raw_score,(raw_score / math.sqrt(t1_score * t2_score)))
    else:
        return (raw_score,-1)

# %% [markdown]
# ## Test: Tree Generation and Collins-Duffy Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tree()
tree_b2 = tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
_generateTree_(toks_b1, tree_b1)
_generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
_flipTree_(tree_b1)
_flipTree_(tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = _CollinsDuffy_(tree_b1, tree_b2, 0.8, 1)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel

print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# --- 0.04027605056762695 seconds ---
# --- 0.04057908058166504 seconds ---
# --- 0.04071807861328125 seconds ---
# --- 0.042855024337768555 seconds ---
# Raw Score: 1.6
# Norm Score: 0.0290974838407

# %% [markdown]
# ## Test: Tree Generation and Moschitti PT Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tree()
tree_b2 = tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
_generateTree_(toks_b1, tree_b1)
_generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
_flipTree_(tree_b1)
_flipTree_(tree_b2)

# for i in tree_b1.items():
#     print(i)
    
# for i in tree_b2.items():
#     print(i)

print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = _MoschittiPT_(tree_b1, tree_b2, 0.8, 0.4, 1)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel

print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# --- 0.039852142333984375 seconds ---
# --- 0.04013514518737793 seconds ---
# --- 0.040258169174194336 seconds ---
# --- 0.04257512092590332 seconds ---
# Raw Score: 4.096
# Norm Score: 0.675520529473

# %% [markdown]
# ## Test: Tree Kernels on Training Data

# %%
from random import randint

def read_data(path_to_file):
    df = pd.read_csv(path_to_file)
    print ("Shape of base training File = ", df.shape)
    # Remove missing values and duplicates from training data
    df.drop_duplicates(inplace=True)
    df.dropna(inplace=True)
    print("Shape of base training data after cleaning = ", df.shape)
    return df

df_train = read_data("input/train.csv")
# Out:
# Shape of base training File =  (404290, 6)
# Shape of base training data after cleaning =  (404288, 6)

# %%
## SET UP TEST INDICES TO SELECT RANDOM ROWS

TEST_SAMPLES = 100
indices = np.arange(TEST_SAMPLES)
for i in range(len(indices)):
    indices[i] = randint(0,df_train.shape[0])

# %%
for ind in indices:
    
    tree_1 = tree()
    tree_2 = tree()

    toks_1 = _getNLPToks_(df_train.get_value(ind,'question1'))
    toks_2 = _getNLPToks_(df_train.get_value(ind,'question2'))

    # Generate a tree structure
    _generateTree_(toks_1, tree_1)
    _generateTree_(toks_2, tree_2)

    # Flip the trees
    _flipTree_(tree_1)
    _flipTree_(tree_2)

    (scoreRaw_cd, scoreNorm_cd) = _CollinsDuffy_(tree_1, tree_2, 0.8, 1)
    (scoreRaw_pt, scoreNorm_pt) = _MoschittiPT_(tree_1, tree_2, 0.8, 0.4, 1)
    print("%s\n%s" % (df_train.get_value(ind,'question1'), df_train.get_value(ind,'question2')))
    print("Collins-Duffy | Norm: %f | Raw: %f" % (scoreNorm_cd, scoreRaw_cd))
    print("Moschitti | Norm: %f | Raw: %f\n" % (scoreNorm_pt, scoreRaw_pt))
# Out:
# How do I overcome smartphone addiction?
# How do I fight my phone addiction?
# Collins-Duffy | Norm: 0.655738 | Raw: 21.262080
# Moschitti | Norm: 0.843661 | Raw: 2.816000
#
# What is the strangest thing that ever happened to you?
# What is the strangest thing someone has ever said to you?
# Collins-Duffy | Norm: 0.323162 | Raw: 29.254400
# Moschitti | Norm: 0.868092 | Raw: 7.424000
#
# How do the Chinese in China view Americans?
# How do the Chinese people view Americans?
# Collins-Duffy | Norm: 0.096894 | Raw: 5.440000
# Moschitti | Norm: 0.738549 | Raw: 4.608000
#
# What are some major social faux pas to avoid when visiting Malta?
# What are some major social faux pas to avoid when visiting Norway?
# Collins-Duffy | Norm: 0.962300 | Raw: 93.331666
# Moschitti | Norm: 1.000000 | Raw: 10.496000
#
# What do you think of Jyoti Basu?
# Who is Jyoti Basu?
# Collins-Duffy | Norm: 0.291996 | Raw: 10.112000
# Moschitti | Norm: 0.760886 | Raw: 2.816000
#
# Which phone should I buy under INR 15K?
# Which mobile I should buy under 15k?
# Collins-Duffy | Norm: 0.246203 | Raw: 13.152000
# Moschitti | Norm: 0.895979 | Raw: 4.352000
#
# How do I get in contact with the Anonymous hackers?
# Who gets punished, the hacker or the client of a hacker?
# Collins-Duffy | Norm: 0.058925 | Raw: 5.600000
# Moschitti | Norm: 0.713068 | Raw: 7.936000
#
# Is it true that Matter waves are faster than the speed of light?
# What's the mmmoffice? Is it true?
# Collins-Duffy | Norm: 0.057395 | Raw: 3.040000
# Moschitti | Norm: 0.509175 | Raw: 3.584000
#
# What's classy if you’re rich, but trashy if you're poor?
# Do rich people ever feel guilty because they're rich?
# Collins-Duffy | Norm: 0.209755 | Raw: 25.491200
# Moschitti | Norm: 0.864619 | Raw: 12.288000
#
# What is an addictive personality?
# What is a non-addictive personality?
# Collins-Duffy | Norm: 0.598332 | Raw: 14.259200
# Moschitti | Norm: 0.894427 | Raw: 2.048000
#
# What is taking ecstasy like?
# Is it possible that ecstasy doesn't work for some people taking the same amount as others?
# Collins-Duffy | Norm: 0.076932 | Raw: 6.080000
# Moschitti | Norm: 0.639137 | Raw: 6.400000
#
# What are some hard mathematics questions for class 9?
# It has been witnessed for years that the questions asked in the admission tests conducted by FIITJEE aren't based on a Class 9 or Class 10 student's mathematical and scientific skills. If they expect us to prepare topics from the JEE then what will they teach us at the coaching institute?
# Collins-Duffy | Norm: 0.068971 | Raw: 10.240000
# Moschitti | Norm: 0.717985 | Raw: 16.896000
#
# What do we mean by standardization?
# What do you mean by standard cell?
# Collins-Duffy | Norm: 0.744816 | Raw: 34.315264
# Moschitti | Norm: 0.970143 | Raw: 4.096000
#
# Why is Spotify nott available in India?
# Why is Spotify not available in India?
# Collins-Duffy | Norm: 0.511488 | Raw: 25.043200
# Moschitti | Norm: 0.947368 | Raw: 4.608000
#
# How do I install things on Linux?
# How do you install XPlanner+ in Linux?
# Collins-Duffy | Norm: 0.404961 | Raw: 21.612800
# Moschitti | Norm: 0.911300 | Raw: 6.656000
#
# What do guys think of this? My bf just told me "we don't know each other that much to marry" after I sent him a long message about our relationship.
# My best friend told that he loves me and that he doesn't find happiness in anything other than talking to me. Should I continue to be his only best friend even after I know my influence on his life is too much or should I break our friendship, making him realize that he has a life other than just me?
# Collins-Duffy | Norm: 0.016341 | Raw: 1.600000
# Moschitti | Norm: 0.560449 | Raw: 7.168000
#
# What are some things new employees should know going into their first day at Express?
# What are some things new employees should know going into their first day at Corning?
# Collins-Duffy | Norm: 0.968598 | Raw: 119.040118
# Moschitti | Norm: 1.000000 | Raw: 16.128000
#
# Is midnight 12 o'clock AM or PM?
# Is 12pm noon or midnight?
# Collins-Duffy | Norm: 0.104553 | Raw: 4.640000
# Moschitti | Norm: 0.852029 | Raw: 5.120000
#
# What is the primary duty of the Madras Sappers in the Indian Army? How do I join the Madras Sappers?
# What is meant by these instructions?
# Collins-Duffy | Norm: 0.173324 | Raw: 11.993600
# Moschitti | Norm: 0.634023 | Raw: 4.608000
#
# How did Aswatthama, Kripacharya, Satyaki, Kritvarma manage to remain alive after the battle of  Mahabharata?
# Did Yuyutsu even fight in the Mahabharata battle?
# Collins-Duffy | Norm: 0.111194 | Raw: 8.800000
# Moschitti | Norm: 0.836046 | Raw: 8.448000
#
# How true is the statement "Gulf of Alaska, where two oceans meet but do not mix"?
# What would happen if we apply a very high voltage across an ocean, just dipping the two terminals inside?
# Collins-Duffy | Norm: 0.066972 | Raw: 11.680000
# Moschitti | Norm: 0.810917 | Raw: 19.200000
#
# Why did the Palmer Raids start?
# What are some safety programs in ground units and how are they used?
# Collins-Duffy | Norm: 0.063378 | Raw: 3.840000
# Moschitti | Norm: 0.513956 | Raw: 3.584000
#
# Which is the best hindi movie in 2016?
# What is the best Bollywood movie of 2016?
# Collins-Duffy | Norm: 0.817524 | Raw: 45.771315
# Moschitti | Norm: 0.958333 | Raw: 5.888000
#
# What is the easiest way to convert an ASPX file to PDF?
# What are some ways to convert PDF files to 300dpi?
# Collins-Duffy | Norm: 0.232307 | Raw: 22.739200
# Moschitti | Norm: 0.680414 | Raw: 8.960000
#
# Which football club has the most loyal fans?
# Which football clubs are the friendliest?
# Collins-Duffy | Norm: 0.146544 | Raw: 6.080000
# Moschitti | Norm: 0.731272 | Raw: 2.560000
#
# What is your New Years Resolution?
# What are your New Years resolutions for 2017?
# Collins-Duffy | Norm: 0.326382 | Raw: 7.993600
# Moschitti | Norm: 0.686406 | Raw: 1.792000
#
# I got a GRE score of 287 and my aggregate is 70% and am in final year btech. Which is better TOEFL or IELTS?
# My GRE score is 287,IELTS 6 and aggregate of 70% . What are suggestions for good universities in MS in CS ??
# Collins-Duffy | Norm: 0.229901 | Raw: 21.504000
# Moschitti | Norm: 0.868599 | Raw: 16.640000
#
# Which are the best horror movies in Hollywood?
# What are the best Hollywood thriller movies?
# Collins-Duffy | Norm: 0.159394 | Raw: 7.680000
# Moschitti | Norm: 0.880771 | Raw: 4.096000
#
# What should a laptop cost in a store with specifications such as Windows 8.1 (64-bit), Intel i5 (5th generation), 8GB RAM (with 2 empty slots), 1TB HDD and 2GB NVIDIA GeForce 940m dedicated graphics?
# I am looking for a laptop with i5 processor, 8GB RAM, 1TB HDD and 2GB Nvidia graphics. What are some good laptops with these specifications?
# Collins-Duffy | Norm: 0.107472 | Raw: 21.600000
# Moschitti | Norm: 0.880238 | Raw: 51.200000
#
# How can I slowly lose weight?
# How can I lose 10 Kilos?
# Collins-Duffy | Norm: 0.517076 | Raw: 21.262080
# Moschitti | Norm: 0.774597 | Raw: 3.072000
#
# Why isn’t Amazon providing the total ratings or reviews filter option in advance search?
# Why are eCommerce websites showing out of stock items in the search results or filter?
# Collins-Duffy | Norm: 0.089719 | Raw: 10.880000
# Moschitti | Norm: 0.877580 | Raw: 14.848000
#
# How do you stay fit if you don't like the gym?
# How can I stay fit with out going gym?
# Collins-Duffy | Norm: 0.152872 | Raw: 13.433600
# Moschitti | Norm: 0.764593 | Raw: 6.912000
#
# For the g+5 building, what is the minimum steel section used as bracings?
# For the g+5 building, what is the minimum steel section used as bracings in staad?
# Collins-Duffy | Norm: 0.850332 | Raw: 80.204544
# Moschitti | Norm: 0.980809 | Raw: 13.568000
#
# How do I survive the competition in online food ordering (middleman) business?
# Are there laws against passive aggressive traps?
# Collins-Duffy | Norm: 0.023724 | Raw: 1.600000
# Moschitti | Norm: 0.605142 | Raw: 6.656000
#
# How can I get permanent residence permit of Norway?
# How can I get permanent residents of Norway?
# Collins-Duffy | Norm: 0.777690 | Raw: 50.407158
# Moschitti | Norm: 0.921681 | Raw: 7.424000
#
# How many people can a user hide at once on OkCupid?
# I'd like to hide myself from some people in OkCupid. What should I do?
# Collins-Duffy | Norm: 0.091928 | Raw: 8.192000
# Moschitti | Norm: 0.659715 | Raw: 6.912000
#
# How does social media help in marketing?
# How does social media helps to promote your business?
# Collins-Duffy | Norm: 0.203193 | Raw: 10.393600
# Moschitti | Norm: 0.510754 | Raw: 3.072000
#
# What are some good channels on YouTube to subscribe?
# Which are some of the best YouTube channels to subscribe for?
# Collins-Duffy | Norm: 0.472938 | Raw: 37.362227
# Moschitti | Norm: 0.900986 | Raw: 7.424000
#
# What are the worst commutes in Manhattan? What are some tips for making them better?
# What are the worst commutes in Minneapolis? What are some tips for making them better?
# Collins-Duffy | Norm: 0.937213 | Raw: 47.185920
# Moschitti | Norm: 1.000000 | Raw: 5.376000
#
# What book (just one) changed your life?
# What are some life-changing books for teenagers?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.172062 | Raw: 0.768000
#
# How can I find the rank of a matrix?
# What are some tricks to find the rank of a matrix?
# Collins-Duffy | Norm: 0.411726 | Raw: 34.914560
# Moschitti | Norm: 0.874083 | Raw: 9.728000
#
# What makes a man happy?
# What makes a man happy all the time?
# Collins-Duffy | Norm: 0.406101 | Raw: 16.025600
# Moschitti | Norm: 0.960769 | Raw: 3.072000
#
# How do I earn more money through internet/online?
# How do you earn money from internet?
# Collins-Duffy | Norm: 0.579662 | Raw: 29.146880
# Moschitti | Norm: 0.940640 | Raw: 4.864000
#
# What is a difference between a small bank and a payments bank? And the need for it?
# What is the difference between a small bank and a payment bank?
# Collins-Duffy | Norm: 0.779427 | Raw: 73.527931
# Moschitti | Norm: 0.983820 | Raw: 14.336000
#
# What is the best way to start a personal tv channel?
# How do I start my own TV channel in the US?
# Collins-Duffy | Norm: 0.037216 | Raw: 2.400000
# Moschitti | Norm: 0.558217 | Raw: 3.584000
#
# In the Bible, was the forbidden fruit a metaphor for sex?
# Why do so many people have trouble understanding that the Bible is metaphorical and not intended to be taken literally?
# Collins-Duffy | Norm: 0.054613 | Raw: 7.680000
# Moschitti | Norm: 0.509753 | Raw: 12.544000
#
# How can I attain a photographic memory?
# Is there a way to develop photographic memory?
# Collins-Duffy | Norm: 0.077697 | Raw: 4.000000
# Moschitti | Norm: 0.739830 | Raw: 4.352000
#
# Evaluate the prospects for better relations between India and Pakistan?
# Should religion be forbidden by law when it tells you to maim or murder?
# Collins-Duffy | Norm: 0.037371 | Raw: 4.000000
# Moschitti | Norm: 0.650167 | Raw: 10.752000
#
# Why is Darwin's theory of evolution still considered fact despite having never been proven?
# How Darwin's theory of evolution is right?
# Collins-Duffy | Norm: 0.298205 | Raw: 27.404800
# Moschitti | Norm: 0.830780 | Raw: 11.264000
#
# Where can I learn C language?
# Where can I learn C language for free?
# Collins-Duffy | Norm: 0.557343 | Raw: 26.542080
# Moschitti | Norm: 0.899735 | Raw: 4.352000
#
# What are some major problems faced by girls during their periods?
# How can I help my girl friend before and during her period?
# Collins-Duffy | Norm: 0.030283 | Raw: 1.600000
# Moschitti | Norm: 0.588348 | Raw: 3.072000
#
# 10,890 people have blocked this no ? Find error in this sentence?
# As a member of the general category how or in what way has the reservation policy affected your chances?
# Collins-Duffy | Norm: 0.033080 | Raw: 2.400000
# Moschitti | Norm: 0.546608 | Raw: 5.376000
#
# Do employees at HD Supply have a good work-life balance? Does this differ across positions and departments?
# Do employees at Tractor Supply have a good work-life balance? Does this differ across positions and departments?
# Collins-Duffy | Norm: 0.789110 | Raw: 45.744128
# Moschitti | Norm: 0.862069 | Raw: 6.400000
#
# Why does my fish have cloudy eyes?
# How many people have been infected with HIV and Aids in South Africa in the last 25 years? How are they being treated?
# Collins-Duffy | Norm: 0.021895 | Raw: 1.600000
# Moschitti | Norm: 0.591864 | Raw: 4.352000
#
# How do I speak English like an original Englishman?
# How can I speak English like an original Englishman?
# Collins-Duffy | Norm: 0.609688 | Raw: 41.885440
# Moschitti | Norm: 0.969697 | Raw: 8.192000
#
# What are some mistakes in the movie "Dangal"?
# What mistakes did you find in the movie 'Dangal'?
# Collins-Duffy | Norm: 0.274216 | Raw: 14.304000
# Moschitti | Norm: 0.786357 | Raw: 4.096000
#
# How do I start a startup if I have an idea ?
# How do I start a startup business if we have an idea?
# Collins-Duffy | Norm: 0.831117 | Raw: 77.905402
# Moschitti | Norm: 0.990847 | Raw: 12.032000
#
# What is RuBP and what is its purpose in photosynthesis?
# What are some examples of photosynthesis?
# Collins-Duffy | Norm: 0.242966 | Raw: 14.624000
# Moschitti | Norm: 0.793575 | Raw: 5.888000
#
# What is the best website to download free physics books?
# Is there any website to download physical therapy books?
# Collins-Duffy | Norm: 0.258546 | Raw: 18.318080
# Moschitti | Norm: 0.876714 | Raw: 7.168000
#
# I have 1 crore rupees, where should I invest so that I get a minimum of 5 lacs as fixed monthly income?
# If you suddenly get 1 crore rupees, how will you invest it and where?
# Collins-Duffy | Norm: 0.208449 | Raw: 39.475200
# Moschitti | Norm: 0.839489 | Raw: 24.832000
#
# How can I change my Life?
# How you can change your life?
# Collins-Duffy | Norm: 0.244867 | Raw: 6.880000
# Moschitti | Norm: 0.877058 | Raw: 2.560000
#
# Are we near World War 3?
# Is World War 3 coming?
# Collins-Duffy | Norm: 0.266205 | Raw: 7.520000
# Moschitti | Norm: 0.700649 | Raw: 2.304000
#
# How do you recognize people from Chinese, Korean, Japanese, Thai and Vietnamese origins?
# How do you recognize Japanese, Chinese and Korean?
# Collins-Duffy | Norm: 0.305059 | Raw: 22.862080
# Moschitti | Norm: 0.613972 | Raw: 7.424000
#
# What was the bad memorable incident that happened in your marriage?
# What have been your most memorable/terrible incident at airport?
# Collins-Duffy | Norm: 0.081684 | Raw: 5.280000
# Moschitti | Norm: 0.577350 | Raw: 3.584000
#
# Which is the best college to do a PG in cyber security? What are the scopes and eligibility?
# Which is the best college for PG in Cyber Security in India?
# Collins-Duffy | Norm: 0.319849 | Raw: 39.123200
# Moschitti | Norm: 0.791629 | Raw: 14.848000
#
# Do UFOs exist? Is there any recorded video on them to prove that they exist?
# Is there any proof that shows that UFOs exist?
# Collins-Duffy | Norm: 0.132565 | Raw: 5.792000
# Moschitti | Norm: 0.556349 | Raw: 3.328000
#
# How do you respond when someone calls you stupid?
# How do you respond when someone calls you an idiot?
# Collins-Duffy | Norm: 0.762774 | Raw: 70.529772
# Moschitti | Norm: 0.947613 | Raw: 10.496000
#
# Which Android apps do you wish existed?
# Which Android apps do do you want to exist?
# Collins-Duffy | Norm: 0.366520 | Raw: 23.087360
# Moschitti | Norm: 0.835240 | Raw: 6.656000
#
# How do you start a new life without any money?
# How do I start a new life with no money?
# Collins-Duffy | Norm: 0.871531 | Raw: 59.711539
# Moschitti | Norm: 1.000000 | Raw: 7.424000
#
# How is it possible for you to get pregnant 8 days before ovulation?
# Is it possible to get pregnant 2 days before ovulation?
# Collins-Duffy | Norm: 0.416146 | Raw: 31.822080
# Moschitti | Norm: 0.918846 | Raw: 7.680000
#
# How can I register for CPA EXAM FROM DUBAI?
# Does using wires with a diode, to use latent thermal energy, disprove or defeat the laws of thermodynamics?
# Collins-Duffy | Norm: 0.033991 | Raw: 3.200000
# Moschitti | Norm: 0.462952 | Raw: 7.168000
#
# Is anyone about to uninstall Quora and stop using it? Why?
# Why would you stop using Quora?
# Collins-Duffy | Norm: 0.210090 | Raw: 13.945600
# Moschitti | Norm: 0.728493 | Raw: 5.632000
#
# Is the O- blood group the universal donor or not?
# Is the O+ blood group the universal donor or not?
# Collins-Duffy | Norm: 0.182085 | Raw: 12.480000
# Moschitti | Norm: 0.915737 | Raw: 10.240000
#
# What is wrong with you Quora?
# What's wrong with the Quora website?
# Collins-Duffy | Norm: 0.323703 | Raw: 16.665600
# Moschitti | Norm: 0.788811 | Raw: 3.584000
#
# Why are there 24 hours in a day, and how does the lenght of day on Earth compare to the one on Mercury?
# Why are there 24 hours in a day, and how does the lenght of day on Earth compare to the one on Venus?
# Collins-Duffy | Norm: 0.985143 | Raw: 253.566513
# Moschitti | Norm: 1.000000 | Raw: 51.200000
#
# What is the best personality test?
# What are some good personality tests?
# Collins-Duffy | Norm: 0.255163 | Raw: 8.793600
# Moschitti | Norm: 0.752618 | Raw: 2.304000
#
# What are some of the most dangerous enemies of the polar bears?
# What are some of the enemies from polar bears? How do they protect themselves?
# Collins-Duffy | Norm: 0.616460 | Raw: 60.090214
# Moschitti | Norm: 0.966575 | Raw: 13.056000
#
# If I skip a back paper in B.Tech, will I face any problem during certificate verification by PSU or IIT?
# I am a B.Tech (ECE) 2012 pass out. I was selected for a central government job in the department of India, but now I want to change my job profile. I want to start working in the technical field, but I am facing so many problems. How do I change my job?
# Collins-Duffy | Norm: 0.081645 | Raw: 8.032000
# Moschitti | Norm: 0.819850 | Raw: 17.920000
#
# How do I bring a positive change in society?
# How do I bring positive change to society?
# Collins-Duffy | Norm: 0.586019 | Raw: 34.876160
# Moschitti | Norm: 0.941357 | Raw: 6.144000
#
# Why do some Japanese guys try to look feminine? Don't the girls find it gross?
# Why have most of the guys in India become so desperate? Don't they know that girls don't always look for relationships? Would it hurt guys to become our friend first?
# Collins-Duffy | Norm: 0.177666 | Raw: 14.649600
# Moschitti | Norm: 0.641448 | Raw: 6.400000
#
# Which is the most popular hybrid mobile app framework?
# What is the Best framework for hybrid mobile app?
# Collins-Duffy | Norm: 0.230563 | Raw: 13.945600
# Moschitti | Norm: 0.881483 | Raw: 6.656000
#
# What is your review of Bones (2010 movie)?
# What is your review of Winter's Bone (2010 movie)?
# Collins-Duffy | Norm: 0.549613 | Raw: 32.382208
# Moschitti | Norm: 0.943300 | Raw: 7.936000
#
# In SAP BODS, what are the questions asked for a 3-year experienced profile?
# What are some free SAP BODS online websites?
# Collins-Duffy | Norm: 0.081802 | Raw: 5.440000
# Moschitti | Norm: 0.731993 | Raw: 6.144000
#
# Can Russia with China defeat the USA?
# In a battle between the USA, Russia, India, North Korea, Japan & China, who would be the last one standing?
# Collins-Duffy | Norm: 0.133489 | Raw: 11.680000
# Moschitti | Norm: 0.883702 | Raw: 13.568000
#
# How do I escape from depression without going to therapists?
# How do I overcome from depression without getting help from anyone?
# Collins-Duffy | Norm: 0.631565 | Raw: 59.350835
# Moschitti | Norm: 0.933218 | Raw: 11.264000
#
# How do I to get funding for an airline company?
# What is difference between model, working and screen coordinate system?
# Collins-Duffy | Norm: 0.081034 | Raw: 6.880000
# Moschitti | Norm: 0.717137 | Raw: 9.216000
#
# Which countries have no official language?
# Why do nations have an official language?
# Collins-Duffy | Norm: 0.287585 | Raw: 12.064000
# Moschitti | Norm: 0.816497 | Raw: 3.072000
#
# What is the technical support phone number for Linksys routers?
# What is lenovo laptop technical support phone number?
# Collins-Duffy | Norm: 0.291858 | Raw: 17.459200
# Moschitti | Norm: 0.883912 | Raw: 7.936000
#
# Is it possible transfer a video from one YouTube channel to another?
# How can one move videos from one YT channel to another?
# Collins-Duffy | Norm: 0.234150 | Raw: 21.236480
# Moschitti | Norm: 0.891780 | Raw: 14.848000
#
# Does Hillary Clinton have Parkinson's Disease?
# How likely is it that Hillary Clinton has Parkinson's disease or other health issues as an explanation for her sometimes erratic movements?
# Collins-Duffy | Norm: 0.103620 | Raw: 8.960000
# Moschitti | Norm: 0.742393 | Raw: 10.496000
#
# What would happen if Trump assaulted a protester and the protester defended himself?
# Paying 25 extra on depositing money through cash deposit machine?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.677186 | Raw: 11.008000
#
# Where can I get cannabis in Bangalore?
# Where can I get some high quality weed (cannabis,marijuana) in Bangalore?
# Collins-Duffy | Norm: 0.432474 | Raw: 31.534080
# Moschitti | Norm: 0.879599 | Raw: 10.240000
#
# How can hydrogen peroxide remove stains?
# How can carpet stains be removed with hydrogen peroxide?
# Collins-Duffy | Norm: 0.427831 | Raw: 21.491200
# Moschitti | Norm: 0.916698 | Raw: 5.120000
#
# Which are some of the books entrepreneurs must read?
# What are the best books for entrepreneurs to read?
# Collins-Duffy | Norm: 0.309532 | Raw: 24.687360
# Moschitti | Norm: 0.886789 | Raw: 8.704000
#
# What kind of economy does the United States have compared to the one in Germany?
# What kind of economy does the United States have compared to the economies of other countries?
# Collins-Duffy | Norm: 0.603790 | Raw: 74.001664
# Moschitti | Norm: 0.940374 | Raw: 15.360000
#
# Is it safe to listen to music on my phone while it's charging?
# What are the consequences of listening to music while charging the phone?
# Collins-Duffy | Norm: 0.094546 | Raw: 10.880000
# Moschitti | Norm: 0.761606 | Raw: 11.776000
#
# Will a single phase electric motor run on a three phase electrical power source?
# What key differences exist between two and three phase electric power?
# Collins-Duffy | Norm: 0.090884 | Raw: 8.480000
# Moschitti | Norm: 0.700880 | Raw: 10.496000
#
# I would like to start a tamil channel in mumbai, but I need some partnership 09987510597 if anybuddy?
# Why is my stomach upset after periods?
# Collins-Duffy | Norm: 0.061055 | Raw: 4.640000
# Moschitti | Norm: 0.447989 | Raw: 4.352000
#
# How one can learn SEO online?
# How can I learn seo online?
# Collins-Duffy | Norm: 0.264506 | Raw: 11.872000
# Moschitti | Norm: 0.865181 | Raw: 4.096000
#
# Why was Charles Darwin considered an atheist?
# How does the flume agent gets the available free block and data node information on hdfs for storing the data?
# Collins-Duffy | Norm: 0.067081 | Raw: 6.432000
# Moschitti | Norm: 0.642058 | Raw: 8.192000
