# %%
import pandas as pd
import numpy as np
from pycorenlp import StanfordCoreNLP 
from collections import defaultdict
from itertools import product
import re
import time
import bisect

# %%
nlp = StanfordCoreNLP('http://localhost:9000')

# %%
def _getNLPToks_(rawSentence):
    output = nlp.annotate(rawSentence, properties={
      'annotators': 'tokenize,ssplit,pos,parse',
      'outputFormat': 'json'
      })
    return output['sentences'][0]['parse'].split("\n")

# %%
def tree(): return defaultdict(tree) # example of autovivification

# %%
def _leadingSpaces_(target):
    return len(target) - len(target.lstrip())

def _findParent_(curIndent, parid, treeRef):
    tmpid = parid
    while (curIndent <= treeRef[tmpid]['indent']):
        tmpid = treeRef[tmpid]['parid']
    return tmpid

# %%
def _generateTree_(rawTokens, treeRef):
    
    # (, ,) as stand-alone
    REGEX_PUNC = r"^\s*\([,!?.'\"]\s*[,!?.'\"]\)"
    # (token
    REGEX_OPEN = r"^\s*\(([a-zA-Z0-9_']*)$"
    # (token (tok1 tok2) (tok3 tok4) .... (tokx toky))
    REGEX_COMP = r"^\s*\(([a-zA-Z0-9_']*)\s*((?:[(]([a-zA-Z0-9_;.,?'!]*)\s*([a-zA-Z0-9_;\.,?!']*)[)]\s*)*)"
    # (tok1 tok2)
    REGEX_ISOL_IN_COMP = r"\(([a-zA-Z0-9_;.,?!']+)\s*([a-zA-Z0-9_;.,?!']+)\)"
    # (, ,)
    REGEX_PUNC_SOLO = r"\([,!?.'\"]\s*[,!?.'\"]\)"
    # (tok1 tok2) as stand-alone
    REGEX_SOLO_PAIR = r"^\s*\(([a-zA-Z0-9_']+)\s*([a-zA-Z0-9_']+)\)"
    
    # manually insert Root token 
    treeRef[len(treeRef)] = {'curid':0, 
                             'parid':-1, 
                             'posOrTok':'ROOT', 
                             'indent':0,
                            'children':[],
                            'childrenTok':[]}
    ID_CTR = 1
    
    for tok in rawTokens[1:]:
        
        curIndent = _leadingSpaces_(tok) # the current indent level
        parid = _findParent_(curIndent, ID_CTR-1, treeRef) # determine parid
            
        checkChild = re.match(REGEX_COMP, tok)
        if (checkChild):
            treeRef[ID_CTR] = {'curid':ID_CTR, 
                               'parid':parid, 
                               'posOrTok':checkChild.group(1), 
                               'indent':curIndent,
                              'children':[],
                              'childrenTok':[]}
            upCTR = ID_CTR
            ID_CTR += 1
            # Eliminate further punctuation

            subCheck = re.sub(REGEX_PUNC_SOLO,'',checkChild.group(2))
            subs = re.findall(REGEX_ISOL_IN_COMP, subCheck) 
            for ch in subs:
                # THE INDENTING IS WRONG HERE - THE HEIRARCHY IS MESSED UP - check test output
                treeRef[ID_CTR] = {'curid':ID_CTR, 
                                   'parid':upCTR, 
                                   'posOrTok':ch[0], 
                                   'indent':curIndent+2,
                                  'children':[],
                                  'childrenTok':[]}
                ID_CTR += 1
                treeRef[ID_CTR] = {'curid':ID_CTR, 
                                   'parid':ID_CTR-1, 
                                   'posOrTok':ch[1], 
                                   'indent':curIndent+2,
                                  'children':[],
                                  'childrenTok':[]}
                ID_CTR += 1
            continue
            
            
        checkSingle = re.match(REGEX_SOLO_PAIR, tok)
        if (checkSingle):
            treeRef[ID_CTR] = {'curid':ID_CTR, 
                               'parid':parid, 
                               'posOrTok':checkSingle.group(1), 
                               'indent':curIndent+2,
                              'children':[],
                              'childrenTok':[]}
            ID_CTR += 1
            treeRef[ID_CTR] = {'curid':ID_CTR, 
                               'parid':ID_CTR-1, 
                               'posOrTok':checkSingle.group(2), 
                               'indent':curIndent+2,
                              'children':[],
                              'childrenTok':[]}
            ID_CTR += 1
            continue


        checkMatch = re.match(REGEX_OPEN, tok)
        if (checkMatch):
            treeRef[ID_CTR] = {'curid':ID_CTR, 
                               'parid':parid, 
                               'posOrTok':checkMatch.group(1), 
                               'indent':curIndent,
                              'children':[],
                              'childrenTok':[]}
            ID_CTR += 1
            continue

        checkPunc = re.match(REGEX_PUNC, tok)
        if (checkPunc): # ignore punctuation
            continue

    return

# %%
'''
_generateTree_() method only provides tree (dict representation) listing parents. 
This is a naive method to add a "children" field to the tree - necessary for optimal Tree Kernel methods.
'''

# Switching to 2-pass O(N)
def _flipTree_(treeRef):
    # Pass 1 fill in children
    for k,v in treeRef.items():
        if (k > 0):
            bisect.insort(treeRef[v['parid']]['children'], k)
    # Pass 2 map children to tokens
    for k,v in treeRef.items():
        if (k > 0):
            treeRef[k]['childrenTok'] = [treeRef[ch]['posOrTok'] for ch in treeRef[k]['children']]

# %%
'''
Implementation of the Colins-Duffy or Subset-Tree (SST) Kernel
'''

def _isLeaf_(tree, parentNode):
    return (len(tree[parentNode]['children']) == 0)

def _isPreterminal_(tree, parentNode):
    for idx in tree[parentNode]['children']:
        if not _isLeaf_(tree, idx):
            return False
    return True

def _cdHelper_(tree1, tree2, node1, node2, store, lam):    
    # No duplicate computations
    if store[node1, node2] >= 0:
        return
    
    # Leaves yield similarity score by definition
    if (_isLeaf_(tree1, node1) or _isLeaf_(tree2, node2)):
        store[node1, node2] = 0
        return
    
    # same parent node
    if tree1[node1]['posOrTok'] == tree2[node2]['posOrTok']: 
        # same children tokens
        if len(tree1[node1]['childrenTok'].symmetric_difference(tree2[node2]['childrenTok'])) == 0:
            # Check if both nodes are pre-terminal
            if _isPreterminal_(tree1, node1) and _isPreterminal_(tree2, node2):
                store[node1, node2] = lam
                return
            # Not pre-terminal. Recurse among the children of both token trees. 
            else:              
                combs = product(tree1[node1]['children'], tree2[node2]['children'])
                runningTotal = 0
                for idx, c in enumerate(combs):
                    _cdHelper_(tree1, tree2, c[0], c[1], store, lam) # Recursively run helper
                    runningTotal += (1 + store[c[0],c[1]])
                    
                store[node1, node2] = lam * runningTotal
                return
        else:
            store[node1, node2] = 0
    else: # parent nodes are different 
        store[node1, node2] = 0
        return 

def _cdKernel_(tree1, tree2, lam):
    # Fill the initial state of the store 
    store = np.empty((len(tree1), len(tree2)))
    store.fill(-1)
    
    # O(N^2) to compute the tree dot product
    for i in range(len(tree1)):
        for j in range(len(tree2)):
            _cdHelper_(tree1, tree2, i, j, store, lam)
            
    return store.sum()

# %% [markdown]
# ## Test: Tree Generation and Collins-Duffy Kernel

# %%
test_b1 = "How do I reduce my thighs?"
test_b2 = "What can I do to reduce my belly?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tree()
tree_b2 = tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
_generateTree_(toks_b1, tree_b1)
_generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
_flipTree_(tree_b1)
_flipTree_(tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

score2 = _cdKernel_(tree_b1, tree_b2, 0.8)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel

print("Score: %s" % (score2))
# Out:
# --- 0.0509340763092041 seconds ---
# --- 0.051650047302246094 seconds ---
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-18-02fc58ffb63f> in <module>()
#      22
#      23 # Flip the trees
# ---> 24 _flipTree_(tree_b1)
#      25 _flipTree_(tree_b2)
#      26
#
# <ipython-input-16-47b8d236cd84> in _flipTree_(treeRef)
#      21     # Pass 1 fill in children
#      22     for k,v in treeRef.items():
# ---> 23         bisect.insort(treeRef[v['parid']]['children'], k)
#      24     # Pass 2 map children to tokens
#      25     for k,v in treeRef.items():
#
# TypeError: object of type 'collections.defaultdict' has no len()

# %%
toks_b1
# Out:
# ['(ROOT',
#  '  (SBARQ',
#  '    (WHADVP (WRB How))',
#  '    (SQ (VBP do)',
#  '      (NP (PRP I))',
#  '      (VP (VB reduce)',
#  '        (NP (PRP$ my) (NNS thighs))))',
#  '    (. ?)))']

# %%
start_time = time.time()
output = nlp.annotate("What can I do to reduce my belly?", properties={
  'annotators': 'tokenize,ssplit,pos,parse',
  'outputFormat': 'json'
  })
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel
# Out:
# --- 0.03567695617675781 seconds ---

# %% [markdown]
# ## Test: Tree Kernels on Training Data

# %%
from random import randint

def read_data(path_to_file):
    df = pd.read_csv(path_to_file)
    print ("Shape of base training File = ", df.shape)
    # Remove missing values and duplicates from training data
    df.drop_duplicates(inplace=True)
    df.dropna(inplace=True)
    print("Shape of base training data after cleaning = ", df.shape)
    return df

df_train = read_data("input/train.csv")
# Out:
# Shape of base training File =  (404290, 6)
# Shape of base training data after cleaning =  (404288, 6)

# %%
## SET UP TEST INDICES TO SELECT RANDOM ROWS

TEST_SAMPLES = 1000
indices = np.arange(TEST_SAMPLES)
for i in range(len(indices)):
    indices[i] = randint(0,df_train.shape[0])

# %%
for ind in indices:
    
    tree_1 = tree()
    tree_2 = tree()

    toks_1 = _getNLPToks_(df_train.get_value(ind,'question1'))
    toks_2 = _getNLPToks_(df_train.get_value(ind,'question2'))

    # Generate a tree structure
    _generateTree_(toks_1, tree_1)
    _generateTree_(toks_2, tree_2)

    # Flip the trees
    _flipTree_(tree_1)
    _flipTree_(tree_2)

    score = _cdKernel_(tree_1, tree_2, 0.9)
    print("%s \n %s \n %f" % (df_train.get_value(ind,'question1'), df_train.get_value(ind,'question2'), score))
# Out:
# How can I get Limousine transport easily in Singapore?
#  Complete this sentence: Life is boring without…?
#  0.900000
# Which is best software course for a fresher to get IT job? Which course has more demand nowadays
#  Which course in IT has a great demand in the market that gets more package too?
#  36.540000
# What is the most popular sport in China?
#  What sports are most popular in China?
#  32.769000
# What are all the flavors of Native American Spirit Cigarettes, and what do the colors mean?
#  What is a good price for American Spirit Cigarettes?
#  15.750000
# What is the sense of life?
#  What is the sense of your life?
#  89.191413
# How did Indian soldiers surrender to Pakistan army in LoC?
#  How many casualties have actually been amounted on either side of the LOC in 2014 due to the ongoing tussle between the armies of India and Pakistan?
#  26.820000
# Can a transgender woman give birth?
#  Can a transgender woman become pregnant?
#  61.935300
# Why do you think you are so special?
#  Why do you think you're special?
#  124.993029
# What is sensex? What is nifty?
#  What are the Nifty and Sensex?
#  21.824100
# How many 250w solar panels do I need to charge a battery of 12 volts 200Ah in an hour?
#  How many watts solar do I need to charge a 12v 200ah battery.?
#  52.362990
# What should do when nothing goes right in life?
#  What do I do when everything goes wrong in my life?
#  54.159300
# What's the difference of view, scene, scenery and sight?
#  What is the difference between perceptual view and conceptual view?
#  55.538100
# What are some recipes using Hormel Black Label Ham?
#  What are some good recipes with Hormel Black Label canned ham?
#  64.600200
# What is the total number of MBBS seats available through NEET 2016?
#  What are the total number of seats in neet (15 percent quota) in 2016?
#  103.310100
# How will you know you love someone?
#  How do know that you are in love?
#  15.669000
# Where can you find the best Binary Options trading Systems?
#  Applications 4 bit asynchronous counter?
#  0.000000
# What is the Reason behind human suffering?
#  What are the primary causes behind the sufferings of human beings?
#  47.843100
# In Freemasonry, why do we open the bible on Psalms 133 in the first degree?
#  Who was the first high priest in the Bible?
#  37.170000
# Can we get more technical knowledge for manufacturing business by studying in IIT?
#  Is the show Arrow appropriate?
#  1.800000
# What is your favorite alcoholic beverage, and why?
#  What's your favorite alcoholic beverage?
#  7.110000
# How do girls pee?
#  How do women pee?
#  56.745990
# What is personal goal statement?
#  What are personal goals?
#  22.724100
# What is the current difference between MS and ME in Usa. Does job opportunities differ?
#  What is difference between CIS, CS,SE in MS?
#  60.858000
# Were there any magazines similar to "Playboy" or "Hustler" in the 19th century?
#  If you were given a chance to slap a historical person between 1st century to 19th century whom would you slap and why?
#  16.200000
# What is the meaning of life? Whats our purpose on Earth?
#  From your perspective, what is the purpose of life?
#  50.032890
# Is it true that sending rocket with no cargo to space is cheap but sending rockets to space with cargo it is a day and night difference?
#  How many pounds of rocket fuel are necessary to propel 1 pound of mass into Earth's orbit from sea level?
#  52.110000
# Is there any possibility of release of GTA 5 on Android devices?
#  What is the dragon-based video game due to be released in 2016?
#  10.800000
# What is an airsoft gun?
#  What is an AEG airsoft gun?
#  37.375200
# Why is life so hard on me?
#  Why is life so hard to understand?
#  26.234100
# What is Kirchhoff's voltage law?
#  What is Kirchhoff's law?
#  70.232022
# How many hours do 4.0 students study per day?
#  How many hours I have to study in class 10 per day if I have to take science in class 11th?
#  17.118000
# Do people start their businesses for love or money?
#  I love my wife but I am attracted to other women. How do I get over this?
#  8.100000
# Why do people pray to God even though everything is predestined?
#  Why do people pray to god even though they know that everything in future is fixed?
#  182.352267
# As a plastic surgeon, what's your biggest concern with your marketing?
#  As a plastic surgeon, what are you biggest concerns with your business?
#  75.174300
# What do you think about the brand SYSKA with regard to LED lighting products?
#  What do you think about C by GE LED bulb?
#  73.090890
# How can I lose max weight in 14 days?
#  What is the fastest way to lose weight successfully?
#  5.310000
# What happens when a 220V appliance is plugged into a 110V socket, and the other way around?
#  Machine name plate says 208-230V, 60Hz, 3 PH. Its a freezer. What happens if I plug it into a 220V 50Hz electric supply?
#  0.000000
# What does psomí mean?
#  What does 逆転の法則 mean?
#  53.650890
# What's the most embarrassing moment you've ever had?
#  What's the most embarrassing moment of your life?
#  56.203200
# What is a good business plan for an assisted living facility?
#  What is a business plan and its objective?
#  37.375200
# What's the best way to get rid of a chest infection?
#  What is the best way to get rid of fleas in my hair?
#  146.132040
# What are the best aspects of living in Kiev as a young adult?
#  Why would mexico pay for the wall, trump plans on cutting the funds immigrants send to mexico, but he also plans on deporting them, so I don't get it?
#  33.480000
# Which is the best laptop under Rs 60000 for gaming in India?
#  What are some of the best gaming laptops under rs 60000 that are available in india?
#  89.532000
# Can someone travel back in time?
#  Can we go back in time?
#  41.958000
# I'm currently in stage two of Huntingtons Disease. How long is progression from beginning to mid stage typically take?
#  What are the typical healing stages in a skin graft rehab post op? Also, how long does the transition take to result in close to normal skin (at present the area after 1 week looks pretty gross)?
#  15.750000
# How does Startpage.com make money?
#  How does linkis.com make money?
#  73.933911
# Why do you think that Doctor Strange (movie) is not good?
#  What is your review of Doctor Strange (2016 movie)?
#  24.858000
# I have a very dry and frizzy hair. I want to get a shiny, smooth and soft hair naturally. What are some ideas?
#  I am Caucasian and I have fine hair. My hair gets frizzy and I'd like smoother, shiny hair. We've had so much humidity. I use a round brush to curl my hair under as I blow dry it. What are some tips to get smoother, shiny hair and fight frizz?
#  11.430000
# What is the most unique name you ever heard?
#  What is the most unique name you have ever heard?
#  143.686558
# What are some must watch Tamil movies?
#  What are some of the copied but still great Bollywood movies?
#  25.334100
# How do I get rid of unwanted hair with laser hair removal treatment?
#  How do I write a web content on a certain topic?
#  60.850890
# What can make someone feel better when they are sad?
#  What are some things that make you sad?
#  21.600000
# Where can I learn horse riding in Nagpur?
#  Where can I learn variety of skills and techniques for horse riding in Melbourne?
#  70.570890
# What is a bulk SMS gateway?
#  What is bulk SMS gateway?
#  36.475200
# What does it mean if a girl calls you smooth?
#  What does it mean to be smooth?
#  58.060890
# What are the salaries of chemical engineers?
#  What are chemical engineering salary?
#  34.675200
# Why did Hanson grow their hair long?
#  How long does it take to grow long hair naturally?
#  28.710000
# Is it possible to lose weight without going to the gym?
#  Can I lose weight without going to gym?
#  66.102381
# What are Um renagade in India users review?
#  What are some hacks to find the profile pages of Yelp users whose reviews are in the "Not Recommended" section?
#  21.060000
# How can I find an IFSC code by using a bank account number?
#  I transferred an amount from HDFC to an Sbi account. The IFSC code is wrong, but the account number is right. What do I do now?
#  24.120000
# I cheated in a programming interview and successfully got a job, how do I survive after that?
#  After a successful job interview, a potential employer asked me for proof of my compensation history. How do I ask them to respect my privacy?
#  29.700000
# What is the best way to make man happy?
#  Dating and Relationships: How can I get over a break up?
#  0.900000
# Why do planes close the lights when taking off and landing?
#  Why do airlines dim the cabin lights for take-off and landing?
#  52.665300
# What is really activation energy?
#  Why is activation energy positive?
#  3.600000
# Which one is the best landing page service at 2016?
#  What are the best landing page builders?
#  19.890000
# What are the possible implications of adoption of a common currency?
#  What are the possible implications of adoption of common currency such as the Euro?
#  204.246748
# Who would win Superman or Goku?
#  Can Superman beat Goku?
#  4.500000
# How do I learn math?
#  How can I learn math?
#  33.893100
# How long does it take for me to get a US green card through my child if my child is a green card holder?
#  How long does it take for one to get a US green card through their parents if the parents are green card holders?
#  248.109390
# Does a gap of a year after graduation seriously affects my career prospects?
#  Will a gap year after graduation adversely affect my interview at IIMs?
#  30.150000
# Do people with higher intelligence have a better-working subconsciousness?
#  Do people with higher intelligence have better memories?
#  44.494200
# When was 2011 5th Global Shipping Summit?
#  Where is the 2011 5th Global Shipping Summit?
#  23.229000
# What's wrong with this solution
#  What is wrong with this solution?
#  48.991680
# Can you play music in a fighter jet?
#  Can fighter pilots listen to music while flying or during combat?
#  38.709000
# What are some of the best books to learn coding?
#  What is the best book to learn coding as a self-study?
#  46.952100
# How do I register for the TOEFL with multiple given names?
#  How do I register multiple given names in TOEFL?
#  64.450890
# What do you think is a healthy food for you?
#  What exactly is healthy food?
#  18.990000
# The best of 2016: Which were the worst Bollywood movies in 2016?
#  Which are the worst Bollywood movies of 2016?
#  74.113200
# Is MLM legal in India?
#  Which are the TOP MLM Companies in India?
#  11.259000
# How do I start preparing for civil services?
#  How can I start preparing for civil service examination?
#  52.774200
# Which simulator should one use for RF module, HT12D (decoder) and HT12E (Encoder)?
#  How do I design a 4:16 decoder using 3:8 decoder?
#  0.900000
# How do I hack DDTank 321?
#  How can I hack COINS in DDTank 321?
#  32.354100
# Where can I buy Vajiram and Vision IAS class notes and handouts in Delhi?
#  What is the total fees for IAS Coaching in Vajiram and Ravi institute of Delhi?
#  68.302890
# Was Adolf Hitler a good leader?
#  What are some facts about Hitler?
#  3.510000
# What is it like to be a hot transgender woman?
#  How do I hide being a transgender woman from my parents?
#  18.630000
# Why doesn't Quora allow the use of emoticons?
#  Why doesn't Quora update to support emojis?
#  77.418990
# Why would God condemn homosexuality and then make gay genes?
#  If God hates homosexuality, why did He make it possible?
#  7.020000
# Can we earn money through Quora?
#  How can I earn money through Quora?
#  29.672100
# Who are the 49ers rival football teams, and why?
#  How many football players play on a team?
#  0.000000
# How do I watch English movies online with subtitles?
#  In which sites I can watch Hollywood movies for free with English subtitles?
#  22.599000
# What happens to Voldemort after he dies?
#  What happened to Grindelwald after he died?
#  48.967200
# In Minecraft, how does a trapped chest work?
#  How many people play Minecraft daily?
#  3.510000
# Are there any commands in Linux to log out from the terminal?
#  How do I use Linux most command?
#  3.510000
# What is the Leonard Cohen song "Hallelujah" about?
#  Who is Leonard in the Merle Haggard song?
#  39.249000
# Do employees at Power Solutions International have a good work-life balance? Does this differ across positions and departments?
#  Do employees at Reading International have a good work-life balance? Does this differ across positions and departments?
#  106.764192
# Does having a gap year after graduation affect the placement prospects of an IIM student?
#  Does a gap of a year after graduation seriously affects my career prospects?
#  75.852000
# Who are some bisexual/lesbian top models?
#  I have come out as bisexual but I think I might actually be a lesbian. How do I tell people?
#  0.000000
# Can we take protinex instead of whey protein?
#  Why is it important to take Whey Protein if you are going to the gym?
#  2.700000
# Can I apply aloe vera gel to my face every night before sleeping?
#  Is the 99% aloe vera gel from GNC really effective in getting rid of scars?
#  6.210000
# What are the similarities and differences between American and British elections?
#  What are some of the differences between pizza sold in the US compared to pizza sold in Italy?
#  84.576960
# How do I make a career in animation?
#  Can I make a career in animation?
#  38.951100
# Why doesn't my body generate enough heat?
#  How does the body generate heat?
#  20.529000
# When are the iim interview results generally announced?
#  What if my result of graduation is pending at the time of interview in IIM? Do I have any option or not?
#  11.610000
# What's the meaning of life?
#  What the meaning of this all life?
#  50.921100
# Why do some Andhra people do crazy stuff in movie theaters in the USA?
#  What is the full form of AMC, the movie theater chain in USA?
#  22.320000
# Is there a gender pay gap? If so why?
#  Is the gender pay gap a myth?
#  101.615400
# What are the most famous/popular local products and businesses in Detroit?
#  What are the most famous/popular local products and businesses in Chicago?
#  175.501162
# Is Modi will do something against reservation?
#  Will Modi remove Quota Reservation?
#  5.310000
# What are the best programming blogs?
#  What is the best programming blog?
#  24.524100
# Why do many Muslims hate RSS?
#  Why most of the muslims hate RSS?
#  12.069000
# What happens if I press my penis hard enough to not let out semen during an ejaculation?
#  What happens during chin tuck surgery?
#  29.834100
# How do you feel about the new MacBook Pro, late 2016?
#  What are your thoughts on the new 2016 MacBook Pro?
#  9.000000
# Why did Yahoo answers fail and Quora succeed?
#  What are the differences between Quora, Reddit, and Yahoo Answers?
#  9.720000
# Arctan (10/10sqrt(3)) =pi/6. I get 0.523598… radians and I do not know how to convert to pi/6. can anyone help me?
#  Is it possible to attend MS in CS without any BS?
#  1.800000
# I have been out of high-school for 2 years and now would like to continue with my studies. But I don’t want any long term commitments-Recommendations?
#  I don't want to have sex with my 2 year boyfriend right now. We make out, but I don't want to lose my virginty before i get married. Am i wrong?
#  56.005200
# How can I block a particular user by his IP using my mobile hotspot?
#  How do I Block devices from using internet on mobile hotspot?
#  12.420000
# Why does Hillary believe that anyone who states a fact such as the Western civilization were accelerated by whites, are racist?
#  Why is it that seemingly rational, fair, non-racist people have such a hard time accepting white privilege or systematic racism as a real thing?
#  65.474100
# How can the drive from Edmonton to Auckland be described, and how do these cities' attractions compare to those in Toronto?
#  How can the drive from Edmonton to Auckland be described, and how do these cities' attractions compare to those in Ottawa?
#  527.410949
# Is it possible to divide Pakistan into Pashtunistan, Sindhudesh, Balochistan and Punjab and annexing Gilgit Baltistan and Azad Kashmir back to India?
#  How can Bangladesh break Pakistan into Pashtunistan, Sindhudesh, Balochistan and Punjabistan?
#  153.753300
# Will India separate Balochistan from Pakistan?
#  How can India separate Balochistan from Pakistan?
#  20.889000
# My girlfriend is depressed. What can I do?
#  My Girlfriend is in depression, What should I do?
#  17.190000
# In the Bible, if God knew that Satan was going to turn evil, why did he/she still create him?
#  If God knew Lucifer would rebel against him, then why did He create him?
#  74.203200
# I eat two large cucumbers every day. Is it good or bad for health?
#  Is it bad for my health if I eat too many nuts a day?
#  15.930000
# How can I earn some extra money during weekends in chennai?
#  What are the additional ways of earning in Chennai on weekends?
#  24.930000
# What is zero FIR?
#  What is zero FIR in India?
#  35.575200
# Is it true that the higher your IQ is, the more you dream?
#  Is it true that the higher our IQ is, the more we dream?
#  253.440820
# What should be the strategy to prepare for KVPY SA?
#  How do I prepare for KVPY SA?
#  31.435200
# How do I start coding?
#  How should I start coding again?
#  26.234100
# What are the answers to 3.5.8 JavaScript in codehs?
#  What are the answers to codeHS JavaScript?
#  93.691413
# How are HP laptops?
#  What is your review of HP Laptops?
#  1.800000
# Which are the best movies ever?
#  What are all time best movies to watch?
#  3.600000
# How do I "be myself" if I don't even know what that means?
#  How do I know if I know myself completely?
#  65.158200
# What can you take to lose weight fast?
#  What are the best ways to lose weight?
#  29.979000
# Which of the following professions on an average is more financially attractive: a doctor, a lawyer, a chartered accountant or an engineer?
#  Which profession is better a chartered accountant or a solicitor?
#  35.550000
# What were the main causes of World War 1 and what were the consequences for the countries involved?
#  What was the main cause of World War One?
#  58.570200
# Why is the American President Barack Obama called POTUS in Twitter?
#  Will President Obama keep his new Twitter account (@POTUS) after he finishes his term?
#  7.200000
# How should I train and eat to get a body like Alexis Ren?
#  Fitness: How do I get a body like this?
#  20.250000
# How did Donald Trump become such a racist?
#  Do you think Donald Trump is a racist? If so, why?
#  8.820000
# If you could live a life from a movie, which would it be and why?
#  If you could live in a movie, what movie would it be and why?
#  55.827000
# What is a good CNC machine for use at home?
#  Is there an affordable CNC for personal use?
#  9.810000
# What is the difference between a gate and a globe valve?
#  What is the difference between a floating ball valve & a trunnion ball valve? On what basis should I select them?
#  255.328635
# Does changing a manager drastically affect a football team?
#  What exactly is the role of a manager in a football team? How does he affect the team?
#  44.370000
# What is the corporate culture like at Vince.? How is the culture different than other companies?
#  What is the corporate culture like at Netflix? How is the culture different than other companies?
#  55.042200
# How can I get a password when the wifi is already connected?
#  How can I connect with any WiFi without password?
#  62.650890
# Do single mothers prefer dating men with kids than men without kids? Why?
#  Are men in their 20s interested in dating a single mom with two kids? Or do they prefer single women with no kids?
#  73.134000
# For how much money did BJP buy Zee News?
#  How much is Zee news charging for paid news?
#  6.210000
# What it is like to be a Hindu in Pakistan?
#  How does it feel being a hindu living in pakistan?
#  9.720000
# Does India finance terrorism in Afghanistan against Pakistan?
#  Does India finance terrorism in Afghanistan and Pakistan?
#  76.300200
# Which is best among the new aiims?
#  Which AIIMS is better excluding AIIMS of new Delhi?
#  6.300000
# How can I stop pirating media?
#  Should we stop pirating media?
#  27.551790
# What torrent sites are active?
#  Which torrent like websites are active?
#  36.821790
# What are some facts about Indian Currency?
#  What are some interesting facts about Indian currency?
#  89.378443
# How do I learn not to care about what people think of me?
#  How can one stop caring about what people say or think about them?
#  69.046200
# On average, how many web cookies are there per internet user worldwide?
#  How many Twitter users are per country?
#  19.440000
# Is Allah, God only for Muslims?
#  Why do the Muslims think Allah is a God?
#  5.310000
# How can I improve traffic on my website? Www.crazykenyan.com
#  How can I improve my website traffic?
#  69.716880
# How can I acquire traits of light yagami before the death note?
#  What is the differece between Chinese education and?
#  22.050000
# What is the Market Size (Total Revenue) of the Nightlife Industry in Taiwan?
#  What is the Market Size (Total Revenue) of the Nightlife Industry in Japan?
#  200.868840
# How can I stop being nervous around a guy in my class?
#  How can I stop being so nervous around guys I like?
#  86.722470
# How does nearby friends work on Facebook? Does it show the distance by road or by point to point? And how accurate is it?
#  Is it a mistake if you like and comment someone in FB who is not in your friend list?
#  7.200000
# What is the best laptop under INR 30,000?
#  Which is the best laptop to buy under 30k?
#  37.151100
# How do I learn the stock market?
#  How do I learn basics of stock market?
#  71.516880
# How does Paytm work?
#  How does PayTM work? Can one pay for an Auto ride in Delhi with PayTm?
#  56.745990
# What can rest of the world learn from India?
#  What should rest of the world learn from India?
#  60.468300
# What is the difference between a graduate of mechanical engineering and a mechanic?
#  What exactly is the difference between a mechanical engineer and a mechanic?
#  125.369622
# What is the physical meaning of the vertical integral of kinetic energy?
#  What is the significance of the vertically integrated eddy kinetic energy? And how does this compare with the globally integrated form of it?
#  82.493991
# Where can I download all the episodes of Bigg Boss 10?
#  Why has Swami OM gone out of Bigg Boss 10?
#  46.746000
# How do I delete a Quora question?
#  How do I delete my former questions?
#  69.716880
# What are the similarities between Mexican and Indian Food?
#  How come Indian and Mexican cuisines are somewhat similar?
#  20.718000
# What is the QuickBooks installation support phone number?
#  Which is the best QuickBooks proadvisor tech support number?
#  30.041100
# Do you think Mike Pence is secretly trying to pull a Frank Underwood with Trump?
#  I'm to write a descriptive essay on a famous piece of art. Which piece of art should I choose?
#  20.079000
# What other public speakers are like Jason Silva?
#  How can I learn to be a good public speaker?
#  0.900000
# What are some of the uses of silk?
#  What are the uses of silk?
#  96.146091
# Can I go back in time?
#  Can we travel in time?
#  11.259000
# How can I improve my professional resume?
#  What is the best way I can improve my resume?
#  9.720000
# How does making a 10 minute video on YouTube earn you more money than making a shorter video?
#  If I made 10 YouTube videos with an average number of views of 1.5 million, how much money would I make?
#  28.080000
# How can I get Meth out of my system in less than 2 days so I can pass my drug test?
#  How do I get meth out of my system from smoking it instantly?
#  57.550500
# Is there a Mac equivalent of the popular iPhone program MeituXiuxiu (美图秀秀）?
#  Is there a Mac app with similar functions as Moldiv app on iPhone?
#  24.030000
# Which one is better: your rational intellect or the irrational one?
#  Which one is better, your rational intellect or your irrational one?
#  45.659790
# What are the best sites for comparing smartphones?
#  What is the best comparison site for smartphones?
#  30.734100
# What do you want to accomplish before you die?
#  What are the things you want to do before you die?
#  51.902100
# Why does the earth rotate and what happens if it stops rotating?
#  What will happen if the earth stops rotating?
#  40.601790
# Is time travel to 2010 possible?
#  Could time travel be a real thing? Could it be scientifically explained?
#  0.900000
# I am in love with my classmate, I am gay and he's straight, what should I do?
#  I'm gay I feel in love with a straight boy. He is also my friend. What should I do?
#  104.932890
# How do I get over the trauma of a breakup?
#  How do I get over my first break up?
#  92.276271
# What do you think of Quora's BNBR policy?
#  What do you think about Quora Policies?
#  85.359240
# Is it a myth that consuming curd at dinner is bad for your health?
#  What is curd rice?
#  0.900000
# Terminations: Should an employee, not delivering results and given all chances, be surprised when fired?
#  What's the best way to fire an employee?
#  7.920000
# What are the fee structure of top private medical colleges in India (on averag)?
#  What is the average fee in private medical college in india?
#  77.372100
# How can I travel to Sweden?
#  How can I travel to work in Sweden?
#  61.660890
# What are the perks and problems with being physically attractive?
#  What are the advantages and disadvantages of being attractive?
#  154.008569
# What universities does S & T Bank recruit new grads from? What majors are they looking for?
#  What universities does Republic Bank recruit new grads from? What majors are they looking for?
#  121.702833
# What do G, PG, PG-13, R, NC-17 movie ratings mean?
#  Why is The Artist rated PG-13?
#  0.900000
# How much money do countries spend protecting itself from itself?
#  How much does it cost to solve crime and what amount of money has been spent on it?
#  13.410000
# How can I learn advanced Python?
#  How do I learn Python?
#  30.644100
# In the Lord Of The Rings: was Sauron in the form of an 'eye' as shown in the movies or was he in the form of a spirit/ghost?
#  How is Sauron portrayed in The Lord Of The Rings (books)? Is he represented by an eye?
#  89.289000
# What is the minimum marks required to qualify JEE Mains?
#  Is there minimum requirement of 12th marks for qualifying JEE mains 2017?
#  2.700000
# How is silk produced?
#  How is silk manufactured?
#  56.745990
# What are the main characteristic of data processing system?
#  What are the main characteristics of data processing?
#  68.714991
# What are best career options for database administration?
#  Is there any way to join in TCS ITIS and turn up as a database administrator?
#  8.100000
# What is the Leonard Cohen song "Hallelujah" about?
#  Who is Leonard Cohen?
#  23.229000
# How do you prove Rabbe's series test- divergence condition- using the epsilon limit definition?
#  How it feels like having sex with your cousin?
#  5.310000
# How much money do you get for losing a finger?
#  How much do I get for the loss of my pinky finger?
#  65.897190
# Why do we sometimes feel a random shiver down our spine, even when it's not cold, and there's nothing wrong with us?
#  Rubbing plastic against hair generates static electricity. Sometimes even sparks are to be seen. Why then doesn't it lead to a fire when we comb our hair with a plastic comb in the presence of oxygen around us?
#  9.000000
# What makes you proud of your country? Why?
#  What makes you proud of your country?
#  109.454368
# Why am I so hesitant to talk to a woman I like now?
#  Why am I hesitating to talk with girls?
#  51.874200
# How do you make a Nike Swoosh emoji?
#  Has Nike been making sizes smaller for the last 2-3 years?
#  0.900000
# I'm 4 years into my H1B, my GC is not yet started. If I apply GC through consulting company, do I need to join this company before filing I-140/I485?
#  Should I wait for my company to process my GC or should I look for a better job opportunity?
#  12.420000
# What does the phrase "there there" mean?
#  What does the phrase "out there" mean?
#  32.354100
# Can we see normal videos using vr glass?
#  Can I use VR glasses being a spectacled guy?
#  70.016760
# What is the best lens for a Canon EOS 700D, which improves quality and is around $600?
#  Which is the best lens for a Canon 70D?
#  122.322294
# I don't have a proof of address, how do I apply for pan card?
#  How can I apply online for issuance of PAN card in India?
#  81.702000
# What will be the implications of banning 500 and 1000 rupees currency notes on Indian economy?
#  What are the economic implications of banning 500 and 1000 rupee notes?
#  47.403990
# What is the best book or book series you ever read and why?
#  The best book you have ever read?
#  22.950000
# What is your bucket list?
#  What is on your bucket list?
#  22.724100
# Can a 19 year old date a 17 year old?
#  Is it illegal for a 13 year old girl to date a 17 year old guy?
#  60.660000
# Do Muslims appreciate that God, Brahma can be another name for Allah followed by Christianity and Hinduism? Allah is not the only name of God, but different faiths converge on a similar principal of one-all-powerful God?
#  Sikhism: Why to chant the name of god Ram, Allah, Om, Waheguru and so on?
#  32.229000
# How can you maximize sales and productivity?
#  How can I be productive in sales?
#  50.865300
# When do you use reduced integration and incompatible for quad in abacus?
#  What is your opinion on the following poem?
#  14.940000
# What are some of the must watch jai shankar tamil movies?
#  What are some of the good animation movies?
#  42.452100
# Which programming language should I learn Java or python?
#  Which programming language should I learn: Java or JavaScript?
#  96.319080
# How do I know if I am good enough for an MBA?
#  How do I know if I am good enough to be a programmer?
#  146.292625
# What's the difference between cognitive science, nueroscience and psychology?
#  What is the difference between cognitive science and neuroscience?
#  94.916313
# What were the major contributions of the political leaders during WW1, and how are the compared to the ones during the Spanish Succession?
#  What were the major contributions of the political leaders during WW1, and how are the compared to the ones during the Austrian Succession?
#  637.291367
# What is the biggest lie you ever told or heard?
#  What is the biggest lie you have told yourself?
#  100.072593
# Is daily masturbation causes any hair fall?
#  Does excessive masturbation lead to hair loss?
#  8.910000
# What do I need to know about lehigh university?
#  Is Being Egyptian engineer won't give you the chance to work in multinational companies in USA or Europe? Why?
#  37.715400
# What are must do things in college?
#  What are some things that one must positively do while in a college in India or a college in general?
#  43.154100
# What is the healthiest diet book?
#  What is the healthiest diet in the world?
#  51.505200
# How do you calculate pKa from pH?
#  What is the formula for pKa?
#  8.820000
# Do you think PM Modi is afraid of attending the parliament and answering harsh questions after taking such an unplanned move?
#  Why is Modi not attending the Parliament after demonetization?
#  8.010000
# Is it ok if a IT professional works on a freelancing work?
#  Is it legal/ok to run ads on a free phone app based on using someone else's original work?
#  16.920000
# How do you sell cars for profit?
#  What is the best way to sell a car?
#  1.800000
# What are the application of binary search trees?
#  What are the applications of binary search trees?
#  118.954254
# Is it worth working in Malta in San Gwann area, salary after taxes is around 1300 euros as a web developer? (also I'm single)
#  Is it bad to pursue a career in software or web development purely for the salary and work-life balance?
#  53.640000
# What was the status of black people in the Roman Empire?
#  What did the Roman Empire trade?
#  23.624100
# Why isn't there such a thing as negative mass?
#  Can particles have negative mass? If so, what would it mean?
#  7.020000
# What is the weirdest thing you have ever done in an elevator?
#  What is the weirdest thing you've ever done?
#  177.048802
# Which is the most popular database language?
#  Where can I get free Email database for U.S?
#  0.900000
# What options do angels have who invested under a SAFE agreement but then the company turned profitable without further need for series A fundraising?
#  What is the name of the profession who buys a business that has been poorly managed then "fixes" the company and sells it for profit? And what do you have to learn to do this?
#  92.889000
# What is the best way to learn hacking in short time?
#  How can I learn hacking for security purposes?
#  21.699000
# A girl used sex as a tool to get my commitment, knowing I wasn't interested in love and now she makes me feel guilty, what do I do?
#  Do employees at Kohl's have a good work-life balance? Does this differ across positions and departments?
#  8.100000
# What makes a good classical music concert program?
#  Do people in classical music orchestras fart during concerts? Did it ever stop a concert?
#  1.800000
# Should I feel jealous that my boyfriend wants to hang out with a girl alone even though I let him?
#  Is it normal to feel jealous of my ex's new girlfriend even though I'm in a relationship?
#  59.093100
# Why is Hillary Clinton blamed for Benghazi attacks? Is she responsible for the security failure and the deaths?
#  Has Hillary Clinton ever in her life accepted full blame and responsibility for something that went badly?
#  15.930000
# What is the best time to brush your teeth?
#  When is the best time to brush your teeth?
#  90.343243
# What is the proper way to use and dispose of an omamori?
#  What is the proper way to brew Japanese green tea?
#  124.686731
# If the universe is flat how could you see stars above you standing at the top of the world and looking up at night?
#  Is it possible for a person to get directions in desert without a compass at night and if it is by way of the pole star then how do you determine it?
#  258.973290
# What is the one thing you regret doing in your life?
#  What’s your biggest regret in life?
#  36.890100
# What is the selection procedure of Amazon for a Java developer?
#  JavaScript vs Java?
#  0.000000
# What should you gift your brother this Raksha Bandhan?
#  What should you gift your sister this Raksha Bandhan?
#  131.013783
# How can you determine the Lewis structure for NA2O?
#  How can you determine the Lewis structure for formaldehyde?
#  162.757283
# How should I study
#  How can I study more time and more effectively?
#  16.659000
# Is free online cricket betting legal in India?
#  Is online cricket betting legal in India?
#  104.223501
# Why was Diana a princess, and Kate MIddleton a duchess? Both were married to a prince.
#  Parts of a Judaism service?
#  1.800000
# Can we break the speed of light? If so, will it create a light boom? Is there another barrier of speed to break?
#  Speed of Light: How fast can we move?
#  18.828000
# The Bible claims that Mary's father's name was Joachim (יְהוֹיָקִים). The Qur'an calls him Imran (عمران‎‎), not related. Is there a story here?
#  What is the Jewish bible called?
#  0.000000
# How do you get onto Kik at school when the website is blocked?
#  How do I get Kik messenger on your MacBook Pro?
#  59.865300
# Do cats have vaginas?
#  How can I hack someone's WhatsApp account if I just have his WhatsApp account number?
#  5.310000
# What rank is needed to get CSE at IIT Bombay?
#  Urgent! What rank do I need in GATE to get CSE at IIT Bombay?
#  0.000000
# Was the third child of Jane from Jonathan or Stephen Hawking in the movie The Theory of Everything?
#  Is there any movie on Stephen Hawking?
#  63.846000
# What are the skills that I need to be a mechanical engineer?
#  What skills are required for mechanical engineering?
#  18.990000
# What do you think about RBI's new move of banning 500 and 1000 notes?
#  What do you think about banning 500 and 1000 rupee notes in India?
#  105.787980
# What does the word "azam" mean in Urdu?
#  What are the meanings of Hindi and Urdu words Anumati and Ijazat respectively?
#  8.010000
# When will the HTC One E8 get the Android Lollipop update in India?
#  Where is Lollipop for the HTC One E8 India?
#  50.769000
# How is technology changing the culture of Argentina?
#  How does technology change culture?
#  27.134100
# Which is best choice for newbies Honda hornet 160R or Suzuki Gixxer 155?
#  I am looking to buy new bike. Suzuki gixxer 155 or honda hornet 160r. Which one to buy?
#  0.000000
# What are the principles of the US Constitution?
#  What are the four principles of the US Constitution?
#  121.654254
# What is the pixel density (PPI- pixel per inch) of a 40-inch full HD (1920x1080) TV screen?
#  What are the differences between WXGA and HD?
#  43.604100
# What are the best anime that deal with mind games, like Death Note?
#  What are some anime similar to Death Note?
#  57.160890
# What is Raghuram Rajan's view on demonetization?
#  What are the views of Raghuram Rajan on demonetization?
#  52.477200
# If World War III broke out, who would win?
#  How do you think a World War III would play out?
#  15.120000
# What are the best Gujarati books?
#  What are the best books in Gujarati literature?
#  38.275200
# Why do people ask such intimate questions on Quora?
#  Why do people ask such strange questions on Quora?
#  163.187750
# How can you tell if you've been blocked on Facebook Messenger?
#  Can blocked people on Snapchat see my story?
#  8.730000
# How difficult is it to learn ukulele?
#  Is it hard to learn the ukulele?
#  18.099000
# What is the most precise way to draw support and resistance lines for forex trading?
#  What is the quickest way of gaining the skill to illustrate science articles with simple line drawings and sketch graphs?
#  75.634200
# What is the transpose of a matrix ?
#  How do I do a matrix transpose in Go?
#  16.830000
# Why do some people currently believe the earth is flat?
#  Why do some people think Earth is flat?
#  68.778711
# Is it possible to mathematically prove that 1=2?
#  How can we prove 1=2?
#  6.210000
# How can I solve this physics question?
#  Can you please solve this physics question?
#  24.048000
# Would sex be considered a "conjugal duty" in modern China?
#  What is formula for calculating the area of a rectangle?
#  15.840000
# Where is the Baraka River located, and how does it compare to the Amur River?
#  Where is the Baraka River located, and how does it compare to the Ural River?
#  356.365481
# How is Yes bank different from other banks in India and how does it manage to have higher interest rates? Is it safe to have an account in yes bank?
#  Which bank is better between Kotak Mahindra and Yes Bank?
#  14.400000
# Which political party in America had the most slave owners supporting it?
#  What are the list of gadgets given to all ZS Associates Employees?
#  20.790000
# What is the incubation period of a pigeon?
#  What is the gestation period of a giraffe?
#  94.778443
# What are some options for a biology student after class 12th in India?
#  I am a PCM+CS 12th class student. I am interested in Actuarial Science after my 12th. Is it a good field?
#  0.900000
# Which is the most profitable business in India?
#  What are profitable businesses in India?
#  35.603100
# Why do I have to pay to see my credit score and why am I not alerted automatically when there are changes?
#  What are triglycerides composed of?
#  10.800000
# What are the safety precautions on handling shotguns proposed by the NRA in Alaska?
#  What are the safety precautions on handling shotguns proposed by the NRA in Vermont?
#  348.794034
# What's the best way to go about getting an idea patented?
#  If I have an idea for a product, how would I go about patenting it?
#  25.470000
# Where do I go when I sleep?
#  Where do we go when we sleep?
#  124.670584
# Can you see who viewed your Instagram?
#  Who views Instagram?
#  0.900000
# Why is polo only played right handed?
#  Can women play polo?
#  2.610000
# What is the best method of learning to speak a language?
#  What is the best method to learn new language?
#  69.640200
# Which is the best platform to learn online and get knowledge + certification for Digital Marketing or every course in general?
#  What is the best digital marketing course available online and offline in India and Why?
#  59.921100
# Why did China's CCTV disparage SpaceX during recent Chinese rocket launch coverage, by claiming Musk's Mars aspirations were an unfunded pipe dream?
#  What are the salaries at Google in Manhattan like?
#  9.900000
# Why can't I have sex?
#  When can I have sex?
#  23.949000
# What if all of The Bible is true, except Adam and Eve?
#  What is the reason behind Indians not celebrating any festival until an year after demise of a close family member?
#  46.719000
# What are the best ways to get rid of phone addiction?
#  How should I get rid of smartphone addiction?
#  44.406090
# Why did Aurangzeb execute Guru Teg Bahadur?
#  Why did Aurangzeb execute Guru Teg Bahadur, not Shivaji?
#  91.946880
# What are some difference between Obama and Trump's recent reddit AMA's?
#  Is Donald Trump likely to win the 2016 election (late 2015 / early 2016)?
#  2.700000
# How do I convert numpy arrays to MATLAB arrays?
#  Is it possible to export numpy arrays to Matlab?
#  31.797000
# How are servo motors used in robotics?
#  Why are servo motors used in robots?
#  102.769092
# If f(x) = (x^2+x+1) / (2x+7) and g(x) = (x^2+x+1) / (0x^2+2x+7), are they equal?
#  What is x^2+2x+1-9y^2?
#  7.020000
# How can I prepare for Infosys interview?
#  What should I prepare for an Infosys campus interview?
#  37.079100
# What are reasonable explanations for missing work?
#  Which reasons for leaving work are actually completely excusable?
#  6.300000
# How do I find a producer for my music?
#  How do you produce a musical?
#  55.275300
# What are the best free Indian porn websites?
#  What are the best websites to download indian porn videos?
#  38.275200
# What are some fun things to do at a sleepover with just one friend?
#  What are 10 things to do at a sleepover when you're bored?
#  101.293328
# What role did Montesquieu played in the French Revolution?
#  Why did the French Revolution fail?
#  23.940000
# How does the reserve in a petrol tank of a bike work? What actually happens when we switch the knob to reserve?
#  Why are motorcycles so much louder than cars or buses?
#  25.929000
# Will there be a camera better then our eyes?
#  Could a camera ever be better than our eyes?
#  9.720000
# Who are the best Payroll outsourcing services in Delhi NCR?
#  Who are the Payroll outsourcing services in Delhi NCR?
#  95.873771
# Why was the non-samurai guy alive at the end of 13 Assassins?
#  Where was The Last Samurai filmed?
#  19.629000
# What are some of the B schools in India that accept GMAT scores even from domestic/Indian students?
#  Which B schools in India accept Gmat scores from Indian students?
#  48.159000
# Can I apply for internet banking in SBI without visiting the branch?
#  How can I register for net banking SBI without visiting to branch?
#  45.117000
# How can I get a beautiful woman even if I'm not a good looking guy?
#  How do I get a beautiful woman as an ugly guy?
#  51.074100
# What are the advantages of masturbation?
#  What are the advantages if I don't masturbate?
#  29.744100
# How long does nicotine stay in your system? Why?
#  How long does tobacco or nicotine stay in your system?
#  42.856200
# Do 'low tech startups' exist?
#  What are some simple low-tech business to start?
#  0.000000
# What is the easiest way to stop masturbation?
#  What are the best ways to stop or reduce the frequency of masturbation?
#  37.313100
# Has any country other than India ever had Demonetization of their currency notes?
#  Which are the other countries where Tamil find its place in currency notes other than India?
#  29.799000
# Will Lana Del Rey ever have a child?
#  What do you think of Lana Del Rey?
#  13.230000
# What is climate and weather?
#  How is the climate and weather predicted?
#  16.659000
# Can tone-deaf people speak tonal languages (like Mandarin, Cantonese, etc.)?
#  If you can speak Mandarin at a decent level, how hard is it to pick up Cantonese?
#  10.620000
# Will India fight a war against Pakistan?
#  What stops india to declare a war against Pakistan?
#  46.917990
# What are some paradoxes?
#  What is the paradox of increase?
#  21.824100
# What are the examples of the worst feeling ever?
#  What is the worst guilty feel experienced?
#  24.524100
# How does springer nature make money?
#  How much money do Uber drivers make?
#  1.800000
# I'm 24 year old Indian male. My salary is 38K per month. Is it a good salary to earn at that age or is it low?
#  What would tanks be called if the Roman Empire existed to this day?
#  0.000000
# How much bandwidth do I require, if I provide internet packages ranging from 1-25 Mbps with unlimited data and have up to 500 customers?
#  If I order shoes from ebay.com with free international shipping, will I have to pay something to custom duty and if it is then how much?
#  68.660100
# What is the election of President Donald Trump means for the US universities and international students applying to them?
#  What will happen to international students in the US if Donald Trump becomes president?
#  63.314100
# How do I stop getting hungry?
#  How do I not get hungry?
#  27.944100
# What can we do in Tableau?
#  What does epidermal growth factor mean? What are platelets derived growth factors mean?
#  16.290000
# How do I stop my dog from humping my furniture?
#  How do you stop your Boxer/Pitbull mix from humping your furniture?
#  128.590319
# Which are the best books for iit chemistry?
#  What is the best book for physical chemistry for JEE?
#  44.748000
# Which phone is best under 15k?
#  Which is the best phone under 15000 Rs.?
#  8.910000
# What are some good colleges/universities offering MBA in Business Analytics/Data Analytics in India?
#  Is there a college that offers a degree in Business Analytics (or Big Data) and Finance?
#  26.289000
# Why is GST amendment a gamechanger for Indian Economy?
#  How exactly is the proposed GST bill beneficial for our economy?
#  23.400000
# The tone of my face is a lot darker than the rest of the body. How could I improve it?
#  The color tone of my face up to my neck is darker than the color of other parts of my body. Is there any effective medicine/cream I could use, as the difference is marginally high?
#  279.674328
# Can we use solar panels without battery?
#  Can our solar panels be used with other stars?
#  37.899000
# Is pepper spray illegal in China? If so, how can it be sold on Ali Baba?
#  Is it legal to use pepper spray on a police officer for self-defense?
#  16.920000
# Do you prefer to be tickled or to tickle?
#  What is the best way to tickle someone?
#  16.389000
# What will be the consequences of India's surgical strike?
#  What do you think of India’s surgical strikes that took place against terrorists in Pakistan?
#  56.492100
# Will I grow taller after 16?
#  Can I grow taller at 16?
#  85.903911
# What is alphanumeric data entry?
#  What is a good technical approach for data entry?
#  36.475200
# Which location(city) is best to get training in Wipro?
#  How is training for freshers at Wipro?
#  33.263100
# What is the average salary of a CMA in India?
#  Country Comparisons: Why is the average salary in USA much greater than India?
#  78.270300
#  Which person has become billionaire in the shortest time in last 40 years?
#  Which person made a billion in a shortest period of time, and how?
#  92.337300
# What are some things new employees should know going into their first day at Fresh Market?
#  What are some things new employees should know going into their first day at Honeywell?
#  352.016899
# How does one go about reporting the realization that your ex murdered his 1st wife and you're next?
#  How do you deal with the problem that your ex-girlfriend looks much prettier than your wife does?
#  35.873100
# What do you think when Donald Trump is the president of the USA?
#  Should Donald Trump be president of the USA?
#  37.645200
# How did you become an introvert?
#  How do I become an introvert?
#  39.752100
# Has there been at least one Bollywood star who escaped controversies throughout?
#  Is there any one who has assassinated a famous personality and escaped without even being arrested?
#  24.713100
# What are the coolest things to code?
#  What's the coolest thing you own?
#  29.834100
# What is craigslist?
# ...
#  What are some tutorials for building a toothpick bridge?
#  14.130000
# How fucked are we?
#  How do human beings have sex?
#  2.610000
# How do you self publish a book?
#  How can I publish my own book?
#  28.034100
# Why do political terms last 4 years and where does this idea come from?
#  For the institutional design folks: In the US lower house, reps have two year terms. What would likely result from extending them to 3 yr terms?
#  0.900000
# What song plays over the end credits to the 2002 movie The Eye?
#  What song plays over the end credits to the 2002 movie Spun?
#  160.674735
# How much charge of electrons is equal to 1.6×10^-19 C.
#  How tough is the life at IIM?
#  10.710000
# Is reading the Game of Thrones books better than watching the TV series?
#  What are the 10 most appealing features of "The Game Of Thrones"? What makes this TV series a must watch?
#  17.640000
# How can I improve my story writing skills?
#  How should I improve my writing skill for blogging?
#  66.621780
# How can we disconnect other users from my Wifi without telling them.?
#  Sometimes I get disconnected from my wifi on my iPhone and I can't tell. Is there an app that will let me know easily if I'm still connected?
#  12.510000
# How do I prepare for an exam in a day?
#  How can I prepare for exam in few days?
#  57.473100
# What is the geography of the Canadian Shield?
#  What are the landforms of the Canadian Shield?
#  68.639400
# Is eating bananas (or even banana shake) good for health or not?
#  Is eating bananas/banana shake good for health or not?
#  11.259000
# What is the reason behind the sudden discontinuance of 500 and 1000 notes by PM Modi?
#  Why are 500 and 1000 notes being banned in India?
#  36.549000
# Where does one purchase electronic components?
#  Where can I purchase electronic components on line?
#  5.310000
# How do you find your health insurance policy number?
#  How do you find your Health First policy number?
#  69.716880
# How can you determine which way a tree will fall?
#  In what way can you transplant aspen trees?
#  20.169000
# Why do planets rotate around itself?
#  How do the planets rotate?
#  45.575100
# How old are the stars of "The Big Bang Theory?"
#  Has The Big Bang Theory (TV show) ended?
#  1.800000
# Do plants grow in Antarctica?
#  If it is discovered somewhere in the future that the ice caps in Greenland and Antarctica are growing, what can we do to insure a renewable future?
#  14.130000
# How dangerous is a black snake with a yellow ring around its head?
#  Why do some people have the urge to eat every hour?
#  0.900000
# How was the International Space Station built?
#  How was international space station made?
#  49.965300
# Can allo app ever outrun WhatsApp? Why or why not?
#  How is Google Allo better than WhatsApp?
#  4.410000
# How do I increase brain processing speed?
#  How can I increase my brain's processing speed and efficiency?
#  29.744100
# What are the best horror novel in 2016?
#  What are some of the best horror novels?
#  64.497960
# Are ecommerce sites in India providing better value compared to brick and mortar stores 10 years back?
#  What time of year is it best to visit New Caledonia?
#  6.300000
# •What are the greatest threats to public health worldwide?
#  What are the greatest threats to public health worldwide?
#  87.247980
# What are some objections to utilitarianism?
#  What are the main drawbacks of utilitarianism?
#  49.665600
# How will the ban on 500₹ and 1000₹ notes impact the Indian economy?
#  How does the ban on 500/1000 denominations affect various domains of the Indian economy?
#  63.224100
# When and why did the tradition begin of Olympians biting their medals in a photo op?
#  What are the popular cups and trophies?
#  0.900000
# What is the typical starting salary for someone with an undergraduate degree in theology?
#  What is the typical starting salary for someone with an undergraduate degree in aviation?
#  401.766162
# How do I become mentally strong?
#  How do I become a mentally strong woman?
#  61.570890
# Is it good to do CCNA before MCSE?
#  Is a CCNA Certification enough to get a good job for a fresher?
#  16.479000
# How can I get rid of this?
#  How can we get rid of studies?
#  106.554133
# How is the word 'probity' used in a sentence?
#  How is the word 'although' used in a sentence?
#  67.479300
# What emotions are experienced by an unmarried Muslimah from an orthodox family when she gets naked first time with a guy?
#  What emotions are experienced by an unmarried Muslim girl, from an orthodox family, when she is being undressed for her first time sex?
#  136.580400
# Can we use hair gel for beard?
#  Does hair gel make the hair white?
#  10.620000
# Do "vampire facelifts" work as advertised?
#  How much is the cost of a facelift?
#  0.000000
# A light ray bends towards normal when it travels from rarer median to denser medium. Why not away from normal?
#  Why does light not bend when it passes through a flat glass slab normally?
#  58.837500
# In the case of a zombie apocalypse, which 3 Quorans would you want on your team, and why?
#  If you woke up during a Zombie Apocalypse, which five Quora members would you want in your crew and why?
#  43.029000
# How are space rockets steered?
#  What are the Propellants in space rockets?
#  8.820000
# When you got started as agent, how did you begin to form relationships with college and AAU coaches?
#  Chamath Palihapitiya: If you go back in time to when you started as an entrepreneur, how much did your startup location (city\country) affect your success and growth?
#  67.283100
# What are the most important things to learn?
#  What are some interesting things to learn?
#  89.504338
# Is 16.5 cm dick length considered to be small?
#  What's the average size of an adult human penis? Does the average vary among people from different continents or ethnic groups?
#  0.000000
# How can I learn grammar effectively?
#  How do I learn grammar quickly?
#  40.103100
# I found a fabric used for tents that is commonly known as reliance in the market, can someone let me know the details and composition of this material?
#  As most of us know, same cosmetic brands have absolutely different qualities for the domestic market and for the export markets. Where can I buy usual daily use, skin and hair care products online that are not manufactured in India?
#  90.819000
# What are the amazing facts about India?
#  What are some incredible facts about india?
#  103.402332
# How do I raise money for a real estate development?
#  How do real estate developers raise capital?
#  49.570200
# Will Apple ever move away from the iPhone?
#  Can I move my SIM card from one iPhone 4S to another?
#  34.470000
# What are the merits and demerits of GST implementation in INDIA?
#  What is the merits and Demerits of GST in India?
#  103.049100
# Can you schedule an Uber ahead of time? How do you do this? Can I set the pickup time in advance?
#  Is there an app like Uber or Lyft where you can schedule a pickup?
#  9.810000
# How do you inflate a car tire with a bike pump?
#  How much does it cost to get new bike tires?
#  18.990000
# Can I grow taller at 16?
#  How can I grow taller at 17?
#  28.287000
# How do I get advertisers for my website?
#  What can I do for online advertisements of my website?
#  12.420000
# What are the differences between bootstrap and angular.js?
#  Why should I use Angular.js?
#  0.900000
# What was Ultra during WW2?
#  Who was the best human during WW2?
#  24.939000
# Do Americans wear outdoor-shoes inside their homes as portrayed in tellies/movies? Don’t they maintain indoor slippers/shoes like Asians or others?
#  Can we wear sports shoes with jeans?
#  9.000000
# Is Quora only for intelligent people?
#  Is this site Quora only for the very intelligent?
#  72.704790
# Do employees at Cooper have a good work-life balance? Does this differ across positions and departments?
#  Do employees at Cooper Tire & Rubber have a good work-life balance? Does this differ across positions and departments?
#  106.764192
# Why do I hate working?
#  Why do I hate work?
#  54.550890
# What do you plan on doing with the Syrian Refugees crisis?
#  What is going on in Syrian refugee crisis?
#  28.124100
# D. To be able to gQuestions .Can anyone answer me in a brief and concise manner for these brief status Quo?
#  How do I expand the LHS with the Taylor expansions up to the second term?
#  5.310000
# Which unique commodities did Europeans trade on the Silk Road?
#  In the age of the Silk Road and spice trade, what did Europeans have to offer in exchange for Eastern products?
#  34.380000
# Why don't Israel and Palestine unite?
#  Why can't Israel and Palestine join in a federation?
#  14.220000
# What's it like having many siblings?
#  What's it like to have siblings?
#  28.034100
# What is the best documentary on George H. W. Bush?
#  What is the best documentary on George W. Bush?
#  176.526750
# What are the best restaurants to try when visiting Yong'an, Fujian, China? What should you try while you're there?
#  What are the best restaurants to try when visiting Longhai, Fujian, China? What should you try while you're there?
#  66.080790
# What is a suitable solar panel installation provider near Somis, California CA?
#  What is a suitable solar panel installation provider near Pacoima, California CA?
#  366.493484
# How can you increase your height?
#  How do I increase my height after 16?
#  23.624100
# Is monarchy in the UK against the democratic principals?
#  Why has the UK retained the monarchy?
#  10.620000
# How accurate are Nostradamus's predictions?
#  How did Nostradamus make so many accurate predictions?
#  2.700000
# What is the difference between the heart and the brain?
#  Does the brain control the heart?
#  35.280000
# What are some examples of moral standards?
#  What are "moral standards"?
#  41.695200
# How banning 500 and 1000 rs note will help fight corruption in India?
#  Would demonetization of 500 and 1000 rupee notes actually help in curbing black money in India?
#  26.469000
# How do you treat a blood blister on a dog?
#  How can you treat a blood blister on a dog?
#  96.396300
# What is digital rights management?
#  What are some digital rights management errors?
#  24.524100
# What is the difference between critical care and intensive care?
#  Critical Care: ICU Discussions. Let's share our clinical dilemmas we are facing as intensivists in our daily ICU rounds?
#  7.200000
# How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Kalahari Desert?
#  How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Karakum Desert?
#  464.359235
# What are some ways to get rid of man boob's naturally?
#  How can I get rid of man boobs?
#  29.240100
# Do any economists believe $15/HR minimum wage would be good?
#  How can small businesses survive with a minimum wage of $15/hr?
#  1.800000
# New fashion for men?
#  How did the chemistry students, teachers and readers memorize what was needed for high grades?
#  7.110000
# Company wants me to resign without serving the notice period.But I need it badly as I do not have a job and want to sustain myself.What should I do?
#  What is the use of text line segmentation?
#  16.110000
# What does love look like to you?
#  What does love look like?
#  83.809701
# What is your definition of "Civilization"?
#  What is the definition of civilization?
#  66.014991
# How do prepare for IAS for a fresher?
#  How should I prepare for IAS now?
#  17.640000
# Why do beggars never lose hair?
#  Had fight w/bf over his dead g/f?
#  0.900000
# What are some reasons people don't believe in climate change?
#  Why are so many people denying climate change?
#  8.820000
# Can you make 50,000 a month playing poker?
#  Can I make 40,000 a month playing poker?
#  141.819378
# What are examples of long-term goals?
#  What are some examples of some long-term goals?
#  66.914991
# If Donald Trump wins, how would it affect India?
#  How will Trump's victory affect India?
#  27.413100
# Why are dogs considered omnivores?
#  Are dogs carnivorous animals?
#  0.900000
# What are thriller novels known for?
#  What are thriller novels?
#  29.744100
# What evidence do you have that God exists or doesn't exist?
#  What evidence do we have that God doesn't exist?
#  80.546400
# What are advantages of drinking warm water with lemon and honey in the morning?
#  What are the advantages of drinking warm lemon water?
#  68.273100
# Why does 100mm cube and 150mm cube has the same compressive strength?
#  How do l calculate compressive strength of a cube in mpa?
#  25.929000
# How do we implement values in society?
#  Does modern society have misplaced values and if so then, why?
#  2.700000
# Where can I get playstation 4 and its games on rent in Pune?
#  Where can I get playstation 4 and its games on rent?
#  118.387980
# What is exactly is a firewall?
#  What is a firewall?
#  30.644100
# What is the best media player for Windows to play HEVC files? Is it VLC?
#  Can VLC media player run .srt files?
#  1.800000
# Is Hillary Clinton any more corrupt than an average politician?
#  Why do people think Hillary Clinton is corrupt?
#  7.920000
# What is the free period in NDA lingo called?
#  Is there any big difference between software analysis and manual analysis in building design?
#  38.709000
# Why do some people hate Apple products?
#  Why do people hate Apple?
#  48.670200
# My roommate snores a lot. What can I do?
#  What can I do if my roommate snores?
#  0.900000
# What is the font used for the Pinterest logo?
#  What font is used in the NOCCO logo?
#  59.281200
# Do you think Tywin knew about Cersei and Jaime all along?
#  Did Tywin know about Jaime and Cersei?
#  24.210000
# How does it feel to be an entrepreneur and an employee?
#  How does it feel to be an entrepreneur?
#  131.203029
# What is capitalist reform?
#  Who is the greatest capitalist of all time?
#  31.580100
# What are some examples of friction in everyday life?
#  What are the best life hacks with everyday objects?
#  84.530520
# How do I start preparation for MBA 2017?
#  How do I start preparing for MBA?
#  60.760890
# How do I end our relationship?
#  What is the best way to end a relationship?
#  6.210000
# Is Physical intimacy necessary in true love?
#  Does true love require physical intimacy? Why or why not?
#  20.430000
# Is Doing Diploma in Nautical science is necessary before joining IMU?
#  Is it necessary to do a diploma in nautical science before joining IMU?
#  47.450790
# What is the difference between the left wing and the right wing? What is the difference on a basic level & on a hardcore politician level?
#  Is it true that Yahoo! Answers is right-wing and Quora is left-wing?
#  1.800000
# What are the best books of all time?
#  Which books are worth reading?
#  18.090000
# If my parents make $150,000 a year but aren't willing to help me pay for college, how can I qualify for financial aid?
#  This year's will be my 2nd shot at AIPMT and I'm confident of qualifying but how do I convince my dad to give me another chance for a better college?
#  56.349000
# How do I connect my Clash Royale on Android to my Clash Royale on Ipad?
#  What is the most efficient way to play Clash Royale?
#  5.400000
# Do you think BJP can finally come into power in UP in 2017? If yes, how and who should should be its CM candidate against Akhilesh and Mayawati?
#  Who will most probably be the BJP's CM candidate in the UP elections?
#  24.120000
# What are career opportunities in companies after an M.Tech in production engineering with a B.Tech in mechanical engineering?
#  Which course after b.tech in mechanical engineering suits best?
#  93.247200
# Is time an illusion? What do they mean by this?
#  How is time an illusion?
#  9.630000
# What is diffrent between computer science and computer engenearing?
#  What is the diffrence between computer science and computer engineering?
#  97.923600
# Why can't I catch a Pokémon in Pokémon GO?
#  Where can I catch a Rhydon in Pokémon GO?
#  47.240100
# Why isn't financial independents taught in school?
#  What can an Indian citizen do today that would most contribute to improve the lives of his or her countrymen?
#  5.400000
# How do you work on your neuroplasticity?
#  What is the importance of neuroplasticity?
#  4.500000
