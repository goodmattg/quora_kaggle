# %%
import pandas as pd
import numpy as np
from pycorenlp import StanfordCoreNLP 
import re, time, bisect, math
import TreeKernel as tk
import TreeBuild as tb

# %%
from gensim.models.keyedvectors import KeyedVectors
word_vectors = KeyedVectors.load_word2vec_format('./w2v_model/GoogleNews-vectors-negative300.bin', binary=True)  # C binary format

# %%
nlp = StanfordCoreNLP('http://localhost:9000')

# %%
def _getNLPToks_(rawSentence):
    output = nlp.annotate(rawSentence, properties={
      'annotators': 'tokenize,ssplit,pos,parse',
      'outputFormat': 'json'
      })
    return output['sentences'][0]['parse'].split("\n")

# %%
def _w2vSimilarity_(word1, word2, modelPtr):
    return modelPtr.similarity(word1, word2)

# %% [markdown]
# ## Test: Tree Generation and Collins-Duffy Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tb.tree()
tree_b2 = tb.tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
tb._generateTree_(toks_b1, tree_b1)
tb._generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
tb._flipTree_(tree_b1)
tb._flipTree_(tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = tk._CollinsDuffy_(tree_b1, tree_b2, 0.8, 1, 0)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel

print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# {'sentences': [{'enhancedDependencies': [{'dep': 'ROOT', 'dependent': 4, 'governor': 0, 'dependentGloss': 'enjoy', 'governorGloss': 'ROOT'}, {'dep': 'advmod', 'dependent': 1, 'governor': 4, 'dependentGloss': 'Why', 'governorGloss': 'enjoy'}, {'dep': 'aux', 'dependent': 2, 'governor': 4, 'dependentGloss': 'do', 'governorGloss': 'enjoy'}, {'dep': 'nsubj', 'dependent': 3, 'governor': 4, 'dependentGloss': 'we', 'governorGloss': 'enjoy'}, {'dep': 'dobj', 'dependent': 5, 'governor': 4, 'dependentGloss': 'parties', 'governorGloss': 'enjoy'}, {'dep': 'case', 'dependent': 6, 'governor': 8, 'dependentGloss': 'in', 'governorGloss': 'scope'}, {'dep': 'det', 'dependent': 7, 'governor': 8, 'dependentGloss': 'the', 'governorGloss': 'scope'}, {'dep': 'nmod:in', 'dependent': 8, 'governor': 4, 'dependentGloss': 'scope', 'governorGloss': 'enjoy'}, {'dep': 'case', 'dependent': 9, 'governor': 11, 'dependentGloss': 'of', 'governorGloss': 'universe'}, {'dep': 'det', 'dependent': 10, 'governor': 11, 'dependentGloss': 'the', 'governorGloss': 'universe'}, {'dep': 'nmod:of', 'dependent': 11, 'governor': 8, 'dependentGloss': 'universe', 'governorGloss': 'scope'}], 'basicDependencies': [{'dep': 'ROOT', 'dependent': 4, 'governor': 0, 'dependentGloss': 'enjoy', 'governorGloss': 'ROOT'}, {'dep': 'advmod', 'dependent': 1, 'governor': 4, 'dependentGloss': 'Why', 'governorGloss': 'enjoy'}, {'dep': 'aux', 'dependent': 2, 'governor': 4, 'dependentGloss': 'do', 'governorGloss': 'enjoy'}, {'dep': 'nsubj', 'dependent': 3, 'governor': 4, 'dependentGloss': 'we', 'governorGloss': 'enjoy'}, {'dep': 'dobj', 'dependent': 5, 'governor': 4, 'dependentGloss': 'parties', 'governorGloss': 'enjoy'}, {'dep': 'case', 'dependent': 6, 'governor': 8, 'dependentGloss': 'in', 'governorGloss': 'scope'}, {'dep': 'det', 'dependent': 7, 'governor': 8, 'dependentGloss': 'the', 'governorGloss': 'scope'}, {'dep': 'nmod', 'dependent': 8, 'governor': 4, 'dependentGloss': 'scope', 'governorGloss': 'enjoy'}, {'dep': 'case', 'dependent': 9, 'governor': 11, 'dependentGloss': 'of', 'governorGloss': 'universe'}, {'dep': 'det', 'dependent': 10, 'governor': 11, 'dependentGloss': 'the', 'governorGloss': 'universe'}, {'dep': 'nmod', 'dependent': 11, 'governor': 8, 'dependentGloss': 'universe', 'governorGloss': 'scope'}], 'enhancedPlusPlusDependencies': [{'dep': 'ROOT', 'dependent': 4, 'governor': 0, 'dependentGloss': 'enjoy', 'governorGloss': 'ROOT'}, {'dep': 'advmod', 'dependent': 1, 'governor': 4, 'dependentGloss': 'Why', 'governorGloss': 'enjoy'}, {'dep': 'aux', 'dependent': 2, 'governor': 4, 'dependentGloss': 'do', 'governorGloss': 'enjoy'}, {'dep': 'nsubj', 'dependent': 3, 'governor': 4, 'dependentGloss': 'we', 'governorGloss': 'enjoy'}, {'dep': 'dobj', 'dependent': 5, 'governor': 4, 'dependentGloss': 'parties', 'governorGloss': 'enjoy'}, {'dep': 'case', 'dependent': 6, 'governor': 8, 'dependentGloss': 'in', 'governorGloss': 'scope'}, {'dep': 'det', 'dependent': 7, 'governor': 8, 'dependentGloss': 'the', 'governorGloss': 'scope'}, {'dep': 'nmod:in', 'dependent': 8, 'governor': 4, 'dependentGloss': 'scope', 'governorGloss': 'enjoy'}, {'dep': 'case', 'dependent': 9, 'governor': 11, 'dependentGloss': 'of', 'governorGloss': 'universe'}, {'dep': 'det', 'dependent': 10, 'governor': 11, 'dependentGloss': 'the', 'governorGloss': 'universe'}, {'dep': 'nmod:of', 'dependent': 11, 'governor': 8, 'dependentGloss': 'universe', 'governorGloss': 'scope'}], 'index': 0, 'tokens': [{'after': ' ', 'before': '', 'word': 'Why', 'index': 1, 'characterOffsetEnd': 3, 'characterOffsetBegin': 0, 'originalText': 'Why', 'pos': 'WRB'}, {'after': ' ', 'before': ' ', 'word': 'do', 'index': 2, 'characterOffsetEnd': 6, 'characterOffsetBegin': 4, 'originalText': 'do', 'pos': 'VBP'}, {'after': ' ', 'before': ' ', 'word': 'we', 'index': 3, 'characterOffsetEnd': 9, 'characterOffsetBegin': 7, 'originalText': 'we', 'pos': 'PRP'}, {'after': ' ', 'before': ' ', 'word': 'enjoy', 'index': 4, 'characterOffsetEnd': 15, 'characterOffsetBegin':  ...
# {'sentences': [{'enhancedDependencies': [{'dep': 'ROOT', 'dependent': 1, 'governor': 0, 'dependentGloss': 'What', 'governorGloss': 'ROOT'}, {'dep': 'cop', 'dependent': 2, 'governor': 1, 'dependentGloss': 'are', 'governorGloss': 'What'}, {'dep': 'compound', 'dependent': 3, 'governor': 4, 'dependentGloss': 'college', 'governorGloss': 'parties'}, {'dep': 'nsubj', 'dependent': 4, 'governor': 1, 'dependentGloss': 'parties', 'governorGloss': 'What'}, {'dep': 'dep', 'dependent': 5, 'governor': 1, 'dependentGloss': 'like', 'governorGloss': 'What'}, {'dep': 'punct', 'dependent': 6, 'governor': 1, 'dependentGloss': '?', 'governorGloss': 'What'}], 'basicDependencies': [{'dep': 'ROOT', 'dependent': 1, 'governor': 0, 'dependentGloss': 'What', 'governorGloss': 'ROOT'}, {'dep': 'cop', 'dependent': 2, 'governor': 1, 'dependentGloss': 'are', 'governorGloss': 'What'}, {'dep': 'compound', 'dependent': 3, 'governor': 4, 'dependentGloss': 'college', 'governorGloss': 'parties'}, {'dep': 'nsubj', 'dependent': 4, 'governor': 1, 'dependentGloss': 'parties', 'governorGloss': 'What'}, {'dep': 'dep', 'dependent': 5, 'governor': 1, 'dependentGloss': 'like', 'governorGloss': 'What'}, {'dep': 'punct', 'dependent': 6, 'governor': 1, 'dependentGloss': '?', 'governorGloss': 'What'}], 'enhancedPlusPlusDependencies': [{'dep': 'ROOT', 'dependent': 1, 'governor': 0, 'dependentGloss': 'What', 'governorGloss': 'ROOT'}, {'dep': 'cop', 'dependent': 2, 'governor': 1, 'dependentGloss': 'are', 'governorGloss': 'What'}, {'dep': 'compound', 'dependent': 3, 'governor': 4, 'dependentGloss': 'college', 'governorGloss': 'parties'}, {'dep': 'nsubj', 'dependent': 4, 'governor': 1, 'dependentGloss': 'parties', 'governorGloss': 'What'}, {'dep': 'dep', 'dependent': 5, 'governor': 1, 'dependentGloss': 'like', 'governorGloss': 'What'}, {'dep': 'punct', 'dependent': 6, 'governor': 1, 'dependentGloss': '?', 'governorGloss': 'What'}], 'index': 0, 'tokens': [{'after': ' ', 'before': '', 'word': 'What', 'index': 1, 'characterOffsetEnd': 4, 'characterOffsetBegin': 0, 'originalText': 'What', 'pos': 'WP'}, {'after': ' ', 'before': ' ', 'word': 'are', 'index': 2, 'characterOffsetEnd': 8, 'characterOffsetBegin': 5, 'originalText': 'are', 'pos': 'VBP'}, {'after': ' ', 'before': ' ', 'word': 'college', 'index': 3, 'characterOffsetEnd': 16, 'characterOffsetBegin': 9, 'originalText': 'college', 'pos': 'NN'}, {'after': ' ', 'before': ' ', 'word': 'parties', 'index': 4, 'characterOffsetEnd': 24, 'characterOffsetBegin': 17, 'originalText': 'parties', 'pos': 'NNS'}, {'after': '', 'before': ' ', 'word': 'like', 'index': 5, 'characterOffsetEnd': 29, 'characterOffsetBegin': 25, 'originalText': 'like', 'pos': 'IN'}, {'after': '', 'before': '', 'word': '?', 'index': 6, 'characterOffsetEnd': 30, 'characterOffsetBegin': 29, 'originalText': '?', 'pos': '.'}], 'parse': '(ROOT\n  (SBARQ\n    (WHNP (WP What))\n    (SQ (VBP are)\n      (NP (NN college) (NNS parties))\n      (PP (IN like)))\n    (. ?)))'}]}
# --- 0.07062005996704102 seconds ---
# --- 0.0708761215209961 seconds ---
# --- 0.07101607322692871 seconds ---
# --- 0.0733189582824707 seconds ---
# Raw Score: 0.8
# Norm Score: 0.124034734589

# %% [markdown]
# ## Test: Tree Generation and Moschitti PT Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tb.tree()
tree_b2 = tb.tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
tb._generateTree_(toks_b1, tree_b1)
tb._generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
tb._flipTree_(tree_b1)
tb._flipTree_(tree_b2)

for i in tree_b1.items():
    print(i)
    
print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = tk._MoschittiPT_(tree_b1, tree_b2, 0.8, 0.4, 1)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel

print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# --- 0.04182696342468262 seconds ---
# --- 0.042407989501953125 seconds ---
# (0, {'indent': 0, 'curid': 0, 'childrenTok': 'SBARQ', 'parid': -1, 'posOrTok': 'ROOT', 'children': [1]})
# (1, {'indent': 2, 'curid': 1, 'childrenTok': ['WHADVP', 'SQ'], 'parid': 0, 'posOrTok': 'SBARQ', 'children': [2, 5]})
# (2, {'indent': 4, 'curid': 2, 'childrenTok': ['WRB'], 'parid': 1, 'posOrTok': 'WHADVP', 'children': [3]})
# (3, {'indent': 6, 'curid': 3, 'childrenTok': ['Why'], 'parid': 2, 'posOrTok': 'WRB', 'children': [4]})
# (4, {'indent': 6, 'curid': 4, 'childrenTok': [], 'parid': 3, 'posOrTok': 'Why', 'children': []})
# (5, {'indent': 4, 'curid': 5, 'childrenTok': ['VBP', 'NP', 'VP'], 'parid': 1, 'posOrTok': 'SQ', 'children': [6, 8, 11]})
# (6, {'indent': 6, 'curid': 6, 'childrenTok': ['do'], 'parid': 5, 'posOrTok': 'VBP', 'children': [7]})
# (7, {'indent': 6, 'curid': 7, 'childrenTok': [], 'parid': 6, 'posOrTok': 'do', 'children': []})
# (8, {'indent': 6, 'curid': 8, 'childrenTok': ['PRP'], 'parid': 5, 'posOrTok': 'NP', 'children': [9]})
# (9, {'indent': 8, 'curid': 9, 'childrenTok': ['we'], 'parid': 8, 'posOrTok': 'PRP', 'children': [10]})
# (10, {'indent': 8, 'curid': 10, 'childrenTok': [], 'parid': 9, 'posOrTok': 'we', 'children': []})
# (11, {'indent': 6, 'curid': 11, 'childrenTok': ['VB', 'NP', 'PP'], 'parid': 5, 'posOrTok': 'VP', 'children': [12, 14, 17]})
# (12, {'indent': 8, 'curid': 12, 'childrenTok': ['enjoy'], 'parid': 11, 'posOrTok': 'VB', 'children': [13]})
# (13, {'indent': 8, 'curid': 13, 'childrenTok': [], 'parid': 12, 'posOrTok': 'enjoy', 'children': []})
# (14, {'indent': 8, 'curid': 14, 'childrenTok': ['NNS'], 'parid': 11, 'posOrTok': 'NP', 'children': [15]})
# (15, {'indent': 10, 'curid': 15, 'childrenTok': ['parties'], 'parid': 14, 'posOrTok': 'NNS', 'children': [16]})
# (16, {'indent': 10, 'curid': 16, 'childrenTok': [], 'parid': 15, 'posOrTok': 'parties', 'children': []})
# (17, {'indent': 8, 'curid': 17, 'childrenTok': ['IN', 'NP'], 'parid': 11, 'posOrTok': 'PP', 'children': [18, 20]})
# (18, {'indent': 10, 'curid': 18, 'childrenTok': ['in'], 'parid': 17, 'posOrTok': 'IN', 'children': [19]})
# (19, {'indent': 10, 'curid': 19, 'childrenTok': [], 'parid': 18, 'posOrTok': 'in', 'children': []})
# (20, {'indent': 10, 'curid': 20, 'childrenTok': ['NP', 'PP'], 'parid': 17, 'posOrTok': 'NP', 'children': [21, 26]})
# (21, {'indent': 12, 'curid': 21, 'childrenTok': ['DT', 'NN'], 'parid': 20, 'posOrTok': 'NP', 'children': [22, 24]})
# (22, {'indent': 14, 'curid': 22, 'childrenTok': ['the'], 'parid': 21, 'posOrTok': 'DT', 'children': [23]})
# (23, {'indent': 14, 'curid': 23, 'childrenTok': [], 'parid': 22, 'posOrTok': 'the', 'children': []})
# (24, {'indent': 14, 'curid': 24, 'childrenTok': ['scope'], 'parid': 21, 'posOrTok': 'NN', 'children': [25]})
# (25, {'indent': 14, 'curid': 25, 'childrenTok': [], 'parid': 24, 'posOrTok': 'scope', 'children': []})
# (26, {'indent': 12, 'curid': 26, 'childrenTok': ['IN', 'NP'], 'parid': 20, 'posOrTok': 'PP', 'children': [27, 29]})
# (27, {'indent': 14, 'curid': 27, 'childrenTok': ['of'], 'parid': 26, 'posOrTok': 'IN', 'children': [28]})
# (28, {'indent': 14, 'curid': 28, 'childrenTok': [], 'parid': 27, 'posOrTok': 'of', 'children': []})
# (29, {'indent': 14, 'curid': 29, 'childrenTok': ['DT', 'NN'], 'parid': 26, 'posOrTok': 'NP', 'children': [30, 32]})
# (30, {'indent': 16, 'curid': 30, 'childrenTok': ['the'], 'parid': 29, 'posOrTok': 'DT', 'children': [31]})
# (31, {'indent': 16, 'curid': 31, 'childrenTok': [], 'parid': 30, 'posOrTok': 'the', 'children': []})
# (32, {'indent': 16, 'curid': 32, 'childrenTok': ['universe'], 'parid': 29, 'posOrTok': 'NN', 'children': [33]})
# (33, {'indent': 16, 'curid': 33, 'childrenTok': [], 'parid': 32, 'posOrTok': 'universe', 'children': []})
# --- 0.04301595687866211 seconds ---
# --- 0.04678487777709961 seconds ---
# Raw Score: 3.36
# Norm Score: 0.326722528894

# %% [markdown]
# ## Test: Tree Kernels on Training Data

# %%
from random import randint

def read_data(path_to_file):
    df = pd.read_csv(path_to_file)
    print ("Shape of base training File = ", df.shape)
    # Remove missing values and duplicates from training data
    df.drop_duplicates(inplace=True)
    df.dropna(inplace=True)
    print("Shape of base training data after cleaning = ", df.shape)
    return df

df_train = read_data("input/train.csv")
# Out:
# Shape of base training File =  (404290, 6)
# Shape of base training data after cleaning =  (404288, 6)

# %%
## SET UP TEST INDICES TO SELECT RANDOM ROWS

TEST_SAMPLES = 100
indices = np.arange(TEST_SAMPLES)
for i in range(len(indices)):
    indices[i] = randint(0,df_train.shape[0])

# %%
for ind in indices:
    
    tree_1 = tb.tree()
    tree_2 = tb.tree()

    toks_1 = _getNLPToks_(df_train.get_value(ind,'question1'))
    toks_2 = _getNLPToks_(df_train.get_value(ind,'question2'))

    # Generate a tree structure
    tb._generateTree_(toks_1, tree_1)
    tb._generateTree_(toks_2, tree_2)

    # Flip the trees
    tb._flipTree_(tree_1)
    tb._flipTree_(tree_2)

    (scoreRaw_cd, scoreNorm_cd) = tk._CollinsDuffy_(tree_1, tree_2, 0.8, 1, 1)
    (scoreRaw_pt, scoreNorm_pt) = tk._MoschittiPT_(tree_1, tree_2, 0.8, 0.4, 1)
    print("%s\n%s" % (df_train.get_value(ind,'question1'), df_train.get_value(ind,'question2')))
    print("Collins-Duffy | Norm: %f | Raw: %f" % (scoreNorm_cd, scoreRaw_cd))
    print("Moschitti | Norm: %f | Raw: %f\n" % (scoreNorm_pt, scoreRaw_pt))
# Out:
# Why does one bake a cake?
# How do I bake a cake without an oven?
# Collins-Duffy | Norm: 0.408248 | Raw: 2.400000
# Moschitti | Norm: 0.588981 | Raw: 5.216000
#
# What are some of the coolest "facts" about the Marvel/DC universe and characters?
# What are some mind blowing facts about DC comics?
# Collins-Duffy | Norm: 0.445435 | Raw: 4.000000
# Moschitti | Norm: 0.704011 | Raw: 13.728000
#
# Can a man lose his virginity by masturbating? If yes how?
# How did you lose your virginity as a man?
# Collins-Duffy | Norm: 0.462910 | Raw: 2.400000
# Moschitti | Norm: 0.550585 | Raw: 4.192000
#
# What is the best way to turn off my iPod touch?
# How do you turn off an iPod?
# Collins-Duffy | Norm: 0.267261 | Raw: 1.600000
# Moschitti | Norm: 0.460889 | Raw: 4.160000
#
# What are some mind blowing technology tools that most people don't know?
# What are some mind-blowing inventions tools that most people don't know about?
# Collins-Duffy | Norm: 0.789352 | Raw: 7.200000
# Moschitti | Norm: 0.853602 | Raw: 12.576000
#
# What are examples of communication software?
# What are some examples of communication software?
# Collins-Duffy | Norm: 0.925820 | Raw: 4.800000
# Moschitti | Norm: 0.955454 | Raw: 8.384000
#
# What are the safety precautions on handling shotguns proposed by the NRA in Kentucky?
# What are the safety precautions on handling shotguns proposed by the NRA in Pennsylvania?
# Collins-Duffy | Norm: 0.937500 | Raw: 12.000000
# Moschitti | Norm: 0.964888 | Raw: 21.984000
#
# What should a couple do in Toronto?
# What's the best way to learn the most about the Star Wars mythology?
# Collins-Duffy | Norm: 0.084515 | Raw: 0.800000
# Moschitti | Norm: 0.341257 | Raw: 4.640000
#
# Why is Quora inhabited almost solely by effete liberal snobs?
# Why is Quora so liberal and progressive? Why does it have such a left/liberal bias?
# Collins-Duffy | Norm: 0.478091 | Raw: 3.200000
# Moschitti | Norm: 0.539077 | Raw: 4.736000
#
# Can we bring a dead animal back to life?
# Is it scientifically possible to bring someone who's been dead for years (not buried) back to life?
# Collins-Duffy | Norm: 0.447214 | Raw: 4.800000
# Moschitti | Norm: 0.607678 | Raw: 11.968000
#
# Is Donald Trump like Andrew Jackson?
# Is Donald Trump just like Andrew Jackson?
# Collins-Duffy | Norm: 0.925820 | Raw: 4.800000
# Moschitti | Norm: 0.930161 | Raw: 8.640000
#
# What would happen if you dumped 3,000 tons of phosphate into a small pond?
# Did the holocaust create 6,000 tons of phosphate and they just dumped this in a pond or whatever?
# Collins-Duffy | Norm: 0.377964 | Raw: 4.800000
# Moschitti | Norm: 0.685201 | Raw: 21.440000
#
# What are good ways to visualise a  cohort analysis?
# What is a cohort analysis?
# Collins-Duffy | Norm: 0.596285 | Raw: 3.200000
# Moschitti | Norm: 0.632222 | Raw: 4.992000
#
# What are the best technology wallets you probably should buy?
# What are the best wallets technologies in 2016?
# Collins-Duffy | Norm: 0.559017 | Raw: 4.000000
# Moschitti | Norm: 0.651335 | Raw: 8.096000
#
# Which is the best service IFB washing machine service center in Hyderabad?
# Where is the best IFB washing machine repair center in Hyderabad?
# Collins-Duffy | Norm: 0.725241 | Raw: 7.200000
# Moschitti | Norm: 0.806885 | Raw: 12.576000
#
# You have just won ten million dollars on the lottery. What would you do with the money?
# If you win a lottery of 5 million dollars, or if you have only 5 years left to live, would you change the way you live?
# Collins-Duffy | Norm: 0.246932 | Raw: 4.000000
# Moschitti | Norm: 0.543692 | Raw: 17.312000
#
# Why was a "Friends" episode dedicated to Pearl Harmon?
# A "Friends" episode was dedicated to Pearl Harmon. Who is that?
# Collins-Duffy | Norm: 0.824958 | Raw: 5.600000
# Moschitti | Norm: 0.853703 | Raw: 10.720000
#
# What is the worst thing that can happen in an adolescent’s life?
# What is the worst thing that can happen with us in life?
# Collins-Duffy | Norm: 0.800641 | Raw: 8.000000
# Moschitti | Norm: 0.882197 | Raw: 15.936000
#
# Is there any idea for a new and useful mini project in computer engineering?
# Are there any new topics in computer science to give me an idea for graduation project?
# Collins-Duffy | Norm: 0.485363 | Raw: 5.600000
# Moschitti | Norm: 0.734482 | Raw: 19.680000
#
# How do I overcome my panic attack issues?
# What is the easiest way to overcome a panic attack?
# Collins-Duffy | Norm: 0.158114 | Raw: 0.800000
# Moschitti | Norm: 0.368562 | Raw: 2.848000
#
# Why did Eclipse programmers choose one main thread to update the UI?
# Does Eclipse have a "dracula" theme like the one for intellij?
# Collins-Duffy | Norm: 0.288675 | Raw: 2.400000
# Moschitti | Norm: 0.487049 | Raw: 7.520000
#
# What is the easiest way to make a little money online?
# What is the best way for making money online?
# Collins-Duffy | Norm: 0.603023 | Raw: 4.800000
# Moschitti | Norm: 0.732762 | Raw: 9.408000
#
# Is it OK to go with a Sony A6300 for a beginner in photographer?
# What if India becomes a joint nation with all it's neighbouring countries united and be friend with China and Russia to form a worthy ally?
# Collins-Duffy | Norm: 0.353553 | Raw: 6.400000
# Moschitti | Norm: 0.638915 | Raw: 26.624000
#
# What is the difference between a gene and an allele?
# What is the difference between a type I, II, and III gene?
# Collins-Duffy | Norm: 0.730297 | Raw: 6.400000
# Moschitti | Norm: 0.865293 | Raw: 15.360000
#
# What is the best way to talk English fluently?
# What's the best way to learn English?
# Collins-Duffy | Norm: 0.707107 | Raw: 4.800000
# Moschitti | Norm: 0.816390 | Raw: 9.408000
#
# Will the i5 6402p be a bottleneck to the GTX 1070?
# Will the i5 6400 be a bottleneck to the GTX 1070?
# Collins-Duffy | Norm: 0.923077 | Raw: 9.600000
# Moschitti | Norm: 0.946600 | Raw: 15.744000
#
# Why do people choose to be a GAY?
# Do some women and men choose to be lesbian or gay? If so, why?
# Collins-Duffy | Norm: 0.319801 | Raw: 2.400000
# Moschitti | Norm: 0.546395 | Raw: 7.008000
#
# What are the good career option after b.tech in electrical engineering from an NIT?
# What are career options after graduating in electrical engineering particularly in the circuit design area?
# Collins-Duffy | Norm: 0.583383 | Raw: 7.200000
# Moschitti | Norm: 0.732930 | Raw: 16.672000
#
# How do I verify instagram?
# How can you look at someone's private Instagram account without following them?
# Collins-Duffy | Norm: 0.134840 | Raw: 0.800000
# Moschitti | Norm: 0.433494 | Raw: 4.384000
#
# How were leptons discovered, and what was the importance of them?
# Which the top 5 of each culture in terms of importance in influencing Australian activities?
# Collins-Duffy | Norm: 0.276686 | Raw: 3.200000
# Moschitti | Norm: 0.570579 | Raw: 14.208000
#
# How do I learn c++ programs faster?
# What is the best way to learn and understand C++ faster?
# Collins-Duffy | Norm: 0.282843 | Raw: 1.600000
# Moschitti | Norm: 0.445360 | Raw: 3.648000
#
# How can I prove [math]\sin(3\theta) = 3\cos^2\theta\sin\theta - \sin^3\theta[/math] using De Moivre's theorem?
# How do I prove that [math]\sin(\theta)\cos^2(\theta)+\sin^3(\theta)=\sin(\theta)[/math]?
# Collins-Duffy | Norm: 0.430331 | Raw: 4.000000
# Moschitti | Norm: 0.807381 | Raw: 27.808000
#
# Constitutionals, a question: what if during the presidential campaign between Trump & Clinton, Hillary dies before election? Who decides who runs?
# Does drinking water and distilled water act the same?
# Collins-Duffy | Norm: 0.075378 | Raw: 0.800000
# Moschitti | Norm: 0.418070 | Raw: 8.992000
#
# Why do beggars never lose hair?
# Had fight w/bf over his dead g/f?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.268454 | Raw: 1.536000
#
# What is the precise meaning of the Sanskrit word मत्परः? What is/are the root word/s used in forming the Sanskrit word मत्परः?
# What is the precise meaning of the Sanskrit word परिचर्यात्मकम्? What is/are the root word/s used in forming the Sanskrit word परिचर्यात्मकम्?
# Collins-Duffy | Norm: 1.000000 | Raw: 8.800000
# Moschitti | Norm: 1.000000 | Raw: 12.384000
#
# What is the best profession in India for females?
# What are some interesting profession in India?
# Collins-Duffy | Norm: 0.503953 | Raw: 3.200000
# Moschitti | Norm: 0.715384 | Raw: 8.576000
#
# What does it mean when a girl says she needs space?
# What does it mean when a girl say she needs space to better herself?
# Collins-Duffy | Norm: 0.805823 | Raw: 8.000000
# Moschitti | Norm: 0.887705 | Raw: 20.800000
#
# How many 2/7 are there in 5/6?
# 7, 4, 6, 3, 4.5, 1.5, 2.25. What is the next number?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.192577 | Raw: 1.280000
#
# What effects do dams have on the environment?
# Why are dams considered harmful for the environment?
# Collins-Duffy | Norm: 0.375000 | Raw: 2.400000
# Moschitti | Norm: 0.517657 | Raw: 4.704000
#
# Why do we feel anger?
# Why cant I feel anger?
# Collins-Duffy | Norm: 0.600000 | Raw: 2.400000
# Moschitti | Norm: 0.746193 | Raw: 4.704000
#
# What is the difference between an Islamic fundamentalist and a devout Muslim?
# Why are believers of Islam so devout?
# Collins-Duffy | Norm: 0.109109 | Raw: 0.800000
# Moschitti | Norm: 0.443471 | Raw: 5.664000
#
# How can I use all of these words in one paragraph?
# In Mac Word, the lines in the paragraph are all indented, how can I make it so that only the first is?
# Collins-Duffy | Norm: 0.284901 | Raw: 4.000000
# Moschitti | Norm: 0.615327 | Raw: 18.592000
#
# Who's your favourite Youtuber?
# What is your favorite YouTuber?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.444444 | Raw: 1.280000
#
# Why do I feel stressed with no reason behind?
# I am sad about coming home from vacation and going back to reality. What can I do to make me feel happy again?
# Collins-Duffy | Norm: 0.092450 | Raw: 0.800000
# Moschitti | Norm: 0.354251 | Raw: 5.408000
#
# Why did everyone care about Trump misspelling "unprecedented"?
# What should everyone know about Fred Trump?
# Collins-Duffy | Norm: 0.428571 | Raw: 2.400000
# Moschitti | Norm: 0.599557 | Raw: 5.472000
#
# Do Oyo rooms allow unmarried couples in Chennai?
# Does OYO allow unmarried couples?
# Collins-Duffy | Norm: 0.316228 | Raw: 1.600000
# Moschitti | Norm: 0.542605 | Raw: 4.672000
#
# What is the difference between "sang" and "sung"?
# What’s the difference between between “gray” and “grey”?
# Collins-Duffy | Norm: 0.577350 | Raw: 4.800000
# Moschitti | Norm: 0.581805 | Raw: 8.640000
#
# How do I get her to chase me?
# How do I get him to chase me?
# Collins-Duffy | Norm: 0.875000 | Raw: 5.600000
# Moschitti | Norm: 0.934896 | Raw: 11.488000
#
# What is the future of virtual reality?
# What is the future of virtual reality in education?
# Collins-Duffy | Norm: 0.881917 | Raw: 5.600000
# Moschitti | Norm: 0.915585 | Raw: 10.976000
#
# How does the earth rotates?
# How does the earth rotate?
# Collins-Duffy | Norm: 0.800000 | Raw: 3.200000
# Moschitti | Norm: 0.855491 | Raw: 4.736000
#
# What universities does Banner recruit new grads from? What majors are they looking for?
# What universities does Cooper recruit new grads from? What majors are they looking for?
# Collins-Duffy | Norm: 0.875000 | Raw: 5.600000
# Moschitti | Norm: 0.910714 | Raw: 8.160000
#
# How should I start contributing to open source projects?
# How can I contribute to open source development?
# Collins-Duffy | Norm: 0.589256 | Raw: 4.000000
# Moschitti | Norm: 0.765886 | Raw: 9.632000
#
# For the men, have any of you tried Lush henna bar's on your facial hair or beard, and has it worked?
# When did men start shaving their facial hair?
# Collins-Duffy | Norm: 0.105409 | Raw: 0.800000
# Moschitti | Norm: 0.372686 | Raw: 5.920000
#
# What can I do to overcome being too possessive with people?
# Being too possesive is bad. How do I avoid it?
# Collins-Duffy | Norm: 0.134840 | Raw: 0.800000
# Moschitti | Norm: 0.422228 | Raw: 4.640000
#
# How would scientific development be affected if the world is engaged in a global conflict and it sees no end?
# Have you fallen in love with an older woman?
# Collins-Duffy | Norm: 0.074536 | Raw: 0.800000
# Moschitti | Norm: 0.361637 | Raw: 6.944000
#
# What is your vision about Avengers: Age of Ultron?
# What are Vision's powers in Avengers Age of Ultron?
# Collins-Duffy | Norm: 0.358569 | Raw: 2.400000
# Moschitti | Norm: 0.737240 | Raw: 12.128000
#
# How do I leave a legacy?
# How do you leave a legacy to your children?
# Collins-Duffy | Norm: 0.771517 | Raw: 4.000000
# Moschitti | Norm: 0.827980 | Raw: 6.304000
#
# What is inside the black structure in Mecca that Muslims circle during Haj and Umrah?
# Why are only Muslims allowed into Mecca and Medina?
# Collins-Duffy | Norm: 0.258199 | Raw: 2.400000
# Moschitti | Norm: 0.546889 | Raw: 10.080000
#
# How are right and wrong defined? And why
# What is right and what is wrong?
# Collins-Duffy | Norm: 0.408248 | Raw: 2.400000
# Moschitti | Norm: 0.436516 | Raw: 3.936000
#
# What can I do to stop my girlfriend from being so obsessed with me?
# How can I stop being so obsessed with my husband ex girlfriend?
# Collins-Duffy | Norm: 0.639010 | Raw: 5.600000
# Moschitti | Norm: 0.724056 | Raw: 14.048000
#
# How would scrapping Rs 500 and 1000 notes affect the real estate sector?
# Will abolishing 1000 and 500 currency note affect property prices?
# Collins-Duffy | Norm: 0.350823 | Raw: 3.200000
# Moschitti | Norm: 0.648424 | Raw: 11.904000
#
# How do I get into cyber security with no background in it?
# How do I get started in the cyber security industry?
# Collins-Duffy | Norm: 0.639010 | Raw: 5.600000
# Moschitti | Norm: 0.702539 | Raw: 10.464000
#
# How can I learn x++ programming?
# What are some of the best ways to learn programming?
# Collins-Duffy | Norm: 0.258199 | Raw: 1.600000
# Moschitti | Norm: 0.536945 | Raw: 5.952000
#
# Can I take Prozac without consulting a doctor?
# Do I have to take Prozac daily for it to work or can I just take it as needed?
# Collins-Duffy | Norm: 0.282843 | Raw: 3.200000
# Moschitti | Norm: 0.543007 | Raw: 13.696000
#
# Why some of my mkv video files don't have thumbnails in Windows Explorer?
# How do I burn video files in AVI, MP4 and MKV on to a DVD through my PC?
# Collins-Duffy | Norm: 0.158114 | Raw: 1.600000
# Moschitti | Norm: 0.599457 | Raw: 13.888000
#
# How do I root my Samsung Galaxy S3 I9300?
# How can I root my Samsung Galaxy S3?
# Collins-Duffy | Norm: 0.750000 | Raw: 2.400000
# Moschitti | Norm: 0.831081 | Raw: 3.936000
#
# What does a human being experience in the first few seconds following decapitation?
# Has there ever been a case of a decapitated head speaking to someone, even if just for a few seconds?
# Collins-Duffy | Norm: 0.271964 | Raw: 4.000000
# Moschitti | Norm: 0.532669 | Raw: 13.984000
#
# What is the origin of gravitational force?
# What is the basic reason for gravitational force?
# Collins-Duffy | Norm: 0.668153 | Raw: 4.000000
# Moschitti | Norm: 0.792009 | Raw: 7.584000
#
# What if I flunk the JEE?
# Is the claim made by Dr.Giridharan S real?
# Collins-Duffy | Norm: 0.144338 | Raw: 0.800000
# Moschitti | Norm: 0.302574 | Raw: 2.336000
#
# What does concert venue mean?
# What is a concert venue?
# Collins-Duffy | Norm: 0.600000 | Raw: 2.400000
# Moschitti | Norm: 0.680664 | Raw: 3.680000
#
# How many genes are there on 1 chromosome?
# How many genes are there in one chromosome?
# Collins-Duffy | Norm: 0.750000 | Raw: 4.800000
# Moschitti | Norm: 0.821429 | Raw: 7.360000
#
# How long does it take a woman to get pregnant after sex?
# How long after my period can I get pregnant?
# Collins-Duffy | Norm: 0.545545 | Raw: 4.000000
# Moschitti | Norm: 0.587377 | Raw: 6.816000
#
# What are alternate exchanges to Coinbase for Bitcoin trading?
# Are swaps traded on exchange?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.368411 | Raw: 3.584000
#
# How do I write like this? (Focus.n.filters)
# How can the old Testament only be several thousand years old when the city of Jericho has been dated to 9000 BC?
# Collins-Duffy | Norm: 0.080064 | Raw: 0.800000
# Moschitti | Norm: 0.422002 | Raw: 7.712000
#
# What is the highest package for NIT Calicut in Chemical branch in 2015?
# Which NIT bagged the highest package in placement season 2014-2015?
# Collins-Duffy | Norm: 0.516398 | Raw: 4.800000
# Moschitti | Norm: 0.727591 | Raw: 13.760000
#
# What do you think of the decision by the Indian Government to replace 1000 notes with 2000 notes?
# Don't you think Modi will repeal decision to ban 500 and 1000 notes as it will cause high inconvenience?
# Collins-Duffy | Norm: 0.186097 | Raw: 3.200000
# Moschitti | Norm: 0.479731 | Raw: 18.560000
#
# How do I know who my spouse is texting?
# How do I spy on my spouse text?
# Collins-Duffy | Norm: 0.507093 | Raw: 2.400000
# Moschitti | Norm: 0.585862 | Raw: 4.448000
#
# How can I work in Microsoft?
# What can I do to get a job at Microsoft?
# Collins-Duffy | Norm: 0.387298 | Raw: 2.400000
# Moschitti | Norm: 0.561407 | Raw: 5.728000
#
# Which is the best coaching institute for CA-IPCC in Delhi?
# Which is the best crash course coaching institute for CA-CPT in delhi?
# Collins-Duffy | Norm: 0.804030 | Raw: 6.400000
# Moschitti | Norm: 0.894342 | Raw: 13.568000
#
# Can you get pregnant 16 days after your period?
# How do I get pregnant just after my periods?
# Collins-Duffy | Norm: 0.507093 | Raw: 2.400000
# Moschitti | Norm: 0.595023 | Raw: 3.936000
#
# How can I improve my English communication skill?
# How can you improve your communication skills?
# Collins-Duffy | Norm: 0.750000 | Raw: 2.400000
# Moschitti | Norm: 0.831081 | Raw: 3.936000
#
# What are things a mechanical engineer should know?
# What are things I know as a mechanical engineer?
# Collins-Duffy | Norm: 0.707107 | Raw: 4.800000
# Moschitti | Norm: 0.809138 | Raw: 9.920000
#
# What happens to proteins expressed by non-dominant alleles? Is their synthesis a complete waste of energy and aminoacids?
# What would happen, in terms of energy and assuming all apparatus is indestructible, if a 40w lamp was left on within a completely reflective sphere?
# Collins-Duffy | Norm: 0.078567 | Raw: 0.800000
# Moschitti | Norm: 0.491616 | Raw: 10.528000
#
# Have you ever had a near-death experience? If so, what did you think of during that?
# Have you ever had a near death experience using Kethamine?
# Collins-Duffy | Norm: 0.707107 | Raw: 4.000000
# Moschitti | Norm: 0.806646 | Raw: 7.840000
#
# Which mobile phone is best under 7k?
# Which is the best mobile for 7k to 8k?
# Collins-Duffy | Norm: 0.503953 | Raw: 3.200000
# Moschitti | Norm: 0.635703 | Raw: 6.784000
#
# What are some of best YouTube channels to learn accounting?
# What are the best YouTube channels to learn accounting?
# Collins-Duffy | Norm: 0.843274 | Raw: 6.400000
# Moschitti | Norm: 0.898221 | Raw: 12.800000
#
# What are some symptoms of eccentric and concentric contractions?
# What are some characteristics of concentric and eccentric contraction?
# Collins-Duffy | Norm: 0.777778 | Raw: 5.600000
# Moschitti | Norm: 0.855072 | Raw: 9.440000
#
# What are some of the best jokes you've ever heard?
# What are some of funniest jokes that you have ever heard?
# Collins-Duffy | Norm: 0.727273 | Raw: 6.400000
# Moschitti | Norm: 0.827129 | Raw: 13.312000
#
# Was Steve Jobs just an "idea guy"?
# Is Steve Jobs the "idea guy" or "execution guy"?
# Collins-Duffy | Norm: 0.400000 | Raw: 1.600000
# Moschitti | Norm: 0.588621 | Raw: 4.160000
#
# What are the best computer languages to learn for 2020?
# What is the most important computer language to learn?
# Collins-Duffy | Norm: 0.559017 | Raw: 4.000000
# Moschitti | Norm: 0.664575 | Raw: 7.328000
#
# How is life without seniors in MBBS college as ours is the first batch of this particular college?
# How is the life/experience of a student at MBBS college?
# Collins-Duffy | Norm: 0.497468 | Raw: 5.600000
# Moschitti | Norm: 0.763746 | Raw: 19.680000
#
# How do you delete your Yahoo email account?
# How do you disable a Yahoo account?
# Collins-Duffy | Norm: 0.566947 | Raw: 2.400000
# Moschitti | Norm: 0.685160 | Raw: 4.192000
#
# How do you legally immigrate to America from India? How can I ease up this process?
# How do you legally immigrate to America from Venezuela? How can I ease up this process?
# Collins-Duffy | Norm: 0.888889 | Raw: 6.400000
# Moschitti | Norm: 0.942263 | Raw: 13.056000
#
# As a freelancer based in India, how do you receive payments from online clients?
# As a freelancer, how and when do you initiate a discussion about payment with a client?
# Collins-Duffy | Norm: 0.455842 | Raw: 6.400000
# Moschitti | Norm: 0.675887 | Raw: 17.152000
#
# How do we really know what the temperature of the Sun is?
# What is the temperature of the Sun?
# Collins-Duffy | Norm: 0.712697 | Raw: 6.400000
# Moschitti | Norm: 0.733887 | Raw: 10.752000
#
# When did human history begin?
# What is the beginning of human history?
# Collins-Duffy | Norm: 0.338062 | Raw: 1.600000
# Moschitti | Norm: 0.439807 | Raw: 3.136000
#
# South Korea: Is the South Korean government more right-wing or left-wing?
# Were the Pahlavis of Iran left-wing rulers or right-wing rulers?
# Collins-Duffy | Norm: 0.272166 | Raw: 1.600000
# Moschitti | Norm: 0.473698 | Raw: 4.416000
#
# Hi all, investment in Venkatamangalam is good or bad? Whether in future land price will have good appreciation
# Does anybody whether the VC firm "VisionPlus" founded by Nokia's ex-VP Tero Ojanpera invests in firms located in India also ? OR are there only specific geographies/countries it invests in ? OR any other tips/snippets/pieces of information about them-- and I was fascinated by their website/approach and I plan to pitch to them-- so will appreciate any information  good/bad/ugly about them?
# Collins-Duffy | Norm: 0.139010 | Raw: 1.600000
# Moschitti | Norm: 0.621827 | Raw: 18.240000
#
# MF is C3H6O3; 32.594g sample of a compound containing only C,H &O,subjected to combustion analysis and __gCO2 & __gH2O were formed. find empir. form.?
# Is there any kind of reservation for wards of grade B officer in JEE?
# Collins-Duffy | Norm: 0.098058 | Raw: 1.600000
# Moschitti | Norm: 0.658908 | Raw: 37.184000
#
# What are the top 10 websites electronics & communication students must visit?
# I am an electronics and communication student in the 6th semester residing in Ahmedabad. Which core company should I visit for summer training?
# Collins-Duffy | Norm: 0.155700 | Raw: 1.600000
# Moschitti | Norm: 0.526351 | Raw: 10.816000
