# %%
import pandas as pd
import numpy as np
from pycorenlp import StanfordCoreNLP 
import re, time, bisect, math
import json
import TreeKernel as tk
import TreeBuild as tb
import pickle

# %%
nlp = StanfordCoreNLP('http://localhost:9000')

# %%
def _getNLPToks_(rawSentence):
    try:
        output = nlp.annotate(rawSentence, properties={
            'annotators': 'tokenize,ssplit,pos,parse,depparse',
            'outputFormat': 'json'
        })
    except UnicodeDecodeError:
        print("HERE")
        sentence = unidecode(rawSentence)
        output = nlp.annotate(sentence, properties={
            'annotators': 'tokenize,ssplit,pos,parse,depparse',
            'outputFormat': 'json'
        })
    if (isinstance(output, str)):
        print(output)
        output = json.loads(output) # Convert str output to dict
        
    dependencies = output['sentences'][0]['basicDependencies']
    tokens = output['sentences'][0]['tokens']
    parse = output['sentences'][0]['parse'].split("\n")
    
    return {'deps':dependencies,
            'toks':tokens, 
            'parse':parse}

# %% [markdown]
# ## Test: Tree Generation and Collins-Duffy Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tb.tree()
tree_b2 = tb.tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
tb._generateTree_(toks_b1, tree_b1)
tb._generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
tb._flipTree_(tree_b1)
tb._flipTree_(tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = tk._CollinsDuffy_(tree_b1, tree_b2, 0.8, 1, 0)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kerne
print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# --- 29.943864822387695 seconds ---
# ----------------------------------------------
# TypeError    Traceback (most recent call last)
# <ipython-input-4-ddd80c1c1119> in <module>()
#      16
#      17 # Generate a tree structure
# ---> 18 tb._generateTree_(toks_b1, tree_b1)
#      19 tb._generateTree_(toks_b2, tree_b2)
#      20
#
# /Users/Matthew/Documents/CIS700/FinalProject_Kaggle/TreeBuild.py in _generateTree_(rawTokens, treeRef)
#      56     ID_CTR = 1
#      57
# ---> 58     for tok in rawTokens[1:]:
#      59
#      60         curIndent = _leadingSpaces_(tok) # the current indent level
#
# TypeError: unhashable type: 'slice'

# %% [markdown]
# ## Test: Tree Kernels on Training Data

# %%
from random import randint

def read_data(path_to_file):
    df = pd.read_csv(path_to_file)
    print ("Shape of base training File = ", df.shape)
    # Remove missing values and duplicates from training data
    df.drop_duplicates(inplace=True)
    df.dropna(inplace=True)
    print("Shape of base training data after cleaning = ", df.shape)
    return df

df_train = read_data("input/train.csv")
# Out:
# Shape of base training File =  (404290, 6)
# Shape of base training data after cleaning =  (404288, 6)

# %%
## SET UP TEST INDICES TO SELECT RANDOM ROWS

TEST_SAMPLES = 100
indices = np.arange(TEST_SAMPLES)
for i in range(len(indices)):
    indices[i] = randint(0,df_train.shape[0])

# %%
df_sample = df_train.ix[indices]

for row in df_sample.iterrows():

    tree_1 = tb.tree()
    tree_2 = tb.tree()

    all_1 = _getNLPToks_(row[1]['question1'])
    all_2 = _getNLPToks_(row[1]['question2'])

    toks_1 = all_1['parse']
    toks_2 = all_2['parse']
    
    # Generate a tree structure
    tb._generateTree_(toks_1, tree_1)
    tb._generateTree_(toks_2, tree_2)

    # Flip the trees
    tb._flipTree_(tree_1)
    tb._flipTree_(tree_2)

    # ST-Score
    (rs_st, ns_st) = tk._CollinsDuffy_(tree_1, tree_2, 0.8, 1, 0)
    # SST-Score
    (rs_sst, ns_sst) = tk._CollinsDuffy_(tree_1, tree_2, 0.8, 1, 1)

    print(row[1]['question1'])
    print(row[1]['question2'])
    print("ST Norm Score: %f" % ns_st)
    print("SST Norm Score: %f" % ns_sst)
    print("ST Raw Score: %f" % rs_st)
    print("SST Raw Score: %f" % rs_sst)
# Out:
# What is the expected cutoff for KVPY 2016 SA -stream 2016?
# How was the KVPY SA 2016? What is the expected cutoff?
# ST Norm Score: 0.566139
# SST Norm Score: 0.566139
# ST Raw Score: 4.000000
# SST Raw Score: 4.000000
# How do I publish YouTube video on wimp?
# Is police corruption endemic in the UK?
# ST Norm Score: 0.000000
# SST Norm Score: 0.000000
# ST Raw Score: 0.000000
# SST Raw Score: 0.000000
# How do I create a linkedin profile?
# How can I improve my LinkedIn Profile?
# ST Norm Score: 0.377964
# SST Norm Score: 0.377964
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# Why do we get a runny nose when we eat something spicy?
# Why do we get runny noses when we eat spicy food?
# ST Norm Score: 0.741249
# SST Norm Score: 0.741249
# ST Raw Score: 8.000000
# SST Raw Score: 8.000000
# Why do my condoms always break?
# Why do condoms break?
# ST Norm Score: 0.750000
# SST Norm Score: 0.750000
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# Why am I always the first to initiate a conversation?
# How can I be the one to initiate the conversation?
# ST Norm Score: 0.547723
# SST Norm Score: 0.547723
# ST Raw Score: 4.800000
# SST Raw Score: 4.800000
# Is Sandor Clegane (The Hound) really dead? Why do people think he will return?
# If the Cleganebowl indeed happens, what can Sandor Clegane do to defeat Robert Strong?
# ST Norm Score: 0.202031
# SST Norm Score: 0.202031
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# Why do guys fall in love more easily than girls but experience more difficulty committing? Could guys with commitment issues ever settle down happily?
# Why do guys fall in love so easily?
# ST Norm Score: 0.639010
# SST Norm Score: 0.639010
# ST Raw Score: 5.600000
# SST Raw Score: 5.600000
# How do you make love to a girl?
# How do you make love?
# ST Norm Score: 0.790569
# SST Norm Score: 0.790569
# ST Raw Score: 4.000000
# SST Raw Score: 4.000000
# Were there many Japanese soldiers who opposed the Rape of Nanking?
# Why did Japanese soldiers commit such atrocities as the Nanjing Massacre?
# ST Norm Score: 0.272727
# SST Norm Score: 0.272727
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# What are the movies or TV series which made you fall in love with the actor?
# What are the movies or TV series which made you fall in love with the actress?
# ST Norm Score: 0.941176
# SST Norm Score: 0.941176
# ST Raw Score: 12.800000
# SST Raw Score: 12.800000
# Why is psychology considered a humanities class?
# IS psychology considered to be a humanity class?
# ST Norm Score: 0.534522
# SST Norm Score: 0.534522
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# What are some good home remedies for a dry throat and a runny nose?
# What helps against sore throat?
# ST Norm Score: 0.111803
# SST Norm Score: 0.111803
# ST Raw Score: 0.800000
# SST Raw Score: 0.800000
# What's your favorite NFL team?
# Which is your favorite football club?
# ST Norm Score: 0.000000
# SST Norm Score: 0.000000
# ST Raw Score: 0.000000
# SST Raw Score: 0.000000
# How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Kalahari Desert?
# How cold can the Gobi Desert get, and how do its average temperatures compare to the ones in the Patagonian Desert?
# ST Norm Score: 0.961538
# SST Norm Score: 0.961538
# ST Raw Score: 20.000000
# SST Raw Score: 20.000000
# What universities does BioReference Labs recruit new grads from? What majors are they looking for?
# What universities does Engagement Labs recruit new grads from? What majors are they looking for?
# ST Norm Score: 0.888889
# SST Norm Score: 0.888889
# ST Raw Score: 6.400000
# SST Raw Score: 6.400000
# What are the basic things for quantity surveyor job?
# What is the average salary of a quantity surveyor?
# ST Norm Score: 0.444444
# SST Norm Score: 0.444444
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# Which is the best English song?
# What are the best English songs to listen?
# ST Norm Score: 0.433013
# SST Norm Score: 0.433013
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# Which programming languages are used the most? Why?
# Which programming language uses mostly and why?
# ST Norm Score: 0.285714
# SST Norm Score: 0.285714
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# What is the best digital marketing course online for a beginner?
# What is the best digital marketing course available online and offline in India and Why?
# ST Norm Score: 0.585018
# SST Norm Score: 0.585018
# ST Raw Score: 6.400000
# SST Raw Score: 6.400000
# What happens to Cinderella at midnight?
# Why does Cinderella have to be home by midnight?
# ST Norm Score: 0.408248
# SST Norm Score: 0.408248
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# What is the best way to change careers?
# How should one change careers?
# ST Norm Score: 0.316228
# SST Norm Score: 0.316228
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# How do I make my Quora feed diverse?
# How do I make my feed very diverse in topics?
# ST Norm Score: 0.790569
# SST Norm Score: 0.790569
# ST Raw Score: 4.000000
# SST Raw Score: 4.000000
# What you wish to do when you have 24 hours left in your life?
# If you have just 24 hours left in your life, what are some of the crazy things you want to do?
# ST Norm Score: 0.641533
# SST Norm Score: 0.641533
# ST Raw Score: 8.800000
# SST Raw Score: 8.800000
# What is the Japanese translation of "blue dragon"?
# Is Google translate a good way to learn Japanese?
# ST Norm Score: 0.136083
# SST Norm Score: 0.136083
# ST Raw Score: 0.800000
# SST Raw Score: 0.800000
# What is the best gift to give on rakshabandhan?
# What is the best gift I should give to my sister on this "Rakshabandhan"?
# ST Norm Score: 0.804030
# SST Norm Score: 0.804030
# ST Raw Score: 6.400000
# SST Raw Score: 6.400000
# Should I start sleeping alone as a teenager?
# If absence and presence need to exist as a discrepancy, is the discrepancy relative to the universe or its source?
# ST Norm Score: 0.144338
# SST Norm Score: 0.144338
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# How do I check if I'm blacklisted by Malaysian immigration and barred from entering Malaysia?
# Singapore allows Malaysians to stay in the country for 30 days. Can I re-enter Singapore to get another 30 days stay after staying a day in Malaysia?
# ST Norm Score: 0.000000
# SST Norm Score: 0.000000
# ST Raw Score: 0.000000
# SST Raw Score: 0.000000
# How do I find a person's identity on the Internet using a mobile number?
# How do I find a person's identity on the Internet using a given mobile number?
# ST Norm Score: 0.971825
# SST Norm Score: 0.971825
# ST Raw Score: 13.600000
# SST Raw Score: 13.600000
# What are the best way of loose the weight?
# What can I do to loose 20-30kg?
# ST Norm Score: 0.123091
# SST Norm Score: 0.123091
# ST Raw Score: 0.800000
# SST Raw Score: 0.800000
# Which companies make the best airsoft guns?
# How do you upgrade your JG g36c airsoft gun?
# ST Norm Score: 0.000000
# SST Norm Score: 0.000000
# ST Raw Score: 0.000000
# SST Raw Score: 0.000000
# How many films has Adam Sandler and Rob Schneider starred in together?
# Which movies have Drew Barrymore and Adam Sandler starred in together?
# ST Norm Score: 0.522233
# SST Norm Score: 0.522233
# ST Raw Score: 4.800000
# SST Raw Score: 4.800000
# Why did God made men so ugly to the point where they are told to cover everything up, while women are encouraged to show as much skin as possible?
# Why, across the religions it is blasphemous for men to perceive female gods as his spouse, whereas it is alright for women to do so?
# ST Norm Score: 0.360180
# SST Norm Score: 0.360180
# ST Raw Score: 9.600000
# SST Raw Score: 9.600000
# I need review about Dr. Mario De Souza, can anyone tell me?
# Is Project Veritas a 2016 version of Woodward & Bersteins's 1972 Watergate expose?
# ST Norm Score: 0.000000
# SST Norm Score: 0.000000
# ST Raw Score: 0.000000
# SST Raw Score: 0.000000
# How can I transfer money from one bank to another?
# How do I transfer money from one country to another country?
# ST Norm Score: 0.701646
# SST Norm Score: 0.701646
# ST Raw Score: 6.400000
# SST Raw Score: 6.400000
# What is the Sahara, and how do the average temperatures there compare to the ones in the Sonoran Desert?
# What is the Sahara, and how do the average temperatures there compare to the ones in the Taklamakan Desert?
# ST Norm Score: 0.967742
# SST Norm Score: 0.967742
# ST Raw Score: 24.000000
# SST Raw Score: 24.000000
# Was Andrew Jackson a man of the people?
# Where can I find a one-cent Andrew Jackson stamp?
# ST Norm Score: 0.144338
# SST Norm Score: 0.144338
# ST Raw Score: 0.800000
# SST Raw Score: 0.800000
# How does one integrate [math]\displaystyle \int\dfrac{1}{\sqrt{x^2-1}}\,dx?[/math]
# How do I integrate this: [math]\int \frac{1}{(1+\sqrt{x})(\sqrt{(x-x^2)})} dx[/math]?
# ST Norm Score: 0.369274
# SST Norm Score: 0.369274
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# How the government of France changed between 1789-1815?
# How did the government of France cycle between monarchy, republic and empire between 1789-1815?
# ST Norm Score: 0.683130
# SST Norm Score: 0.683130
# ST Raw Score: 5.600000
# SST Raw Score: 5.600000
# Which are the most inspiring autobiographies?
# What are some inspiring autobiographies?
# ST Norm Score: 0.547723
# SST Norm Score: 0.547723
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# Are weeds good to health?
# Is weed good for health?
# ST Norm Score: 0.400000
# SST Norm Score: 0.400000
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# Why is it legal to burn the American flag in the US?
# Why did the California protesters burn the American flag?
# ST Norm Score: 0.564076
# SST Norm Score: 0.564076
# ST Raw Score: 5.600000
# SST Raw Score: 5.600000
# What are the available Codeforces contest parsers for C++?
# Can I get the Codeforces contests result to work on it?
# ST Norm Score: 0.213201
# SST Norm Score: 0.213201
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# What's the best Fire Emblem game?
# Which is the best fire emblem?
# ST Norm Score: 0.308607
# SST Norm Score: 0.308607
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# Where and how do extreme couponers get their coupons from?
# Where do extreme couponers get coupons?
# ST Norm Score: 0.721688
# SST Norm Score: 0.721688
# ST Raw Score: 4.000000
# SST Raw Score: 4.000000
# How do I get a pilot's license?
# How do I become a pilot?
# ST Norm Score: 0.721688
# SST Norm Score: 0.721688
# ST Raw Score: 4.000000
# SST Raw Score: 4.000000
# Why is NH2 an electron donating group but NO2 an electron withdrawing group?
# Is benzene an electron withdrawing or donating group?
# ST Norm Score: 0.648886
# SST Norm Score: 0.648886
# ST Raw Score: 6.400000
# SST Raw Score: 6.400000
# Can Android ever replace iOS?
# Is framework 7 is going to replace android/ios SDKs?
# ST Norm Score: 0.169031
# SST Norm Score: 0.169031
# ST Raw Score: 0.800000
# SST Raw Score: 0.800000
# What are some good books (fiction and non-fiction) that are about the dot-com bubble?
# What are the best books about the dot-com bubble of the late 90s?
# ST Norm Score: 0.538138
# SST Norm Score: 0.538138
# ST Raw Score: 6.400000
# SST Raw Score: 6.400000
# What are the best fantasy trilogies of all time?
# What are the best fantasy movies of all time?
# ST Norm Score: 0.888889
# SST Norm Score: 0.888889
# ST Raw Score: 6.400000
# SST Raw Score: 6.400000
# What is your best argument for arguing the non-existence of God? What's your best argument for the existence of God?
# What is the best argument for the existence of (Abrahamic) God?
# ST Norm Score: 0.733799
# SST Norm Score: 0.733799
# ST Raw Score: 5.600000
# SST Raw Score: 5.600000
# Are microwaves generated by microwave ovens dangerous to human beings in any way?
# How dangerous are microwave ovens?
# ST Norm Score: 0.372104
# SST Norm Score: 0.372104
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# Does time exist?
# Broadly, does time exist, and if so, in what regard?
# ST Norm Score: 0.384900
# SST Norm Score: 0.384900
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# Which are the most underrated Bollywood actors and actresses?
# Who is the most underrated Bollywood actors?
# ST Norm Score: 0.577350
# SST Norm Score: 0.577350
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# What would today be like if hitler had won WWII?
# If Hitler had won World War II, what sort of world would there have been today?
# ST Norm Score: 0.316228
# SST Norm Score: 0.316228
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# What will be the effect of India scrapping Rs. 500 & Rs. 1000 notes on Indian stock markets?
# What will be the effect of the ban of the 1000rs and 500rs notes on the stock market?
# ST Norm Score: 0.589256
# SST Norm Score: 0.589256
# ST Raw Score: 8.000000
# SST Raw Score: 8.000000
# What will you do if you faound a way to use 100% of your brain?
# Hypothetically speaking, what if you found a way to use 100 percent of your brain? What do you think you'll be able to do?
# ST Norm Score: 0.644503
# SST Norm Score: 0.644503
# ST Raw Score: 7.200000
# SST Raw Score: 7.200000
# What is the best thing your mother said to you?
# What is the best thing your dad has said to you?
# ST Norm Score: 0.824958
# SST Norm Score: 0.824958
# ST Raw Score: 5.600000
# SST Raw Score: 5.600000
# What is the difference between the following sentences with "on" and "in"?
# What is the difference between the following sentences with "would/could" and "will/can"?
# ST Norm Score: 0.919866
# SST Norm Score: 0.919866
# ST Raw Score: 8.800000
# SST Raw Score: 8.800000
# Can a Sikh Enjoy worldly pleasures?
# Is Islam against seeking material wealth and enjoying worldly pleasures if legally obtained?
# ST Norm Score: 0.226455
# SST Norm Score: 0.226455
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# Where should I stay in Goa?
# Where are some great places to stay in Goa?
# ST Norm Score: 0.544331
# SST Norm Score: 0.544331
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# What are the best books to study psychology?
# What are best books on psychology?
# ST Norm Score: 0.577350
# SST Norm Score: 0.577350
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# How can you train a Golden Retriever/Corgi mix?
# How friendly is a Golden Retriever/Corgi mix?
# ST Norm Score: 0.617213
# SST Norm Score: 0.617213
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# How do people become beggars?
# Can begging be dropped?
# ST Norm Score: 0.000000
# SST Norm Score: 0.000000
# ST Raw Score: 0.000000
# SST Raw Score: 0.000000
# How do you determine the specific heat of sand?
# What is the specific heat of plastic? How is this determined?
# ST Norm Score: 0.503953
# SST Norm Score: 0.503953
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# What are the best printers compatible with Dell computers?
# What is a good home 3D printer to start toying with?
# ST Norm Score: 0.201008
# SST Norm Score: 0.201008
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# What are some things new employees should know going into their first day at CSC?
# What are some things new employees should know going into their first day at AT&T?
# ST Norm Score: 0.957427
# SST Norm Score: 0.957427
# ST Raw Score: 8.800000
# SST Raw Score: 8.800000
# How will abolishing rs.500 and rs.1000 notes reduce corruption and identifying black money?
# How will the India demonetization of 500 and 1000 rupees notes will reduce black money?
# ST Norm Score: 0.529412
# SST Norm Score: 0.529412
# ST Raw Score: 7.200000
# SST Raw Score: 7.200000
# How should I study in first year of MBBS?
# What is the proper methodology to study 1st year MBBS?
# ST Norm Score: 0.210819
# SST Norm Score: 0.210819
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# Why is Cricket called Cricket?
# Why is cricket called a ‘gentleman’s game’?
# ST Norm Score: 0.285714
# SST Norm Score: 0.285714
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# Which private medical college should I apply when my NEET score is 191?
# Which private medical college should I apply when my NEET score is 184?
# ST Norm Score: 0.900000
# SST Norm Score: 0.900000
# ST Raw Score: 7.200000
# SST Raw Score: 7.200000
# If you delete photos from your iPhone, will they be deleted from Google Photos?
# Can I delete photos/videos from my Android device without having them removed from auto-backup?
# ST Norm Score: 0.334497
# SST Norm Score: 0.334497
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# What is the effect of price on quantity demand?
# What are the effects of a price floor on quantity demanded and quantity supplied?
# ST Norm Score: 0.583333
# SST Norm Score: 0.583333
# ST Raw Score: 5.600000
# SST Raw Score: 5.600000
# What are the priorities of life from first to last?
# What is your #1 priority in life?
# ST Norm Score: 0.316228
# SST Norm Score: 0.316228
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# Who was a better Dumbledore -- Richard Harris (RIP) or Michael Gambon?
# Which portrayal Dumbledore did you prefer, Richard Harris or Michael Gambon?
# ST Norm Score: 0.454545
# SST Norm Score: 0.454545
# ST Raw Score: 4.000000
# SST Raw Score: 4.000000
# Are there any graduate scholarships for the field of computational linguistics in America?
# Is there Any master scholarship in brain computer interface field?
# ST Norm Score: 0.263117
# SST Norm Score: 0.263117
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# What are the best small classes for freshmen at Northwest Missouri State?
# What are the best small classes for freshmen at Missouri State?
# ST Norm Score: 0.957427
# SST Norm Score: 0.957427
# ST Raw Score: 8.800000
# SST Raw Score: 8.800000
# Is it good to give up on life?
# Is it good to give up sometimes in life?
# ST Norm Score: 0.824958
# SST Norm Score: 0.824958
# ST Raw Score: 5.600000
# SST Raw Score: 5.600000
# What is the difference between : and ; ?
# What is the difference between "&" and "and"?
# ST Norm Score: 0.673575
# SST Norm Score: 0.673575
# ST Raw Score: 5.600000
# SST Raw Score: 5.600000
# Is there a chance that Donald Trump turns out to be a very good president?
# Do you think Donald Trump will make a good U.S. President?
# ST Norm Score: 0.365636
# SST Norm Score: 0.365636
# ST Raw Score: 4.000000
# SST Raw Score: 4.000000
# Why is Quora so liberal leaning?
# Why is Quora such a liberal hangout?
# ST Norm Score: 0.617213
# SST Norm Score: 0.617213
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# I am an Indian, I want to move to Greenland. I will go on a tourist visa and will never come back, what would you advise?
# Working Abroad: I am a 30 year old Indian male engg graduate from india. I have 6 years of experience in automotive and electronics field. I want to move abroad on work visa. How should I go about this?
# ST Norm Score: 0.285714
# SST Norm Score: 0.285714
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# Why is O the most common blood type in humans even though it is a recessive trait?
# Could I donate my blood to a person with blood type O if my blood is type A?
# ST Norm Score: 0.294628
# SST Norm Score: 0.294628
# ST Raw Score: 4.000000
# SST Raw Score: 4.000000
# How can we control bad feelings?
# How can I control my emotion and fears?
# ST Norm Score: 0.365148
# SST Norm Score: 0.365148
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# What specifically defines the entrepreneurial spirit?
# What is entrepreneurial?
# ST Norm Score: 0.235702
# SST Norm Score: 0.235702
# ST Raw Score: 0.800000
# SST Raw Score: 0.800000
# How do i control emotions at work place or public place?
# How could I control my emotions and my negative thoughts?
# ST Norm Score: 0.124035
# SST Norm Score: 0.124035
# ST Raw Score: 0.800000
# SST Raw Score: 0.800000
# What is a way to make money online?
# What is the easiest way to earn money from online?
# ST Norm Score: 0.670820
# SST Norm Score: 0.670820
# ST Raw Score: 4.800000
# SST Raw Score: 4.800000
# What are all the flavors of Native American Spirit Cigarettes, and what do the colors mean?
# Why do American Spirit Cigarettes have somewhat of a cult following?
# ST Norm Score: 0.213201
# SST Norm Score: 0.213201
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# Why is the surname "LEE" so common in China?
# What does the integral of a function say about the function's properties'?
# ST Norm Score: 0.153393
# SST Norm Score: 0.153393
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# What is something that money can't buy?
# How much money do I need to buy something off Alibaba?
# ST Norm Score: 0.319801
# SST Norm Score: 0.319801
# ST Raw Score: 2.400000
# SST Raw Score: 2.400000
# How do I update my profile picture and name on messenger?
# What are some awesome WhatsApp profile pictures?
# ST Norm Score: 0.000000
# SST Norm Score: 0.000000
# ST Raw Score: 0.000000
# SST Raw Score: 0.000000
# What are the 11 dimensions in string theory?
# According to string theory there are 11 dimensions; what are those dimensions?
# ST Norm Score: 0.530330
# SST Norm Score: 0.530330
# ST Raw Score: 4.800000
# SST Raw Score: 4.800000
# How does a long distance relationship work?
# How does long distance relationship work?
# ST Norm Score: 0.925820
# SST Norm Score: 0.925820
# ST Raw Score: 4.800000
# SST Raw Score: 4.800000
# Which gas is readily soluble in water at room temperature?
# What is the temperature of water at room temperature?
# ST Norm Score: 0.572078
# SST Norm Score: 0.572078
# ST Raw Score: 4.800000
# SST Raw Score: 4.800000
# Why is Wikipedia now asking for donations?
# Why is Wikipedia asking for donations all of a sudden?
# ST Norm Score: 0.717137
# SST Norm Score: 0.717137
# ST Raw Score: 4.800000
# SST Raw Score: 4.800000
# How does one prepare for the Regional Mathematics Olympiad?
# How did you prepare for the Regional Mathematical Olympiad?
# ST Norm Score: 0.666667
# SST Norm Score: 0.666667
# ST Raw Score: 4.800000
# SST Raw Score: 4.800000
# How do I understand if my best friend is falling for me?
# How do I make my best friend fall in love with me?
# ST Norm Score: 0.471405
# SST Norm Score: 0.471405
# ST Raw Score: 3.200000
# SST Raw Score: 3.200000
# How do I stop worrying about future?
# What are some psychological tricks to stop caring about what people think?
# ST Norm Score: 0.218218
# SST Norm Score: 0.218218
# ST Raw Score: 1.600000
# SST Raw Score: 1.600000
# What are your opinion about defence service SSB to recruit?
# Is there a software that will help a personal assistant do their job more efficiently?
# ST Norm Score: 0.000000
# SST Norm Score: 0.000000
# ST Raw Score: 0.000000
# SST Raw Score: 0.000000
# Which is the best coaching institute for cat preparation in Delhi?
# What is the best coaching institute for the CAT preparation in Delhi?
# ST Norm Score: 0.805823
# SST Norm Score: 0.805823
# ST Raw Score: 8.000000
# SST Raw Score: 8.000000

# %%
with open('input/stanfordData_train1.nlp', 'rb') as handle:
    try:
        while True:
            tmp = pickle.load(handle)
            if tmp == {}:
                print("Empty")
    except EOFError:
        pass

# %%
print(df_train.ix[212574]['question1'])
_getNLPToks_(df_train.ix[212574]['question1'])

# %%
df_train.ix[[1,5]]
# Out:
#    id  qid1  qid2                                          question1  \
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 5   5    11    12  Astrology: I am a Capricorn Sun Cap moon and c...
#
#                                            question2  is_duplicate
# 1  What would happen if the Indian government sto...             0
# 5  I'm a triple Capricorn (Sun, Moon and ascendan...             1
