# %%
import pandas as pd
import numpy as np
from pycorenlp import StanfordCoreNLP 
import re, time, bisect, math
import TreeKernel as tk
import TreeBuild as tb

# %%
from gensim.models.keyedvectors import KeyedVectors
word_vectors = KeyedVectors.load_word2vec_format('./w2v_model/GoogleNews-vectors-negative300.bin', binary=True)  # C binary format

# %%
nlp = StanfordCoreNLP('http://localhost:9000')

# %%
def _getNLPToks_(rawSentence):
    output = nlp.annotate(rawSentence, properties={
      'annotators': 'tokenize,ssplit,pos,parse',
      'outputFormat': 'json'
      })
    return output['sentences'][0]['parse'].split("\n")

# %%
def _w2vSimilarity_(word1, word2, modelPtr):
    return modelPtr.similarity(word1, word2)

# %% [markdown]
# ## Test: Tree Generation and Collins-Duffy Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tb.tree()
tree_b2 = tb.tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
tb._generateTree_(toks_b1, tree_b1)
tb._generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
tb._flipTree_(tree_b1)
tb._flipTree_(tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = tk._CollinsDuffy_(tree_b1, tree_b2, 0.8, 1, 0)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel

print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# --- 0.03782510757446289 seconds ---
# --- 0.0381472110748291 seconds ---
# --- 0.038294076919555664 seconds ---
# --- 0.041108131408691406 seconds ---
# Raw Score: 0.8
# Norm Score: 0.124034734589

# %% [markdown]
# ## Test: Tree Generation and Moschitti PT Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tb.tree()
tree_b2 = tb.tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
tb._generateTree_(toks_b1, tree_b1)
tb._generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
tb._flipTree_(tree_b1)
tb._flipTree_(tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = tk._MoschittiPT_(tree_b1, tree_b2, 0.8, 0.4, 1)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel

print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# --- 0.03903079032897949 seconds ---
# --- 0.03934288024902344 seconds ---
# --- 0.03950095176696777 seconds ---
# --- 0.04249095916748047 seconds ---
# Raw Score: 3.36
# Norm Score: 0.326722528894

# %% [markdown]
# ## Test: Tree Kernels on Training Data

# %%
from random import randint

def read_data(path_to_file):
    df = pd.read_csv(path_to_file)
    print ("Shape of base training File = ", df.shape)
    # Remove missing values and duplicates from training data
    df.drop_duplicates(inplace=True)
    df.dropna(inplace=True)
    print("Shape of base training data after cleaning = ", df.shape)
    return df

df_train = read_data("input/train.csv")
# Out:
# Shape of base training File =  (404290, 6)
# Shape of base training data after cleaning =  (404288, 6)

# %%
## SET UP TEST INDICES TO SELECT RANDOM ROWS

TEST_SAMPLES = 100
indices = np.arange(TEST_SAMPLES)
for i in range(len(indices)):
    indices[i] = randint(0,df_train.shape[0])

# %%
for ind in indices:
    
    tree_1 = tb.tree()
    tree_2 = tb.tree()

    toks_1 = _getNLPToks_(df_train.get_value(ind,'question1'))
    toks_2 = _getNLPToks_(df_train.get_value(ind,'question2'))

    # Generate a tree structure
    tb._generateTree_(toks_1, tree_1)
    tb._generateTree_(toks_2, tree_2)

    # Flip the trees
    tb._flipTree_(tree_1)
    tb._flipTree_(tree_2)

    (scoreRaw_cd, scoreNorm_cd) = tk._CollinsDuffy_(tree_1, tree_2, 0.8, 1, 1)
    (scoreRaw_pt, scoreNorm_pt) = tk._MoschittiPT_(tree_1, tree_2, 0.8, 0.4, 1)
    print("%s\n%s" % (df_train.get_value(ind,'question1'), df_train.get_value(ind,'question2')))
    print("Collins-Duffy | Norm: %f | Raw: %f" % (scoreNorm_cd, scoreRaw_cd))
    print("Moschitti | Norm: %f | Raw: %f\n" % (scoreNorm_pt, scoreRaw_pt))
# Out:
# What are the jobs for me after completing master's in economics?
# What are the jobs after m.a economic?
# Collins-Duffy | Norm: 0.545545 | Raw: 4.000000
# Moschitti | Norm: 0.722947 | Raw: 11.168000
#
# A couple who has 5 sons went for a picnic. Each son has 7 sisters. Each sister has 3 babies. In total, how many people went for the picnic?
# Brain Teasers: Two women set out to the market to sell some oranges. Each  had 30 oranges. The first lady sold oranges at 2 for a rupee and second lady sold oranges at 3 for rupee. At last, the first and second lady made Rs 15 and Rs 10 respectively. So the total amount is Rs 25. The next day, when they sold their 30 oranges together to make business profitable, they pooled their sixty oranges and sold at rate of 5 for Rs 2. After they sold all oranges, they found they had only Rs 24. They could not understand where the one rupee went. Where did it go?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.451110 | Raw: 8.704000
#
# How do I burn the fat around my waist?
# How do I lose fat on the sides of my waist?
# Collins-Duffy | Norm: 0.503953 | Raw: 3.200000
# Moschitti | Norm: 0.668279 | Raw: 7.040000
#
# What are the advantages of Natural Language Processing?
# What are advantages of natural language processing?
# Collins-Duffy | Norm: 0.534522 | Raw: 3.200000
# Moschitti | Norm: 0.708464 | Raw: 6.784000
#
# If I die when two events occur sequentially, but not simultaneously, is the scenario affected by relativity of simultaneity? (details in description)
# If simultaneity is relative, how can we tell whether or not an event really did occur before another?
# Collins-Duffy | Norm: 0.216295 | Raw: 3.200000
# Moschitti | Norm: 0.566723 | Raw: 16.768000
#
# What are the tastiest Indian vegetarian dish?
# What are some Indian Vegetarian dishes that foreigners love to eat?
# Collins-Duffy | Norm: 0.341882 | Raw: 2.400000
# Moschitti | Norm: 0.493328 | Raw: 5.984000
#
# How can I maintain abs?
# How do you maintain abs?
# Collins-Duffy | Norm: 0.600000 | Raw: 2.400000
# Moschitti | Norm: 0.746193 | Raw: 4.704000
#
# Why there are so many Malayalam News channels in Kerala?
# Kerala, India: What are some of the best novels written in Malayalam?
# Collins-Duffy | Norm: 0.408248 | Raw: 3.200000
# Moschitti | Norm: 0.688606 | Raw: 13.952000
#
# What compound are responsible to fragrance of ghee?
# I am gluten intolerant. Can I have ghee?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.273115 | Raw: 2.048000
#
# What are some examples of science experiments where scientists lost control of the situation?
# People think I'm gay but I’m not. What should I do?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.333678 | Raw: 8.448000
#
# How many days before my period can I get pregnant?
# Is it possible to get pregnant before period or after period ends?
# Collins-Duffy | Norm: 0.283473 | Raw: 2.400000
# Moschitti | Norm: 0.411992 | Raw: 5.472000
#
# Are there any good and simple pre & post-workout meals which contain enough protein and carbs?
# What are the best pre- and post-workout meals?
# Collins-Duffy | Norm: 0.292770 | Raw: 2.400000
# Moschitti | Norm: 0.448761 | Raw: 5.984000
#
# Why Cyrus Mistry has been replaced by Ratan Tata?
# Why was Cyrus Mistry removed as the Chairman of Tata Sons?
# Collins-Duffy | Norm: 0.402015 | Raw: 3.200000
# Moschitti | Norm: 0.552883 | Raw: 8.064000
#
# Who was the first person in Game of Thrones you hated? Joffrey? Cersei?
# Who is the most arrogant character in Game of Thrones?
# Collins-Duffy | Norm: 0.572078 | Raw: 4.800000
# Moschitti | Norm: 0.778807 | Raw: 14.528000
#
# What should I say whenever my girlfriend asks me why I love her?
# Whenever I ask my husband why he loves me, he can't come up with anything legitimate. What do you/your spouse say to this question?
# Collins-Duffy | Norm: 0.269069 | Raw: 3.200000
# Moschitti | Norm: 0.613466 | Raw: 15.744000
#
# Can I use two Jio sim on one dual sim phone?
# Why in Naruto: Shippuden The Longest moment epsiode the chair Itachi was sitting on had one black dot on each side of his head?
# Collins-Duffy | Norm: 0.204124 | Raw: 2.400000
# Moschitti | Norm: 0.574847 | Raw: 14.688000
#
# What if Donald Trump winning this elections?
# Did Donald Trump win the election?
# Collins-Duffy | Norm: 0.308607 | Raw: 1.600000
# Moschitti | Norm: 0.456299 | Raw: 3.648000
#
# What does it feel like to have sex with a man if you are (or were) a straight man?
# What is it like to be a straight man who had had sex with another man?
# Collins-Duffy | Norm: 0.638915 | Raw: 10.400000
# Moschitti | Norm: 0.806847 | Raw: 27.808000
#
# Does America have embassies in every country?
# What country does an embassy office belongs to? Does it fall under the jurisdiction of foreign country or of homeland?
# Collins-Duffy | Norm: 0.133631 | Raw: 0.800000
# Moschitti | Norm: 0.276594 | Raw: 2.592000
#
# What ancestry makes John Legend have a white nose, Asian eyes/eyebrows, and black skin tone/hair?
# Do Asian people have African ancestry?
# Collins-Duffy | Norm: 0.339683 | Raw: 2.400000
# Moschitti | Norm: 0.567674 | Raw: 7.008000
#
# What is the most badass thing about Plato?
# What is the most badass thing about George S. Patton?
# Collins-Duffy | Norm: 0.782624 | Raw: 5.600000
# Moschitti | Norm: 0.857326 | Raw: 9.440000
#
# How do I connect my SQL server database with my new website?
# What is the current GDP in 2016?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.245701 | Raw: 1.792000
#
# How is the HTC One E9+?
# Does the HTC One E9+ have any issues?
# Collins-Duffy | Norm: 0.534522 | Raw: 3.200000
# Moschitti | Norm: 0.525329 | Raw: 5.504000
#
# How does film producers earn money?
# How does the film producers earn?
# Collins-Duffy | Norm: 0.666667 | Raw: 3.200000
# Moschitti | Norm: 0.744073 | Raw: 4.992000
#
# Is MacBook Pro 2016 worth it?
# What are your thoughts on the new 2016 MacBook Pro?
# Collins-Duffy | Norm: 0.308607 | Raw: 1.600000
# Moschitti | Norm: 0.509823 | Raw: 4.672000
#
# Why is Reliance the worst communication company for consumers?
# How many consumers do most huge companies have?
# Collins-Duffy | Norm: 0.117851 | Raw: 0.800000
# Moschitti | Norm: 0.231133 | Raw: 2.336000
#
# What is saturation & active region in a transistor?
# What is saturation?
# Collins-Duffy | Norm: 0.612372 | Raw: 2.400000
# Moschitti | Norm: 0.653495 | Raw: 4.704000
#
# How can I find all the website accounts that are associated with my email address?
# How do I find domain names associated with an email address?
# Collins-Duffy | Norm: 0.435194 | Raw: 4.000000
# Moschitti | Norm: 0.606762 | Raw: 10.400000
#
# Is every rhombus a parallelogram?
# What are the lines of symmetry in a rhombus?
# Collins-Duffy | Norm: 0.298142 | Raw: 1.600000
# Moschitti | Norm: 0.501967 | Raw: 4.672000
#
# How much does YouTube pay per subscriber?
# Does YouTube pay per video or channel?
# Collins-Duffy | Norm: 0.428571 | Raw: 2.400000
# Moschitti | Norm: 0.563048 | Raw: 4.448000
#
# If sweat doesn't come does it helps to reduce weight loss?
# How does sweating contribute to weight loss?
# Collins-Duffy | Norm: 0.505076 | Raw: 4.000000
# Moschitti | Norm: 0.483970 | Raw: 7.328000
#
# How to build non-lethal weapons?
# What are some non-lethal weapons technologies?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.142524 | Raw: 0.768000
#
# What should be the value of √-1?
# What is the value of 1+1°=?
# Collins-Duffy | Norm: 0.666667 | Raw: 3.200000
# Moschitti | Norm: 0.708932 | Raw: 6.528000
#
# What do I need to do if I want to live beyond the age of 100 years old?
# What is a formula to live for 100 years?
# Collins-Duffy | Norm: 0.426401 | Raw: 4.800000
# Moschitti | Norm: 0.653928 | Raw: 14.016000
#
# What camera took a picture of the world's first camera?
# Which was the first mobile to have dual lens camera?
# Collins-Duffy | Norm: 0.300000 | Raw: 2.400000
# Moschitti | Norm: 0.476192 | Raw: 5.984000
#
# What's the best way to write an F in cursive?
# How do you write a cursive capital "J?"
# Collins-Duffy | Norm: 0.106600 | Raw: 0.800000
# Moschitti | Norm: 0.457969 | Raw: 6.176000
#
# Where can I find affordable but good help for completing mobile app development projects?
# How much is Greek spoken in Turkey?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.309375 | Raw: 3.840000
#
# Why is Europe's train system so expensive compared to driving (especially when more than one person is involved)?
# How much does it cost for an Indian to travel all of Europe?
# Collins-Duffy | Norm: 0.124035 | Raw: 1.600000
# Moschitti | Norm: 0.500165 | Raw: 13.376000
#
# I perfer to find a English partner to learn language eachother I am a Chinese girl and I perfer to learn speaking English with WeChat is that ok?
# If I am speaking to a girl from a different country, and I start to learn a bit of her language is it creepy?
# Collins-Duffy | Norm: 0.637888 | Raw: 20.000000
# Moschitti | Norm: 0.829361 | Raw: 68.640000
#
# Top 5 online portals to buy antique jewellery in UK?
# What are the Top 5 online portals to buy antique jewellery in UK?
# Collins-Duffy | Norm: 0.877058 | Raw: 8.000000
# Moschitti | Norm: 0.891819 | Raw: 15.168000
#
# Why do some Americans build their homes with wood while some Europeans prefer brick?
# How do you build an outdoor brick fireplace?
# Collins-Duffy | Norm: 0.188982 | Raw: 1.600000
# Moschitti | Norm: 0.412879 | Raw: 5.184000
#
# I got marriage in 2012 my age 30 my wife age 16 at that time . bacause of some problems we are separately living now . Can I take divorce from her?
# I got married in 2012 when I was 30 and my wife was 16. Due to some problems, we are separately living now . Can I take divorce from her?
# Collins-Duffy | Norm: 0.441942 | Raw: 4.000000
# Moschitti | Norm: 0.645558 | Raw: 11.680000
#
# Can we have increased profits but decreased profitability?
# How do I increase my companies productivity and how can I make huge profit?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.327715 | Raw: 5.120000
#
# Which are the emerging service-based software startups in India?
# What are some good startup companies in India and based from out of India?
# Collins-Duffy | Norm: 0.408248 | Raw: 3.200000
# Moschitti | Norm: 0.585545 | Raw: 8.832000
#
# Which is the best bank to open an NRE account with?
# What is the best bank to open NRE account if I am staying in Thailand and planning to repatriate some amount back to India?
# Collins-Duffy | Norm: 0.550482 | Raw: 8.000000
# Moschitti | Norm: 0.703746 | Raw: 19.776000
#
# Police: what are some highly abusive and humiliating ways in which you were handled by police?
# What are the legal consequences for police officers that abuse their power?
# Collins-Duffy | Norm: 0.158114 | Raw: 1.600000
# Moschitti | Norm: 0.509204 | Raw: 10.048000
#
# Why Delhi has the most no. of crimes in India?
# Why most of the crimes occur in the surroundings of Delhi?
# Collins-Duffy | Norm: 0.421637 | Raw: 3.200000
# Moschitti | Norm: 0.644697 | Raw: 10.112000
#
# Why does my Instagram account unfollow/block people on its own?
# Why Instagram block me temporary?
# Collins-Duffy | Norm: 0.258199 | Raw: 0.800000
# Moschitti | Norm: 0.484908 | Raw: 2.592000
#
# What enemies do grizzly bears have?
# How do grizzly bears defend themselves?
# Collins-Duffy | Norm: 0.500000 | Raw: 2.400000
# Moschitti | Norm: 0.586673 | Raw: 3.936000
#
# What are the best resources to learn SAP for beginners?
# What are the best resources for learning SAP?
# Collins-Duffy | Norm: 0.782624 | Raw: 5.600000
# Moschitti | Norm: 0.864321 | Raw: 10.720000
#
# Relation between phase & line voltage?
# What is line voltage and phase voltage?
# Collins-Duffy | Norm: 0.596285 | Raw: 3.200000
# Moschitti | Norm: 0.680706 | Raw: 7.296000
#
# What's an interesting secret you care to share anonymously?
# Secrets: What is that one secret that you can never share with anyone?
# Collins-Duffy | Norm: 0.326599 | Raw: 3.200000
# Moschitti | Norm: 0.596109 | Raw: 11.136000
#
# What are some places to shop cheap branded/good clothes, or beauty products/appliances in the Delhi NRC?
# I am at Delhi. What are some good places to enjoy with family members as well as for shopping?
# Collins-Duffy | Norm: 0.138675 | Raw: 0.800000
# Moschitti | Norm: 0.489578 | Raw: 5.664000
#
# What depression is?
# What is depression for you?
# Collins-Duffy | Norm: 0.516398 | Raw: 1.600000
# Moschitti | Norm: 0.496696 | Raw: 2.624000
#
# How do you write a question on Quora?
# Trying how to write a question on Quora?
# Collins-Duffy | Norm: 0.625000 | Raw: 4.000000
# Moschitti | Norm: 0.644011 | Raw: 7.072000
#
# How do I prepare for the CAT 2015 candidate?
# How do I prepare for CAT 16 from now?
# Collins-Duffy | Norm: 0.666667 | Raw: 4.800000
# Moschitti | Norm: 0.757130 | Raw: 8.128000
#
# What's the most annoying Quora bug?
# What are some notable bugs on Quora?
# Collins-Duffy | Norm: 0.308607 | Raw: 1.600000
# Moschitti | Norm: 0.435945 | Raw: 3.392000
#
# I love school but I have a 2.8 GPA after sophomore year. Can I still get into a good college?
# I have a 2.8 GPA but I love school and have a very strong work ethic. How can I get into a good college?
# Collins-Duffy | Norm: 0.758175 | Raw: 10.400000
# Moschitti | Norm: 0.842547 | Raw: 21.408000
#
# What federal branch ruled that the states were unconstitutional?
# Were "stop and frisk" policies ruled unconstitutional?
# Collins-Duffy | Norm: 0.235702 | Raw: 1.600000
# Moschitti | Norm: 0.452316 | Raw: 4.928000
#
# What do Thais think about Italy?
# What is the minimum mark for admission in govt medical colleges in west bengal?
# Collins-Duffy | Norm: 0.102062 | Raw: 0.800000
# Moschitti | Norm: 0.425147 | Raw: 6.176000
#
# How do I search for a roommate in Bangalore?
# How does one find a roommate in Bangalore?
# Collins-Duffy | Norm: 0.589256 | Raw: 4.000000
# Moschitti | Norm: 0.767893 | Raw: 10.912000
#
# My parents won't believe me about anything. How do I deal with this and why are they doing this?
# How effective are Byju's GMAT course material 150 hours? Which one is better Manhattan or Byju
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.243288 | Raw: 2.304000
#
# What will be the biggest web design trends for 2015?
# What are the big web design trends for 2013?
# Collins-Duffy | Norm: 0.632456 | Raw: 4.800000
# Moschitti | Norm: 0.695746 | Raw: 7.616000
#
# Why is Saltwater taffy candy imported in Germany?
# Why is saltwater Taffy candy imported in Canada?
# Collins-Duffy | Norm: 0.625000 | Raw: 4.000000
# Moschitti | Norm: 0.765625 | Raw: 7.840000
#
# How do you unjam a staple gun?
# How do I fix a jammed staple gun?
# Collins-Duffy | Norm: 0.668153 | Raw: 4.000000
# Moschitti | Norm: 0.760034 | Raw: 6.304000
#
# How do I suck it up and lose weight?
# How should one change their diet to lose weight?
# Collins-Duffy | Norm: 0.408248 | Raw: 2.400000
# Moschitti | Norm: 0.665481 | Raw: 7.776000
#
# Bank of India review?
# What are cool cakes? Is there any other word for them?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.197245 | Raw: 1.024000
#
# How do the Rebuild of Evangelion films compare to the original series?
# What are some of the best Evangelion AMVs?
# Collins-Duffy | Norm: 0.377964 | Raw: 3.200000
# Moschitti | Norm: 0.568704 | Raw: 7.808000
#
# Why do women have multiple orgasms and not men?
# Why can women have multiple orgasms and keep going while men can not?
# Collins-Duffy | Norm: 0.688530 | Raw: 6.400000
# Moschitti | Norm: 0.696172 | Raw: 11.776000
#
# What should I do to stop hair loss?
# How do I reduce hair loss problems naturally?
# Collins-Duffy | Norm: 0.375000 | Raw: 2.400000
# Moschitti | Norm: 0.499429 | Raw: 4.960000
#
# Will a new digital currency replace Bitcoin to be the mainstream?
# Which digital currency other than Bitcoin should a person buy and what is the rationale for your choice(s)?
# Collins-Duffy | Norm: 0.376889 | Raw: 4.000000
# Moschitti | Norm: 0.554407 | Raw: 11.424000
#
# If your girlfriend/wife says "Don't get me anything for Valentines Day", are there any men out there actually dumb enough to go home empty-handed?
# What are some things women think men like, but men actually don't?
# Collins-Duffy | Norm: 0.269191 | Raw: 4.000000
# Moschitti | Norm: 0.651671 | Raw: 22.944000
#
# Is time travel already possible on Earth?
# Is time travel still theorized as being possible?
# Collins-Duffy | Norm: 0.534522 | Raw: 3.200000
# Moschitti | Norm: 0.594166 | Raw: 5.760000
#
# What are the best laptops within 30000?
# Which is the best laptop model to buy within 30k?
# Collins-Duffy | Norm: 0.358569 | Raw: 2.400000
# Moschitti | Norm: 0.550538 | Raw: 5.984000
#
# Where can I find an online course for digital marketing?
# Which are the courses on Coursera or other MOOCs to study digital marketing?
# Collins-Duffy | Norm: 0.182574 | Raw: 1.600000
# Moschitti | Norm: 0.485816 | Raw: 7.232000
#
# When I wake up in the morning daily, my penis is erect and tight. Why does it happens? Does it happen to all the men?
# Why do I keep choking in my sleep?
# Collins-Duffy | Norm: 0.272166 | Raw: 1.600000
# Moschitti | Norm: 0.513435 | Raw: 5.696000
#
# What can be the Themes for a toastmasters meeting?
# How do I join the Toastmasters club of Delhi?
# Collins-Duffy | Norm: 0.111111 | Raw: 0.800000
# Moschitti | Norm: 0.432857 | Raw: 5.152000
#
# How do you scan a document to your computer?
# How do I scan documents into my computer?
# Collins-Duffy | Norm: 0.462910 | Raw: 2.400000
# Moschitti | Norm: 0.640026 | Raw: 4.960000
#
# What do you think about J. K. Rowling for having authored the 'Harry Potter series' on one hand and 'The Casual Vacancy' on the other?
# Has J.K Rowling copied some one else’s idea to construct the Harry Potter Series?
# Collins-Duffy | Norm: 0.198762 | Raw: 3.200000
# Moschitti | Norm: 0.477825 | Raw: 15.488000
#
# Can a person remember his past life?
# Can anyone remember past life?
# Collins-Duffy | Norm: 0.447214 | Raw: 1.600000
# Moschitti | Norm: 0.582259 | Raw: 2.880000
#
# Why is my hair turning blonde from a medium brown?
# Why does the hair on my body that sees the most sun turn blonde?
# Collins-Duffy | Norm: 0.188982 | Raw: 1.600000
# Moschitti | Norm: 0.471325 | Raw: 6.464000
#
# How do I legally use popular songs in youtube videos?
# How do you legally upload a karaoke version of a popular song on YouTube?
# Collins-Duffy | Norm: 0.316228 | Raw: 3.200000
# Moschitti | Norm: 0.616630 | Raw: 11.392000
#
# In what order should one swim, enter jacuzzi and have steam bath?
# What should I do after I take a steam bath?
# Collins-Duffy | Norm: 0.250000 | Raw: 2.400000
# Moschitti | Norm: 0.516646 | Raw: 8.288000
#
# Is there demand for AWS certification?
# Does it help managers to do AWS certification?
# Collins-Duffy | Norm: 0.288675 | Raw: 1.600000
# Moschitti | Norm: 0.485946 | Raw: 5.184000
#
# Why I am single?
# Why am I still single?
# Collins-Duffy | Norm: 0.894427 | Raw: 3.200000
# Moschitti | Norm: 0.852202 | Raw: 4.480000
#
# Where can I get ezpopsy dresses coupons online?
# Where can I buy ezpopsy dresses with coupons?
# Collins-Duffy | Norm: 0.625000 | Raw: 4.000000
# Moschitti | Norm: 0.738309 | Raw: 7.072000
#
# How we lose belly fat india?
# How can I lose body fat in my belly and chest?
# Collins-Duffy | Norm: 0.144338 | Raw: 0.800000
# Moschitti | Norm: 0.347190 | Raw: 2.848000
#
# Can we travel in time?
# Can we turn back time?
# Collins-Duffy | Norm: 0.600000 | Raw: 2.400000
# Moschitti | Norm: 0.693122 | Raw: 4.192000
#
# Which is a suitable solar panel installation provider near Atascadero, California CA?
# What is a suitable solar panel installation provider near Atascadero, California CA?
# Collins-Duffy | Norm: 0.916667 | Raw: 8.800000
# Moschitti | Norm: 0.939320 | Raw: 12.384000
#
# Why can't a body move faster than the speed of light?
# How do we know that nothing can travel faster than the speed of light?
# Collins-Duffy | Norm: 0.385758 | Raw: 4.000000
# Moschitti | Norm: 0.626679 | Raw: 12.704000
#
# Why is GATE less trodden path for NITians?
# How many iitians and nitians appear for Gate/ESE exam?
# Collins-Duffy | Norm: 0.133631 | Raw: 0.800000
# Moschitti | Norm: 0.453290 | Raw: 4.896000
#
# Can a person have more than one UAN (universal account number)?
# I have an NRI account. Can I avail more than one offer at a time?
# Collins-Duffy | Norm: 0.269680 | Raw: 1.600000
# Moschitti | Norm: 0.520844 | Raw: 4.928000
#
# Which are the best couse for financial modeling?
# Can lettuce cause diarrhea? If so, why and how can it be treated?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000
# Moschitti | Norm: 0.290095 | Raw: 2.048000
#
# I had sex 5 days after my period, what are the chances of being pregnant?
# My period was only 4 days had sex 5 days after period ended what is the possibility of me being pregnant?
# Collins-Duffy | Norm: 0.585018 | Raw: 6.400000
# Moschitti | Norm: 0.807883 | Raw: 23.296000
#
# What is your favorite pet? Why?
# What is your favorite pet photo?
# Collins-Duffy | Norm: 1.000000 | Raw: 1.600000
# Moschitti | Norm: 0.954521 | Raw: 2.624000
#
# Can neural networks take vector images (such as SVG) as input?
# Can neural networks output vector representations (such as SVG) of images?
# Collins-Duffy | Norm: 0.752618 | Raw: 7.200000
# Moschitti | Norm: 0.856952 | Raw: 19.744000
#
# Is LASIK (laser eye surgery) a repeatable operation? If not, what is the best age for surgery?
# Is there any limit (power range) for Lasik surgery for eye?
# Collins-Duffy | Norm: 0.294174 | Raw: 2.400000
# Moschitti | Norm: 0.657886 | Raw: 12.896000
#
# How can you reduce your alcohol consumption?
# How can I reduce my alcohol consumption?
# Collins-Duffy | Norm: 0.750000 | Raw: 2.400000
# Moschitti | Norm: 0.831081 | Raw: 3.936000
#
# Can heavy water be found at the bottom of the ocean?
# Is there more deuterated water at the bottom of an ocean or deep lake?
# Collins-Duffy | Norm: 0.518875 | Raw: 5.600000
# Moschitti | Norm: 0.684779 | Raw: 15.328000
#
# Which city/state in USA is best for a Textile Engineer to find a job?
# What is the best way to get an entry-level job as a biomedical engineer (MS) in the USA?
# Collins-Duffy | Norm: 0.440959 | Raw: 5.600000
# Moschitti | Norm: 0.708779 | Raw: 19.168000
