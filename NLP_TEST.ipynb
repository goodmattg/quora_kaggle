# %%
import pandas as pd
import numpy as np
from pycorenlp import StanfordCoreNLP 
import re, time, bisect, math
import TreeKernel as tk
import TreeBuild as tb

# %%
from gensim.models.keyedvectors import KeyedVectors
word_vectors = KeyedVectors.load_word2vec_format('./w2v_model/GoogleNews-vectors-negative300.bin', binary=True)  # C binary format

# %%
nlp = StanfordCoreNLP('http://localhost:9000')

# %%
def _getNLPToks_(rawSentence):
    output = nlp.annotate(rawSentence, properties={
      'annotators': 'tokenize,ssplit,pos,depparse,parse',
      'outputFormat': 'json'
      })
    return output['sentences'][0]['parse'].split("\n")

# %%
def _w2vSimilarity_(word1, word2, modelPtr):
    return modelPtr.similarity(word1, word2)

# %% [markdown]
# ## Test: Tree Generation and Collins-Duffy Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tb.tree()
tree_b2 = tb.tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
tb._generateTree_(toks_b1, tree_b1)
tb._generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
tb._flipTree_(tree_b1)
tb._flipTree_(tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = tk._CollinsDuffy_(tree_b1, tree_b2, 0.8, 1, 0)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kerne
print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# --- 0.07650089263916016 seconds ---
# --- 0.07787394523620605 seconds ---
# --- 0.07800984382629395 seconds ---
# --- 0.08410000801086426 seconds ---
# Raw Score: 0.8
# Norm Score: 0.124034734589

# %% [markdown]
# ## Test: Tree Generation and Moschitti PT Kernel

# %% [markdown]
# ## Test: Tree Kernels on Training Data

# %%
from random import randint

def read_data(path_to_file):
    df = pd.read_csv(path_to_file)
    print ("Shape of base training File = ", df.shape)
    # Remove missing values and duplicates from training data
    df.drop_duplicates(inplace=True)
    df.dropna(inplace=True)
    print("Shape of base training data after cleaning = ", df.shape)
    return df

df_train = read_data("input/train.csv")
# Out:
# Shape of base training File =  (404290, 6)
# Shape of base training data after cleaning =  (404288, 6)

# %%
## SET UP TEST INDICES TO SELECT RANDOM ROWS

TEST_SAMPLES = 100
indices = np.arange(TEST_SAMPLES)
for i in range(len(indices)):
    indices[i] = randint(0,df_train.shape[0])

# %%
start_time = time.time()

for ind in indices:
    
    tree_1 = tb.tree()
    tree_2 = tb.tree()

    toks_1 = _getNLPToks_(df_train.get_value(ind,'question1'))
    toks_2 = _getNLPToks_(df_train.get_value(ind,'question2'))

    # Generate a tree structure
    tb._generateTree_(toks_1, tree_1)
    tb._generateTree_(toks_2, tree_2)

    # Flip the trees
    tb._flipTree_(tree_1)
    tb._flipTree_(tree_2)

    
    print("%s\n%s" % (df_train.get_value(ind,'question1'), df_train.get_value(ind,'question2')))
    
    for lamb in [1]:
        (scoreRaw_cd, scoreNorm_cd) = tk._CollinsDuffy_(tree_1, tree_2, lamb, 1, 1)
        print("Collins-Duffy | Norm: %f | Raw: %f | Lambda: %3f" % (scoreNorm_cd, scoreRaw_cd, lamb))
    
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel
# Out:
# What are the treatments available for knee pain?
# What are the best treatments available for knee pain?
# Collins-Duffy | Norm: 0.942809 | Raw: 8.000000 | Lambda: 1.000000
# Is Shri Atal Bihari Vajpayee one of the best prime ministers of India? What has been his contribution to India? Does he really deserve the Bharat Ratna that was awarded to him, which, other prime ministers could or should have gotten, but didn't?
# Why is Atal Bihari Vajpayee considered one of the best Prime Ministers of India?
# Collins-Duffy | Norm: 0.710047 | Raw: 11.000000 | Lambda: 1.000000
# How close is the US to eliminating cash entirely and replacing it with electronic currency?
# What states in the US use currency other than the US dollar?
# Collins-Duffy | Norm: 0.322749 | Raw: 5.000000 | Lambda: 1.000000
# What should I do to get more answers of my questions from Quora?
# What can I do to assertively make my Quora question interesting enough to answer?
# Collins-Duffy | Norm: 0.322329 | Raw: 4.000000 | Lambda: 1.000000
# How do I write a high level (English) essay?
# I have to write an essay about myself. How should I begin (and end) the essay?
# Collins-Duffy | Norm: 0.353553 | Raw: 3.000000 | Lambda: 1.000000
# How many lock and key combinations are possible?
# What led to the modern day lock/key system?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# What did you learn from your life experiences?
# What are some important lesson you learn from your experiences?
# Collins-Duffy | Norm: 0.632456 | Raw: 4.000000 | Lambda: 1.000000
# What do plankton eat?
# Do plankton eat?
# Collins-Duffy | Norm: 0.577350 | Raw: 2.000000 | Lambda: 1.000000
# What determines a substance's specific heat capacity?
# What are the fundamental factors contributing to heat capacity?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# What happened to Rama's lineage after the death of Luv and Kush?
# What happened to that Dhobi (washerman) who was responsible for Lord Rama and Sita Mata's separation?
# Collins-Duffy | Norm: 0.403604 | Raw: 6.000000 | Lambda: 1.000000
# Why won't my iPod's screen turn on? How do I fix it?
# Why won't my iPod Touch 4G turn on? How do I fix it?
# Collins-Duffy | Norm: 0.894427 | Raw: 4.000000 | Lambda: 1.000000
# What are remedies to get rid of belly fat?
# How do I get rid of jelly belly?
# Collins-Duffy | Norm: 0.471405 | Raw: 4.000000 | Lambda: 1.000000
# Where can I get grappling mats in Australia?
# Where can I get various grappling mats in Australia?
# Collins-Duffy | Norm: 0.824958 | Raw: 7.000000 | Lambda: 1.000000
# What song plays over the end credits to the 2002 movie The Eye?
# What song plays over the end credits to the 2002 movie The Nugget?
# Collins-Duffy | Norm: 0.933333 | Raw: 14.000000 | Lambda: 1.000000
# Should hamsters eat popcorn?
# Can hamsters eat honey? Why or why not?
# Collins-Duffy | Norm: 0.500000 | Raw: 2.000000 | Lambda: 1.000000
# What is the best business model to follow in IOT?
# What is the best business model to follow?
# Collins-Duffy | Norm: 0.894427 | Raw: 8.000000 | Lambda: 1.000000
# How important is waking up early?
# How important is it to wake up early to be successful?
# Collins-Duffy | Norm: 0.452911 | Raw: 4.000000 | Lambda: 1.000000
# Being an IT project manager or a quality manager focusing on Agile precess set up with in the organization, which one is more valuable for my career?
# I'm developing a new management consulting practice, which does for management in general what agile does for project management. Who are the most progressive management consulting groups to talk with about partnering?
# Collins-Duffy | Norm: 0.210819 | Raw: 6.000000 | Lambda: 1.000000
# How would you spend your last 24 hours that you had to live?
# How would you spend the last 24 hours in your life?
# Collins-Duffy | Norm: 0.502519 | Raw: 5.000000 | Lambda: 1.000000
# What are tips for saving money?
# What are the best methods of saving money?
# Collins-Duffy | Norm: 0.577350 | Raw: 4.000000 | Lambda: 1.000000
# Why do so many people want to know about Jake Williams’ thoughts on certain issues?
# Why are there so many questions about Jake Wiliams?
# Collins-Duffy | Norm: 0.416667 | Raw: 5.000000 | Lambda: 1.000000
# How do I really make money online?
# How can I make money online for free?
# Collins-Duffy | Norm: 0.534522 | Raw: 4.000000 | Lambda: 1.000000
# Why don't people search on Google before posting it on Quora?
# Why don't Quora users simply use Google first before asking a question?
# Collins-Duffy | Norm: 0.444750 | Raw: 6.000000 | Lambda: 1.000000
# What is the best thing any one has ever done for you?
# What is the best thing someone has done for you?
# Collins-Duffy | Norm: 0.821584 | Raw: 9.000000 | Lambda: 1.000000
# Who is most reachest Bollywood actor?
# Who is the most over-rated Bollywood actor/actress?
# Collins-Duffy | Norm: 0.547723 | Raw: 3.000000 | Lambda: 1.000000
# Why can't government freely print and distribute money to eradicate poverty?
# What is the mechanism to print currency in the country? How much currency can a country print at a time?
# Collins-Duffy | Norm: 0.083333 | Raw: 1.000000 | Lambda: 1.000000
# What's the difference between an MBA, an MMS and a PGDM?
# What is the difference between an MMS degree and an MBA degree?
# Collins-Duffy | Norm: 0.734968 | Raw: 11.000000 | Lambda: 1.000000
# What individuals and events in history are a source of pride for Egypt?
# What individuals and events in history are a source of pride for Iraq?
# Collins-Duffy | Norm: 0.923077 | Raw: 12.000000 | Lambda: 1.000000
# How do I get more traffic on my website?
# How do I generate more traffic to my blog?
# Collins-Duffy | Norm: 0.714286 | Raw: 5.000000 | Lambda: 1.000000
# Do you think atheists are more immoral?
# Why do some theists say atheists are immoral?
# Collins-Duffy | Norm: 0.400892 | Raw: 3.000000 | Lambda: 1.000000
# How do you see the future of IT industry in India?
# What is the future of the IT sector in India?
# Collins-Duffy | Norm: 0.522233 | Raw: 6.000000 | Lambda: 1.000000
# What are the best ways to lose weight fast?
# How can someone lose weight quickly?
# Collins-Duffy | Norm: 0.272166 | Raw: 2.000000 | Lambda: 1.000000
# How can you create invoice and shipment automatically in Magento 2?
# How do I install Magento extension in 2.1.2?
# Collins-Duffy | Norm: 0.319801 | Raw: 3.000000 | Lambda: 1.000000
# How do I deal with a person that tells the same divorce story from 30 years ago over and over?
# How do I set boundaries and earn respect from people that get too comfortable with me over time because I am a friendly and open person by nature?
# Collins-Duffy | Norm: 0.489956 | Raw: 13.000000 | Lambda: 1.000000
# Can a 40-year-old date a 20-year-old?
# Should a 21 year-old woman try dating a 40 year-old man?
# Collins-Duffy | Norm: 0.596285 | Raw: 4.000000 | Lambda: 1.000000
# What Android phones will support Bluetooth low energy?
# Which is the best low cost Android phone?
# Collins-Duffy | Norm: 0.250000 | Raw: 2.000000 | Lambda: 1.000000
# What is a bigger franchise universe: Harry Potter or Star Wars?
# Who would win in a war between the wizards of the Harry Potter universe and the military?
# Collins-Duffy | Norm: 0.251478 | Raw: 4.000000 | Lambda: 1.000000
# What is the salary of an Indian foreign service officer?
# What will be the salary of Indian Foreign Service Officer(A) according to 7 cpc?
# Collins-Duffy | Norm: 0.326599 | Raw: 4.000000 | Lambda: 1.000000
# Why do people hate criticism on themselves?
# Why do people hate constructive criticism?
# Collins-Duffy | Norm: 0.771517 | Raw: 5.000000 | Lambda: 1.000000
# What are some laws that should be made to control the high levels of animal trafficking in Fiji?
# What are some laws that should be made to control the high levels of animal trafficking in India?
# Collins-Duffy | Norm: 0.944444 | Raw: 17.000000 | Lambda: 1.000000
# Is MacBook pro 2016 too pricey or is it worth it?
# Will upgrading to the 2016 MacBook Pro be worth it?
# Collins-Duffy | Norm: 0.350823 | Raw: 4.000000 | Lambda: 1.000000
# What is the best email verifier tool?
# What is the best email marketing tool?
# Collins-Duffy | Norm: 0.857143 | Raw: 6.000000 | Lambda: 1.000000
# What would be the best way to quit smoking?
# What else should I do to quit smoking?
# Collins-Duffy | Norm: 0.471405 | Raw: 4.000000 | Lambda: 1.000000
# How do Seiko watches compare to other watch brands?
# What do you first look out for when getting a watch other than the brand and the price?
# Collins-Duffy | Norm: 0.223607 | Raw: 3.000000 | Lambda: 1.000000
# Leave aside beef is it proper to kill and eat any animal or creature or whatsoever? If there is an issue eating beef why not for chicken or pork? Life is the same...
# How did chicken, beef and pork emerge as the standard meats?
# Collins-Duffy | Norm: 0.142134 | Raw: 2.000000 | Lambda: 1.000000
# How do I say happy birthday to myself?
# How do you say "happy birthday" in Spanish?
# Collins-Duffy | Norm: 0.433013 | Raw: 3.000000 | Lambda: 1.000000
# What is the real mean of life?
# What is the main motto of human life?
# Collins-Duffy | Norm: 0.668153 | Raw: 5.000000 | Lambda: 1.000000
# How do I burn a dvd movie using windows 10? (PLEASE read description before answering)
# What are High pitch Bollywood music songs?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# What is the theme of website mangobaaz.com?
# What is the theme of website parhlo.com?
# Collins-Duffy | Norm: 0.857143 | Raw: 6.000000 | Lambda: 1.000000
# What are the onsite salaries in Indian IT companies?
# Which Indian IT companies have Non US clients and onsite for the same?
# Collins-Duffy | Norm: 0.369800 | Raw: 4.000000 | Lambda: 1.000000
# In Cognizant, If I switch from ITIS to Development should I undergo PAT training and clear the assessments?
# Can I move from itis to development?
# Collins-Duffy | Norm: 0.338062 | Raw: 4.000000 | Lambda: 1.000000
# On Roku, can I get network channels (ABC, ABC Family, NBC, CBS, FOX, CW) and view full episodes of current shows? Is it free or only through subscription services like HuluPlus?
# How can I watch TV Channels on Roku?
# Collins-Duffy | Norm: 0.158114 | Raw: 2.000000 | Lambda: 1.000000
# How can you best describe Adolf Hitler?
# What was best in Adolf Hitler?
# Collins-Duffy | Norm: 0.308607 | Raw: 2.000000 | Lambda: 1.000000
# How do you clean dirty Kraftmaid cabinets?
# What is the best way to clean KraftMaid cabinets?
# Collins-Duffy | Norm: 0.251976 | Raw: 2.000000 | Lambda: 1.000000
# Does one need OOP concept to understand / master MVC?
# How do I master C++ OOPS concepts?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# How do I solve [math] \displaystyle \int x\ln(x + 1)\,dx[/math]?
# How can this be solved  [math] \int xsin^{-1}(x) \ dx [/math]?
# Collins-Duffy | Norm: 0.455842 | Raw: 4.000000 | Lambda: 1.000000
# What is the correct time to take green tea for weight loss?
# Will I lose weight if I drink every day 2 cups of green tea for about 2 weeks?
# Collins-Duffy | Norm: 0.246183 | Raw: 4.000000 | Lambda: 1.000000
# Why did the former USSR let Germany unite, while the U.S. has kept Korea divided?
# Why did USSR let Germany unite and the U.S. has kept Korea divided?
# Collins-Duffy | Norm: 0.874475 | Raw: 13.000000 | Lambda: 1.000000
# Can animal cell be made out of clay?
# Can one be a child prodigy of political science and history?
# Collins-Duffy | Norm: 0.319801 | Raw: 3.000000 | Lambda: 1.000000
# Which video game franchise is more critically acclaimed: Halo or Uncharted?
# Which video game franchise has won more awards, halo or uncharted? Also which franchise has been more acclaimed?
# Collins-Duffy | Norm: 0.454545 | Raw: 5.000000 | Lambda: 1.000000
# Do employees at G&K Services have a good work-life balance? Does this differ across positions and departments?
# Do employees at Matrix Service have a good work-life balance? Does this differ across positions and departments?
# Collins-Duffy | Norm: 0.866025 | Raw: 6.000000 | Lambda: 1.000000
# What are the best business school to do MBA?
# What are the Best business schools for an MBA?
# Collins-Duffy | Norm: 0.555556 | Raw: 5.000000 | Lambda: 1.000000
# What is the story behind chanakya's death?
# What is the mystery of chanakya's death?
# Collins-Duffy | Norm: 0.750000 | Raw: 6.000000 | Lambda: 1.000000
# Who won the 2015–16 NBA championship?
# Who won the 1999 NBA championship?
# Collins-Duffy | Norm: 0.771517 | Raw: 5.000000 | Lambda: 1.000000
# Most of people passing government exams belong to meena or Kumar community how can this happen?
# What are your thoughts on Equidistant Letter Sequences (ELS codes) that are found in the Bible?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# According to the Albert Einstine the gravity is due to curvature of mass in the space time fabric what force make the curvature?
# Why do objects with mass warp space-time?
# Collins-Duffy | Norm: 0.065372 | Raw: 1.000000 | Lambda: 1.000000
# What is the internet speed at bits?
# What is your internet speed?
# Collins-Duffy | Norm: 0.534522 | Raw: 2.000000 | Lambda: 1.000000
# I typed a long draft closed whatsapp for a second to check something went back and the draft was gone?
# How can I generate a sine wave from an audio input?
# Collins-Duffy | Norm: 0.184637 | Raw: 3.000000 | Lambda: 1.000000
# Which country is most likely to trigger WW3?
# So as of now, who is most likely to start a MAJOR world war?
# Collins-Duffy | Norm: 0.377964 | Raw: 4.000000 | Lambda: 1.000000
# How do I filter out US election news in my Quora feed?
# How do I filter out US elections in my Quora feed?
# Collins-Duffy | Norm: 0.824958 | Raw: 7.000000 | Lambda: 1.000000
# Ashlee Vance: What is Elon Musk's idea of enjoyment?
# Ashlee Vance: What is Elon Musk afraid of?
# Collins-Duffy | Norm: 0.782624 | Raw: 7.000000 | Lambda: 1.000000
# Most of us are never going to be famous. I'm miserable with this realization. What is the alternative to fame?
# My present roommate at first asked about sharing the room next year also to which I said yes(he refused another person in doing so).But of late I realized that sharing the room with tim further would cause problems because he mostly remains away and added to that has some addictions seeing this I now refused to be with him and this now (unexpectedly) fills me with guilt and remorse although he is perfectly as before what should I do plz help?
# Collins-Duffy | Norm: 0.071067 | Raw: 1.000000 | Lambda: 1.000000
# As technology is growing day by day, what according to you didn't got online?
# What were some of the things you didn't know were fun/possible until you got rich?
# Collins-Duffy | Norm: 0.278207 | Raw: 5.000000 | Lambda: 1.000000
# What is the size of a profile photo on Instagram?
# What is the maximum file size on Instagram?
# Collins-Duffy | Norm: 0.670820 | Raw: 6.000000 | Lambda: 1.000000
# I watched Game of Thrones and just completed Suits. Which is a good TV series that I can watch if I liked GOT and Suits?
# What are some recommended TV series if I like Game of Thrones and Suits?
# Collins-Duffy | Norm: 0.534522 | Raw: 6.000000 | Lambda: 1.000000
# Do you'll think World War 3 will happen and why?
# When would the World War III break out?
# Collins-Duffy | Norm: 0.213201 | Raw: 2.000000 | Lambda: 1.000000
# What do you think are the qualities of a good leader?
# What are the best ways to be an effective leader?
# Collins-Duffy | Norm: 0.381385 | Raw: 4.000000 | Lambda: 1.000000
# What do you think about Israeli-Palestinian conflict?
# Can you express your opinion about the Israeli-Palestinian Conflict here?
# Collins-Duffy | Norm: 0.365148 | Raw: 2.000000 | Lambda: 1.000000
# How do you earn emergency money?
# How do you create an emergency fund?
# Collins-Duffy | Norm: 0.617213 | Raw: 4.000000 | Lambda: 1.000000
# What are non living things?
# What are non living things? Can they grow?
# Collins-Duffy | Norm: 1.000000 | Raw: 5.000000 | Lambda: 1.000000
# What are some good paying jobs for a 12 year old?
# What are the best jobs for 13 year olds?
# Collins-Duffy | Norm: 0.502519 | Raw: 5.000000 | Lambda: 1.000000
# Why was alcohol prohibited in the United States?
# What were the motives behind alcohol prohibition in the United States?
# Collins-Duffy | Norm: 0.588348 | Raw: 6.000000 | Lambda: 1.000000
# Was the Taj Mahal originally an ancient Hindu temple?
# Taj mahal is tejo mahalaya ancient shiva temple?
# Collins-Duffy | Norm: 0.353553 | Raw: 3.000000 | Lambda: 1.000000
# What is the first letter of a four letter word meaning "to grow light as the sun rises?
# What 11 letter word means a stinky smell?
# Collins-Duffy | Norm: 0.301511 | Raw: 4.000000 | Lambda: 1.000000
# What's the starting salary for a person with an ACCA degree in UAE?
# Which is most worth it: doing an MBA after getting a CA degree or the ACCA?
# Collins-Duffy | Norm: 0.267261 | Raw: 4.000000 | Lambda: 1.000000
# Does Donald Trump really want tobe President?
# Does Donald Trump really want to be president, or is it just an act to stay in the limelight?
# Collins-Duffy | Norm: 0.412393 | Raw: 5.000000 | Lambda: 1.000000
# Are spacetime and the superfluid dark matter the same 'stuff'?
# Does superfluid dark matter ripple when galaxy clusters collide and wave in double slit experiments?
# Collins-Duffy | Norm: 0.311400 | Raw: 4.000000 | Lambda: 1.000000
# How do you make ≠ (not equal) sign on keyboard?
# How do you make the cent sign on your keyboard?
# Collins-Duffy | Norm: 0.707107 | Raw: 6.000000 | Lambda: 1.000000
# What was the purpose of J.J. Thomson's cathode ray tube experiments? What did they accomplish?
# What should be the name of fresher party for chemical engineering?
# Collins-Duffy | Norm: 0.301511 | Raw: 3.000000 | Lambda: 1.000000
# Why is Hillary Clinton a better choice than Donald Trump?
# How is Hillary Clinton a better choice than Donald Trump?
# Collins-Duffy | Norm: 0.900000 | Raw: 9.000000 | Lambda: 1.000000
# What is the Sahara, and how do the average temperatures there compare to the ones in the Gibson Desert?
# What is the Sahara, and how do the average temperatures there compare to other deserts?
# Collins-Duffy | Norm: 0.827653 | Raw: 19.000000 | Lambda: 1.000000
# What are the differences in life between Chinese and western cultures?
# What are the biggest differences between Chinese culture and western culture?
# Collins-Duffy | Norm: 0.668994 | Raw: 8.000000 | Lambda: 1.000000
# What are the best recipes for crab stuffed salmon?
# What is a good recipe for salmon?
# Collins-Duffy | Norm: 0.377964 | Raw: 3.000000 | Lambda: 1.000000
# Is Iran an enemy or an ally to the USA?
# Why does the USA always have to have an enemy?
# Collins-Duffy | Norm: 0.547723 | Raw: 6.000000 | Lambda: 1.000000
# Are participants in stage hypnosis part of the show?
# Is Stage Hypnosis different from Hypnosis (in general) or Hypnotherapy?
# Collins-Duffy | Norm: 0.096225 | Raw: 1.000000 | Lambda: 1.000000
# How do I get over the girl blamed me for everything before she dump me, changed address and number, got dumped 1 month before wedding?
# I dated a girl for around 1.6 years. Before me, she had 3 boyfriends, and after dumping me, she made a new boyfriend within few months. How can someone move on so quickly?
# Collins-Duffy | Norm: 0.196960 | Raw: 3.000000 | Lambda: 1.000000
# Why do people write questions on Quora that could be answered with a quick web search?
# Why don't many people posting questions on Quora check Google first?
# Collins-Duffy | Norm: 0.360844 | Raw: 5.000000 | Lambda: 1.000000
# How can I effectively lose belly fat?
# What is the best way to lose belly fat? (workout, natural remedies and pills)
# Collins-Duffy | Norm: 0.251976 | Raw: 2.000000 | Lambda: 1.000000
# What are some examples of easy similes?
# What are examples of similes?
# Collins-Duffy | Norm: 0.845154 | Raw: 5.000000 | Lambda: 1.000000
# Did the Romans have a religion before adopting that of the Greeks? What was it?
# Were the Greek/Roman gods depicted as fair?
# Collins-Duffy | Norm: 0.239046 | Raw: 2.000000 | Lambda: 1.000000
# --- 4.614718198776245 seconds ---

# %%
import pickle

# with open('filename.pickle', 'wb') as handle:
#     pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('filename.pickle', 'rb') as handle:
#     b = pickle.load(handle)

# print a == b

import json, os
with open('testoutput', 'ab') as fout:
    count = 0
    for row in df_train.iterrows():
        count+=1
        if count > 100:
            break
    
        tree_1 = tb.tree()
        tree_2 = tb.tree()
        
        print(row)

        print(row[1]['question1'])
        print(row[1]['question2'])
        
        toks_1 = _getNLPToks_(row[1]['question1'])
        toks_2 = _getNLPToks_(row[1]['question2'])

        # Generate a tree structure
        tb._generateTree_(toks_1, tree_1)
        tb._generateTree_(toks_2, tree_2)

        # Flip the trees
        tb._flipTree_(tree_1)
        tb._flipTree_(tree_2)

        tmp = {'q1':tree_1, 'q2':tree_2}

        pickle.dump(tmp, fout, protocol=pickle.HIGHEST_PROTOCOL)
        
        tree_1.clear()
        tree_2.clear()
# Out:
# (0, id                                                              0
# qid1                                                            1
# qid2                                                            2
# question1       What is the step by step guide to invest in sh...
# question2       What is the step by step guide to invest in sh...
# is_duplicate                                                    0
# Name: 0, dtype: object)
# What is the step by step guide to invest in share market in india?
# What is the step by step guide to invest in share market?
# (1, id                                                              1
# qid1                                                            3
# qid2                                                            4
# question1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# question2       What would happen if the Indian government sto...
# is_duplicate                                                    0
# Name: 1, dtype: object)
# What is the story of Kohinoor (Koh-i-Noor) Diamond?
# What would happen if the Indian government stole the Kohinoor (Koh-i-Noor) diamond back?
# (2, id                                                              2
# qid1                                                            5
# qid2                                                            6
# question1       How can I increase the speed of my internet co...
# question2       How can Internet speed be increased by hacking...
# is_duplicate                                                    0
# Name: 2, dtype: object)
# How can I increase the speed of my internet connection while using a VPN?
# How can Internet speed be increased by hacking through DNS?
# (3, id                                                              3
# qid1                                                            7
# qid2                                                            8
# question1       Why am I mentally very lonely? How can I solve...
# question2       Find the remainder when [math]23^{24}[/math] i...
# is_duplicate                                                    0
# Name: 3, dtype: object)
# Why am I mentally very lonely? How can I solve it?
# Find the remainder when [math]23^{24}[/math] is divided by 24,23?
# (4, id                                                              4
# qid1                                                            9
# qid2                                                           10
# question1       Which one dissolve in water quikly sugar, salt...
# question2                 Which fish would survive in salt water?
# is_duplicate                                                    0
# Name: 4, dtype: object)
# Which one dissolve in water quikly sugar, salt, methane and carbon di oxide?
# Which fish would survive in salt water?
# (5, id                                                              5
# qid1                                                           11
# qid2                                                           12
# question1       Astrology: I am a Capricorn Sun Cap moon and c...
# question2       I'm a triple Capricorn (Sun, Moon and ascendan...
# is_duplicate                                                    1
# Name: 5, dtype: object)
# Astrology: I am a Capricorn Sun Cap moon and cap rising...what does that say about me?
# I'm a triple Capricorn (Sun, Moon and ascendant in Capricorn) What does this say about me?
# (6, id                                                              6
# qid1                                                           13
# qid2                                                           14
# question1                                     Should I buy tiago?
# question2       What keeps childern active and far from phone ...
# is_duplicate                                                    0
# Name: 6, dtype: object)
# Should I buy tiago?
# What keeps childern active and far from phone and video games?
# (7, id                                                      7
# qid1                                                   15
# qid2                                                   16
# question1                  How can I be a good geologist?
# question2       What should I do to be a great geologist?
# is_duplicate                                            1
# Name: 7, dtype: object)
# How can I be a good geologist?
# What should I do to be a great geologist?
# (8, id                                                  8
# qid1                                               17
# qid2                                               18
# question1             When do you use シ instead of し?
# question2       When do you use "&" instead of "and"?
# is_duplicate                                        0
# Name: 8, dtype: object)
# When do you use シ instead of し?
# When do you use "&" instead of "and"?
# (9, id                                                              9
# qid1                                                           19
# qid2                                                           20
# question1       Motorola (company): Can I hack my Charter Moto...
# question2       How do I hack Motorola DCX3400 for free internet?
# is_duplicate                                                    0
# Name: 9, dtype: object)
# Motorola (company): Can I hack my Charter Motorolla DCX3400?
# How do I hack Motorola DCX3400 for free internet?
# (10, id                                                             10
# qid1                                                           21
# qid2                                                           22
# question1       Method to find separation of slits using fresn...
# question2       What are some of the things technicians can te...
# is_duplicate                                                    0
# Name: 10, dtype: object)
# Method to find separation of slits using fresnel biprism?
# What are some of the things technicians can tell about the durability and reliability of Laptops and its components?
# (11, id                                                       11
# qid1                                                     23
# qid2                                                     24
# question1       How do I read and find my YouTube comments?
# question2            How can I see all my Youtube comments?
# is_duplicate                                              1
# Name: 11, dtype: object)
# How do I read and find my YouTube comments?
# How can I see all my Youtube comments?
# (12, id                                                   12
# qid1                                                 25
# qid2                                                 26
# question1          What can make Physics easy to learn?
# question2       How can you make physics easy to learn?
# is_duplicate                                          1
# Name: 12, dtype: object)
# What can make Physics easy to learn?
# How can you make physics easy to learn?
# (13, id                                                       13
# qid1                                                     27
# qid2                                                     28
# question1       What was your first sexual experience like?
# question2            What was your first sexual experience?
# is_duplicate                                              1
# Name: 13, dtype: object)
# What was your first sexual experience like?
# What was your first sexual experience?
# (14, id                                                             14
# qid1                                                           29
# qid2                                                           30
# question1       What are the laws to change your status from a...
# question2       What are the laws to change your status from a...
# is_duplicate                                                    0
# Name: 14, dtype: object)
# What are the laws to change your status from a student visa to a green card in the US, how do they compare to the immigration laws in Canada?
# What are the laws to change your status from a student visa to a green card in the US? How do they compare to the immigration laws in Japan?
# (15, id                                                             15
# qid1                                                           31
# qid2                                                           32
# question1       What would a Trump presidency mean for current...
# question2       How will a Trump presidency affect the student...
# is_duplicate                                                    1
# Name: 15, dtype: object)
# What would a Trump presidency mean for current international master’s students on an F1 visa?
# How will a Trump presidency affect the students presently in US or planning to study in US?
# (16, id                                         16
# qid1                                       33
# qid2                                       34
# question1        What does manipulation mean?
# question2       What does manipulation means?
# is_duplicate                                1
# Name: 16, dtype: object)
# What does manipulation mean?
# What does manipulation means?
# (17, id                                                             17
# qid1                                                           35
# qid2                                                           36
# question1       Why do girls want to be friends with the guy t...
# question2                How do guys feel after rejecting a girl?
# is_duplicate                                                    0
# Name: 17, dtype: object)
# Why do girls want to be friends with the guy they reject?
# How do guys feel after rejecting a girl?
# (18, id                                                             18
# qid1                                                           37
# qid2                                                           38
# question1       Why are so many Quora users posting questions ...
# question2       Why do people ask Quora questions which can be...
# is_duplicate                                                    1
# Name: 18, dtype: object)
# Why are so many Quora users posting questions that are readily answered on Google?
# Why do people ask Quora questions which can be answered easily by Google?
# (19, id                                                             19
# qid1                                                           39
# qid2                                                           40
# question1       Which is the best digital marketing institutio...
# question2       Which is the best digital marketing institute ...
# is_duplicate                                                    0
# Name: 19, dtype: object)
# Which is the best digital marketing institution in banglore?
# Which is the best digital marketing institute in Pune?
# (20, id                                                       20
# qid1                                                     41
# qid2                                                     42
# question1                        Why do rockets look white?
# question2       Why are rockets and boosters painted white?
# is_duplicate                                              1
# Name: 20, dtype: object)
# Why do rockets look white?
# Why are rockets and boosters painted white?
# (21, id                                                            21
# qid1                                                          43
# qid2                                                          44
# question1                  What's causing someone to be jealous?
# question2       What can I do to avoid being jealous of someone?
# is_duplicate                                                   0
# Name: 21, dtype: object)
# What's causing someone to be jealous?
# What can I do to avoid being jealous of someone?
# (22, id                                                           22
# qid1                                                         45
# qid2                                                         46
# question1       What are the questions should not ask on Quora?
# question2                 Which question should I ask on Quora?
# is_duplicate                                                  0
# Name: 22, dtype: object)
# What are the questions should not ask on Quora?
# Which question should I ask on Quora?
# (23, id                                                             23
# qid1                                                           47
# qid2                                                           48
# question1                                How much is 30 kV in HP?
# question2       Where can I find a conversion chart for CC to ...
# is_duplicate                                                    0
# Name: 23, dtype: object)
# How much is 30 kV in HP?
# Where can I find a conversion chart for CC to horsepower?
# (24, id                                                             24
# qid1                                                           49
# qid2                                                           50
# question1       What does it mean that every time I look at th...
# question2        How many times a day do a clock’s hands overlap?
# is_duplicate                                                    0
# Name: 24, dtype: object)
# What does it mean that every time I look at the clock the numbers are the same?
# How many times a day do a clock’s hands overlap?
# (25, id                                                             25
# qid1                                                           51
# qid2                                                           52
# question1       What are some tips on making it through the jo...
# question2       What are some tips on making it through the jo...
# is_duplicate                                                    0
# Name: 25, dtype: object)
# What are some tips on making it through the job interview process at Medicines?
# What are some tips on making it through the job interview process at Foundation Medicine?
# (26, id                                                  26
# qid1                                                53
# qid2                                                54
# question1                     What is web application?
# question2       What is the web application framework?
# is_duplicate                                         0
# Name: 26, dtype: object)
# What is web application?
# What is the web application framework?
# (27, id                                                             27
# qid1                                                           55
# qid2                                                           56
# question1       Does society place too much importance on sports?
# question2                How do sports contribute to the society?
# is_duplicate                                                    0
# Name: 27, dtype: object)
# Does society place too much importance on sports?
# How do sports contribute to the society?
# (28, id                                                     28
# qid1                                                   57
# qid2                                                   58
# question1          What is best way to make money online?
# question2       What is best way to ask for money online?
# is_duplicate                                            0
# Name: 28, dtype: object)
# What is best way to make money online?
# What is best way to ask for money online?
# (29, id                                                             29
# qid1                                                           59
# qid2                                                           60
# question1                  How should I prepare for CA final law?
# question2       How one should know that he/she completely pre...
# is_duplicate                                                    1
# Name: 29, dtype: object)
# How should I prepare for CA final law?
# How one should know that he/she completely prepare for CA final exam?
# (30, id                                                           30
# qid1                                                         61
# qid2                                                         62
# question1         What's one thing you would like to do better?
# question2       What's one thing you do despite knowing better?
# is_duplicate                                                  0
# Name: 30, dtype: object)
# What's one thing you would like to do better?
# What's one thing you do despite knowing better?
# (31, id                                                             31
# qid1                                                           63
# qid2                                                           64
# question1       What are some special cares for someone with a...
# question2       How can I keep my nose from getting stuffy at ...
# is_duplicate                                                    1
# Name: 31, dtype: object)
# What are some special cares for someone with a nose that gets stuffy during the night?
# How can I keep my nose from getting stuffy at night?
# (32, id                                                             32
# qid1                                                           65
# qid2                                                           66
# question1       What Game of Thrones villain would be the most...
# question2       What Game of Thrones villain would you most li...
# is_duplicate                                                    1
# Name: 32, dtype: object)
# What Game of Thrones villain would be the most likely to give you mercy?
# What Game of Thrones villain would you most like to be at the mercy of?
# (33, id                                                             33
# qid1                                                           67
# qid2                                                           68
# question1       Does the United States government still blackl...
# question2       How is the average speed of gas molecules dete...
# is_duplicate                                                    0
# Name: 33, dtype: object)
# Does the United States government still blacklist (employment, etc.) some United States citizens because their political views?
# How is the average speed of gas molecules determined?
# (34, id                                                     34
# qid1                                                   69
# qid2                                                   70
# question1       What is the best travel website in spain?
# question2                What is the best travel website?
# is_duplicate                                            0
# Name: 34, dtype: object)
# What is the best travel website in spain?
# What is the best travel website?
# (35, id                                                             35
# qid1                                                           71
# qid2                                                           72
# question1       Why do some people think Obama will try to tak...
# question2       Has there been a gun control initiative to tak...
# is_duplicate                                                    0
# Name: 35, dtype: object)
# Why do some people think Obama will try to take their guns away?
# Has there been a gun control initiative to take away guns people already own?
# (36, id                                                             36
# qid1                                                           73
# qid2                                                           74
# question1       I'm a 19-year-old. How can I improve my skills...
# question2       I am a 19 year old guy. How can I become a bil...
# is_duplicate                                                    0
# Name: 36, dtype: object)
# I'm a 19-year-old. How can I improve my skills or what should I do to become an entrepreneur in the next few years?
# I am a 19 year old guy. How can I become a billionaire in the next 10 years?
# (37, id                                                             37
# qid1                                                           75
# qid2                                                           76
# question1       When a girlfriend asks her boyfriend "Why did ...
# question2       My girlfriend said that we should end this bec...
# is_duplicate                                                    0
# Name: 37, dtype: object)
# When a girlfriend asks her boyfriend "Why did you choose me? What makes you want to be with me?", what should one reply to her?
# My girlfriend said that we should end this because she is confused about her feelings for me. I wished her well and disconnected. Should I call her and ask her if she wants to get back together?
# (38, id                                               38
# qid1                                             77
# qid2                                             78
# question1               How do we prepare for UPSC?
# question2       How do I prepare for civil service?
# is_duplicate                                      1
# Name: 38, dtype: object)
# How do we prepare for UPSC?
# How do I prepare for civil service?
# (39, id                                                             39
# qid1                                                           79
# qid2                                                           80
# question1       What is the stall speed and AOA of an f-14 wit...
# question2       Why did aircraft stop using variable-sweep win...
# is_duplicate                                                    0
# Name: 39, dtype: object)
# What is the stall speed and AOA of an f-14 with wings fully swept back?
# Why did aircraft stop using variable-sweep wings, like those on an F-14?
# (40, id                                             40
# qid1                                           81
# qid2                                           82
# question1                     Why do Slavs squat?
# question2       Will squats make my legs thicker?
# is_duplicate                                    0
# Name: 40, dtype: object)
# Why do Slavs squat?
# Will squats make my legs thicker?
# (41, id                                                             41
# qid1                                                           83
# qid2                                                           84
# question1       When can I expect my Cognizant confirmation mail?
# question2          When can I expect Cognizant confirmation mail?
# is_duplicate                                                    0
# Name: 41, dtype: object)
# When can I expect my Cognizant confirmation mail?
# When can I expect Cognizant confirmation mail?
# (42, id                                                     42
# qid1                                                   85
# qid2                                                   86
# question1       Can I make 50,000 a month by day trading?
# question2       Can I make 30,000 a month by day trading?
# is_duplicate                                            0
# Name: 42, dtype: object)
# Can I make 50,000 a month by day trading?
# Can I make 30,000 a month by day trading?
# (43, id                                                             43
# qid1                                                           87
# qid2                                                           88
# question1       Is being a good kid and not being a rebel wort...
# question2                          Is being bored good for a kid?
# is_duplicate                                                    0
# Name: 43, dtype: object)
# Is being a good kid and not being a rebel worth it in the long run?
# Is being bored good for a kid?
# (44, id                                                             44
# qid1                                                           89
# qid2                                                           90
# question1       What universities does Rexnord recruit new gra...
# question2       What universities does B&G Foods recruit new g...
# is_duplicate                                                    0
# Name: 44, dtype: object)
# What universities does Rexnord recruit new grads from? What majors are they looking for?
# What universities does B&G Foods recruit new grads from? What majors are they looking for?
# (45, id                                                             45
# qid1                                                           91
# qid2                                                           92
# question1       What is the quickest way to increase Instagram...
# question2       How can we increase our number of Instagram fo...
# is_duplicate                                                    0
# Name: 45, dtype: object)
# What is the quickest way to increase Instagram followers?
# How can we increase our number of Instagram followers?
# (46, id                                                             46
# qid1                                                           93
# qid2                                                           94
# question1       How did Darth Vader fought Darth Maul in Star ...
# question2       Does Quora have a character limit for profile ...
# is_duplicate                                                    0
# Name: 46, dtype: object)
# How did Darth Vader fought Darth Maul in Star Wars Legends?
# Does Quora have a character limit for profile descriptions?
# (47, id                                                             47
# qid1                                                           95
# qid2                                                           96
# question1       What are the stages of breaking up between cou...
# question2       Who is affected more by a breakup, the boy or ...
# is_duplicate                                                    0
# Name: 47, dtype: object)
# What are the stages of breaking up between couple? I mean, what happens after the breaking up emotionally whether its a male or female?
# Who is affected more by a breakup, the boy or the girl?
# (48, id                                                             48
# qid1                                                           97
# qid2                                                           98
# question1       What are some examples of products that can be...
# question2       What are some of the products made from crude ...
# is_duplicate                                                    1
# Name: 48, dtype: object)
# What are some examples of products that can be make from crude oil?
# What are some of the products made from crude oil?
# (49, id                                  49
# qid1                                99
# qid2                               100
# question1       How do I make friends.
# question2        How to make friends ?
# is_duplicate                         1
# Name: 49, dtype: object)
# How do I make friends.
# How to make friends ?
# (50, id                                                             50
# qid1                                                          101
# qid2                                                          102
# question1       Is Career Launcher good for RBI Grade B prepar...
# question2       How is career launcher online program for RBI ...
# is_duplicate                                                    1
# Name: 50, dtype: object)
# Is Career Launcher good for RBI Grade B preparation?
# How is career launcher online program for RBI Grade B?
# (51, id                                                             51
# qid1                                                          103
# qid2                                                          104
# question1       Will a Blu Ray play on a regular DVD player? I...
# question2       How can you play a Blu Ray DVD on a regular DV...
# is_duplicate                                                    1
# Name: 51, dtype: object)
# Will a Blu Ray play on a regular DVD player? If so, how?
# How can you play a Blu Ray DVD on a regular DVD player?
# (52, id                                                             52
# qid1                                                          105
# qid2                                                          106
# question1                                   Nd she is always sad?
# question2       Aerodynamically what happens when propellor ro...
# is_duplicate                                                    0
# Name: 52, dtype: object)
# Nd she is always sad?
# Aerodynamically what happens when propellor rotates?
# (53, id                                                             53
# qid1                                                          107
# qid2                                                          108
# question1       What is the best/most memorable thing you've e...
# question2       What is the most delicious dish you've ever ea...
# is_duplicate                                                    1
# Name: 53, dtype: object)
# What is the best/most memorable thing you've ever eaten and why?
# What is the most delicious dish you've ever eaten and why?
# (54, id                                                     54
# qid1                                                  109
# qid2                                                  110
# question1       How GST affects the CAs and tax officers?
# question2                     Why can't I do my homework?
# is_duplicate                                            0
# Name: 54, dtype: object)
# How GST affects the CAs and tax officers?
# Why can't I do my homework?
# (55, id                                                             55
# qid1                                                          111
# qid2                                                          112
# question1                       How difficult is it get into RSI?
# question2       Do you apply for programs like RSI when you're...
# is_duplicate                                                    0
# Name: 55, dtype: object)
# How difficult is it get into RSI?
# Do you apply for programs like RSI when you're a rising senior?
# (56, id                                                             56
# qid1                                                          113
# qid2                                                          114
# question1                                   Who is israil friend?
# question2       Is my boyfriend lying about his true feelings ...
# is_duplicate                                                    0
# Name: 56, dtype: object)
# Who is israil friend?
# Is my boyfriend lying about his true feelings for his friend and is he secretly attracted to her?
# (57, id                                                     57
# qid1                                                  115
# qid2                                                  116
# question1       What are some good rap songs to dance to?
# question2            What are some of the best rap songs?
# is_duplicate                                            0
# Name: 57, dtype: object)
# What are some good rap songs to dance to?
# What are some of the best rap songs?
# (58, id                                                             58
# qid1                                                          117
# qid2                                                          118
# question1       I was suddenly logged off Gmail. I can't remem...
# question2       I can't remember my Gmail password or my recov...
# is_duplicate                                                    1
# Name: 58, dtype: object)
# I was suddenly logged off Gmail. I can't remember my Gmail password and just realized the recovery email is no longer alive. What can I do?
# I can't remember my Gmail password or my recovery email. How can I recover my e-mail?
# (59, id                                                   59
# qid1                                                119
# qid2                                                120
# question1       What are the best ways to learn French?
# question2                How do I learn french genders?
# is_duplicate                                          0
# Name: 59, dtype: object)
# What are the best ways to learn French?
# How do I learn french genders?
# (60, id                                                             60
# qid1                                                          121
# qid2                                                          122
# question1       How do I download content from a kickass torre...
# question2                        Is Kickass Torrents trustworthy?
# is_duplicate                                                    0
# Name: 60, dtype: object)
# How do I download content from a kickass torrent without registration?
# Is Kickass Torrents trustworthy?
# (61, id                                                             61
# qid1                                                          123
# qid2                                                          124
# question1       Is it normal to have a dark ring around the ir...
# question2       What causes a dark ring around the iris? How s...
# is_duplicate                                                    0
# Name: 61, dtype: object)
# Is it normal to have a dark ring around the iris of my eye?
# What causes a dark ring around the iris? How should it be treated?
# (62, id                                                             62
# qid1                                                          125
# qid2                                                          126
# question1       How is the new Harry Potter book 'Harry Potter...
# question2                 How bad is the new book by J.K Rowling?
# is_duplicate                                                    1
# Name: 62, dtype: object)
# How is the new Harry Potter book 'Harry Potter and the Cursed Child'?
# How bad is the new book by J.K Rowling?
# (63, id                                                         63
# qid1                                                      127
# qid2                                                      128
# question1                      Why do I always get depressed?
# question2       Why do I always get depressed in the evening?
# is_duplicate                                                0
# Name: 63, dtype: object)
# Why do I always get depressed?
# Why do I always get depressed in the evening?
# (64, id                                                             64
# qid1                                                          129
# qid2                                                          130
# question1       Where can I find a European family office data...
# question2          Where do I find a U.S. family office database?
# is_duplicate                                                    0
# Name: 64, dtype: object)
# Where can I find a European family office database?
# Where do I find a U.S. family office database?
# (65, id                                                             65
# qid1                                                          131
# qid2                                                          132
# question1       What is Java programming? How To Learn Java Pr...
# question2           How do I learn a computer language like java?
# is_duplicate                                                    1
# Name: 65, dtype: object)
# What is Java programming? How To Learn Java Programming Language ?
# How do I learn a computer language like java?
# (66, id                                                             66
# qid1                                                          133
# qid2                                                          134
# question1                        What is the best book ever made?
# question2       What is the most important book you have ever ...
# is_duplicate                                                    1
# Name: 66, dtype: object)
# What is the best book ever made?
# What is the most important book you have ever read?
# (67, id                                                            67
# qid1                                                         135
# qid2                                                         136
# question1        Can we ever store energy produced in lightning?
# question2       Is it possible to store the energy of lightning?
# is_duplicate                                                   1
# Name: 67, dtype: object)
# Can we ever store energy produced in lightning?
# Is it possible to store the energy of lightning?
# (68, id                                                       68
# qid1                                                    137
# qid2                                                    138
# question1       What is your review of Performance Testing?
# question2                      What is performance testing?
# is_duplicate                                              0
# Name: 68, dtype: object)
# What is your review of Performance Testing?
# What is performance testing?
# (69, id                                                             69
# qid1                                                          139
# qid2                                                          140
# question1       At what cost does so much privacy as in German...
# question2       Are there any people who genuinely enjoy salad...
# is_duplicate                                                    0
# Name: 69, dtype: object)
# At what cost does so much privacy as in Germany come? What else is lost to gain so much privacy?
# Are there any people who genuinely enjoy salad with no dressing?
# (70, id                                                             70
# qid1                                                          141
# qid2                                                          142
# question1                         What are the types of immunity?
# question2       What are the different types of immunity in ou...
# is_duplicate                                                    0
# Name: 70, dtype: object)
# What are the types of immunity?
# What are the different types of immunity in our body?
# (71, id                                                        71
# qid1                                                     143
# qid2                                                     144
# question1       What is a narcissistic personality disorder?
# question2         What is narcissistic personality disorder?
# is_duplicate                                               1
# Name: 71, dtype: object)
# What is a narcissistic personality disorder?
# What is narcissistic personality disorder?
# (72, id                                                      72
# qid1                                                   145
# qid2                                                   146
# question1                How I can speak English fluently?
# question2       How can I learn to speak English fluently?
# is_duplicate                                             1
# Name: 72, dtype: object)
# How I can speak English fluently?
# How can I learn to speak English fluently?
# (73, id                                                             73
# qid1                                                          147
# qid2                                                          148
# question1       How helpful is QuickBooks' auto data recovery ...
# question2       What is the quickbooks customer support phone ...
# is_duplicate                                                    1
# Name: 73, dtype: object)
# How helpful is QuickBooks' auto data recovery support phone number to recover your corrupted data files?
# What is the quickbooks customer support phone number USA?
# (74, id                                                             74
# qid1                                                          149
# qid2                                                          150
# question1       Who is the richest gambler of all time and how...
# question2       Who is the richest gambler of all time and how...
# is_duplicate                                                    1
# Name: 74, dtype: object)
# Who is the richest gambler of all time and how can I reach his level?
# Who is the richest gambler of all time and how can I reach his level as a gambler?
# (75, id                                                             75
# qid1                                                          151
# qid2                                                          152
# question1       If I fire a bullet backward from an aircraft g...
# question2       Do bullets travel faster than the speed of sou...
# is_duplicate                                                    0
# Name: 75, dtype: object)
# If I fire a bullet backward from an aircraft going faster than the bullet; will the bullet be going backwards?
# Do bullets travel faster than the speed of sound when shot from a gun? If not, is it possible? If they do, what gun and how much devastation occurs?
# (76, id                                           76
# qid1                                        153
# qid2                                        154
# question1       How do I prevent breast cancer?
# question2         Is breast cancer preventable?
# is_duplicate                                  0
# Name: 76, dtype: object)
# How do I prevent breast cancer?
# Is breast cancer preventable?
# (77, id                                                             77
# qid1                                                          155
# qid2                                                          156
# question1       How do I log out of my Gmail account on my fri...
# question2       How can I know who logged in to my Gmail accou...
# is_duplicate                                                    0
# Name: 77, dtype: object)
# How do I log out of my Gmail account on my friend's phone?
# How can I know who logged in to my Gmail account? (by telling his IP address or device name)?
# (78, id                                                             78
# qid1                                                          157
# qid2                                                          158
# question1              How can I make money through the Internet?
# question2       What are some different ways to make money onl...
# is_duplicate                                                    0
# Name: 78, dtype: object)
# How can I make money through the Internet?
# What are some different ways to make money online, excluding selling things?
# (79, id                                                             79
# qid1                                                          159
# qid2                                                          160
# question1                                What is purpose of life?
# question2       What's the purpose of life? What is life actua...
# is_duplicate                                                    1
# Name: 79, dtype: object)
# What is purpose of life?
# What's the purpose of life? What is life actually about?
# (80, id                                                             80
# qid1                                                          161
# qid2                                                          162
# question1       When will the BJP government strip all the Mus...
# question2       Why India does not apply the "Burma-Rohingya m...
# is_duplicate                                                    0
# Name: 80, dtype: object)
# When will the BJP government strip all the Muslims and the Christians of the Indian citizenship and put them on boats like the Rohingya's of Burma?
# Why India does not apply the "Burma-Rohingya model" to deport illegal Bangladeshis?
# (81, id                                                             81
# qid1                                                          163
# qid2                                                          164
# question1       What is the right etiquette for wishing a Jeho...
# question2       How important is it to be the first person to ...
# is_duplicate                                                    0
# Name: 81, dtype: object)
# What is the right etiquette for wishing a Jehovah Witness happy birthday?
# How important is it to be the first person to wish someone a happy birthday?
# (82, id                                                             82
# qid1                                                          165
# qid2                                                          166
# question1       If someone wants to open a commercial FM radio...
# question2       I want to make a travel commercial/clip video ...
# is_duplicate                                                    0
# Name: 82, dtype: object)
# If someone wants to open a commercial FM radio station in any city of India, how much does it cost and what is the procedure?
# I want to make a travel commercial/clip video HD , For India and New Zealand. How much will it cost?
# (83, id                                                             83
# qid1                                                          167
# qid2                                                          168
# question1                            Why do Swiss despise Asians?
# question2       Why do technical employees despise sales peopl...
# is_duplicate                                                    0
# Name: 83, dtype: object)
# Why do Swiss despise Asians?
# Why do technical employees despise sales people so much?
# (84, id                                                             84
# qid1                                                          169
# qid2                                                          170
# question1       What are some of the high salary income jobs i...
# question2       What are some high paying jobs for a fresher w...
# is_duplicate                                                    1
# Name: 84, dtype: object)
# What are some of the high salary income jobs in the field of biotechnology?
# What are some high paying jobs for a fresher with an M.Tech in biotechnology?
# (85, id                                                       85
# qid1                                                    171
# qid2                                                    172
# question1       How can I increase my height after 21 also?
# question2                     Can height increase after 25?
# is_duplicate                                              1
# Name: 85, dtype: object)
# How can I increase my height after 21 also?
# Can height increase after 25?
# (86, id                                                             86
# qid1                                                          173
# qid2                                                          174
# question1       What were the major effects of the cambodia ea...
# question2       What were the major effects of the cambodia ea...
# is_duplicate                                                    1
# Name: 86, dtype: object)
# What were the major effects of the cambodia earthquake, and how do these effects compare to the Kamchatca earthquakes in 1952?
# What were the major effects of the cambodia earthquake, and how do these effects compare to the Valparaiso earthquake in 1822?
# (87, id                                                             87
# qid1                                                          175
# qid2                                                          176
# question1       What is the difference between sincerity and f...
# question2       What's the difference between honest and sincere?
# is_duplicate                                                    0
# Name: 87, dtype: object)
# What is the difference between sincerity and fairness?
# What's the difference between honest and sincere?
# (88, id                                                           88
# qid1                                                        177
# qid2                                                        178
# question1        Which is the best gaming laptop under 60k INR?
# question2       Which is the best gaming laptop under Rs 60000?
# is_duplicate                                                  1
# Name: 88, dtype: object)
# Which is the best gaming laptop under 60k INR?
# Which is the best gaming laptop under Rs 60000?
# (89, id                                                             89
# qid1                                                          179
# qid2                                                          180
# question1       What is your review of The Next Warrior: Provi...
# question2       What is your review of The Next Warrior: Provi...
# is_duplicate                                                    0
# Name: 89, dtype: object)
# What is your review of The Next Warrior: Proving Grounds - Part 9?
# What is your review of The Next Warrior: Proving Grounds - Part 5?
# (90, id                                                             90
# qid1                                                          181
# qid2                                                          182
# question1       What is the best reference book for physics cl...
# question2       Which book should I choose for reference for p...
# is_duplicate                                                    0
# Name: 90, dtype: object)
# What is the best reference book for physics class 11th?
# Which book should I choose for reference for physics and chemistry (class 11, CBSE board)?
# (91, id                                                             91
# qid1                                                          183
# qid2                                                          184
# question1       National Institute of Technology, Kurukshetra:...
# question2       National Institute of Technology Karnataka (NI...
# is_duplicate                                                    0
# Name: 91, dtype: object)
# National Institute of Technology, Kurukshetra: How is the social life at NITK, Surathkal?
# National Institute of Technology Karnataka (NITK) , Surathkal: To the graduating batch: What lessons would you want to give to your juniors before you leave?
# (92, id                                                             92
# qid1                                                          185
# qid2                                                          186
# question1       What are some of the best romantic movies in E...
# question2       What is the best romantic movie you have ever ...
# is_duplicate                                                    1
# Name: 92, dtype: object)
# What are some of the best romantic movies in English?
# What is the best romantic movie you have ever seen?
# (93, id                                                  93
# qid1                                               187
# qid2                                               188
# question1                     What causes a nightmare?
# question2       What causes nightmares that seem real?
# is_duplicate                                         1
# Name: 93, dtype: object)
# What causes a nightmare?
# What causes nightmares that seem real?
# (94, id                                                             94
# qid1                                                          189
# qid2                                                          190
# question1             What is abstract expressionism in painting?
# question2       What are some of the major influences of abstr...
# is_duplicate                                                    0
# Name: 94, dtype: object)
# What is abstract expressionism in painting?
# What are some of the major influences of abstract expressionism?
# (95, id                                      95
# qid1                                   191
# qid2                                   192
# question1       How does 3D printing work?
# question2         How do 3D printing work?
# is_duplicate                             1
# Name: 95, dtype: object)
# How does 3D printing work?
# How do 3D printing work?
# (96, id                                                             96
# qid1                                                          193
# qid2                                                          194
# question1       What was it like to attend Caltech with Jeremy...
# question2        Who are some notable folks who attended Caltech?
# is_duplicate                                                    0
# Name: 96, dtype: object)
# What was it like to attend Caltech with Jeremy Ehrhardt?
# Who are some notable folks who attended Caltech?
# (97, id                                           97
# qid1                                        195
# qid2                                        196
# question1       Why did harry become a horcrux?
# question2                    What is a Horcrux?
# is_duplicate                                  0
# Name: 97, dtype: object)
# Why did harry become a horcrux?
# What is a Horcrux?
# (98, id                                                             98
# qid1                                                          197
# qid2                                                          198
# question1       What are the best associate product manager (A...
# question2       What are the general requirement to become a P...
# is_duplicate                                                    0
# Name: 98, dtype: object)
# What are the best associate product manager (APM) programs that someone in their early 20s can join to learn product management and have a rewarding career in the company?
# What are the general requirement to become a Product Manager or a Program Manager in a product based software company?
# (99, id                                                             99
# qid1                                                          199
# qid2                                                          200
# question1       Why is the number for Skype at 1-855-425-3768 ...
# question2       How could I get Skype to work on an android 4....
# is_duplicate                                                    0
# Name: 99, dtype: object)
# Why is the number for Skype at 1-855-425-3768 always busy?
# How could I get Skype to work on an android 4.1.1 phone?

# %%
with open('testoutput', 'rb') as handle:
    try:
        while True:
            tmp = pickle.load(handle)
            (scoreRaw_cd, scoreNorm_cd) = tk._CollinsDuffy_(tmp['q1'], tmp['q2'], 1.0, 1, 1)
            print("Collins-Duffy | Norm: %f | Raw: %f | Lambda: %3f" % (scoreNorm_cd, scoreRaw_cd, lamb))
    
    except EOFError:
        pass
# Out:
# Collins-Duffy | Norm: 0.944911 | Raw: 15.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.404061 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.286039 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.419314 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.500773 | Raw: 9.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.503953 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.612372 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.447214 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.139010 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.365148 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.668153 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.816497 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.901421 | Raw: 29.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.218218 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.750000 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.102062 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.358057 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.777778 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.507093 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.358569 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.503953 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.057831 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.897085 | Raw: 13.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.816497 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.267261 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.824958 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.639602 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.632456 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.166667 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.842665 | Raw: 13.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.078567 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.866025 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.241747 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.436436 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.092450 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.617213 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.089087 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.755929 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.888889 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.591608 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.935414 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.377964 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.178174 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.701646 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.670820 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.316228 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.840168 | Raw: 12.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.866025 | Raw: 9.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.158114 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.533002 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.182574 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.144338 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.612372 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.447214 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.816497 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.777778 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.597614 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.235702 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.447214 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.866025 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.912871 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.866025 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.117851 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.915209 | Raw: 14.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.243975 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.408248 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.250000 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.204124 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.730297 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.221404 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.350070 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.241209 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.447214 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.440959 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.169031 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.900500 | Raw: 27.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.625000 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.777778 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.900000 | Raw: 9.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.460179 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.404145 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.400000 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.408248 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.353553 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.800000 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.204124 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.450694 | Raw: 13.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.102062 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.944911 | Raw: 15.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.404061 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.286039 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.419314 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.500773 | Raw: 9.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.503953 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.612372 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.447214 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.139010 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.365148 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.668153 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.816497 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.901421 | Raw: 29.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.218218 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.750000 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.102062 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.358057 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.777778 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.507093 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.358569 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.503953 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.057831 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.897085 | Raw: 13.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.816497 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.267261 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.824958 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.639602 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.632456 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.166667 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.842665 | Raw: 13.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.078567 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.866025 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.241747 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.436436 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.092450 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.617213 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.089087 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.755929 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.888889 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.591608 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.935414 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.377964 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.178174 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.701646 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.670820 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.316228 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.840168 | Raw: 12.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.866025 | Raw: 9.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.158114 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.533002 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.182574 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.144338 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.612372 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.447214 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.816497 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.777778 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.597614 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.235702 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.447214 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.866025 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.912871 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.866025 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.117851 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.915209 | Raw: 14.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.243975 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.408248 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.250000 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.204124 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.730297 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.221404 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.350070 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.241209 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.447214 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.440959 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.169031 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.900500 | Raw: 27.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.625000 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.777778 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.900000 | Raw: 9.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.460179 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.404145 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.400000 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.408248 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.353553 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.800000 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.204124 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.450694 | Raw: 13.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.102062 | Raw: 1.000000 | Lambda: 1.000000

# %%
df_train[1].values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/Matthew/miniconda3/envs/bleedingEdge/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-d6566ad4ae3d> in <module>()
# ----> 1 df_train[1].values
#
# /Users/Matthew/miniconda3/envs/bleedingEdge/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/Matthew/miniconda3/envs/bleedingEdge/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /Users/Matthew/miniconda3/envs/bleedingEdge/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /Users/Matthew/miniconda3/envs/bleedingEdge/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/Matthew/miniconda3/envs/bleedingEdge/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 1
