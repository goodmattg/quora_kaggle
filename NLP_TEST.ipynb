# %%
import pandas as pd
import numpy as np
from pycorenlp import StanfordCoreNLP 
import re, time, bisect, math
import TreeKernel as tk
import TreeBuild as tb

# %%
from gensim.models.keyedvectors import KeyedVectors
word_vectors = KeyedVectors.load_word2vec_format('./w2v_model/GoogleNews-vectors-negative300.bin', binary=True)  # C binary format

# %%
nlp = StanfordCoreNLP('http://localhost:9000')

# %%
def _getNLPToks_(rawSentence):
    output = nlp.annotate(rawSentence, properties={
      'annotators': 'tokenize,ssplit,pos,parse',
      'outputFormat': 'json'
      })
    return output['sentences'][0]['parse'].split("\n")

# %%
def _w2vSimilarity_(word1, word2, modelPtr):
    return modelPtr.similarity(word1, word2)

# %% [markdown]
# ## Test: Tree Generation and Collins-Duffy Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tb.tree()
tree_b2 = tb.tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
tb._generateTree_(toks_b1, tree_b1)
tb._generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
tb._flipTree_(tree_b1)
tb._flipTree_(tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = tk._CollinsDuffy_(tree_b1, tree_b2, 0.8, 1, 0)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kerne
print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# --- 0.09436917304992676 seconds ---
# --- 0.09468698501586914 seconds ---
# --- 0.0948190689086914 seconds ---
# --- 0.0969841480255127 seconds ---
# Raw Score: 0.8
# Norm Score: 0.124034734589

# %% [markdown]
# ## Test: Tree Generation and Moschitti PT Kernel

# %%
test_b1 = "Why do we enjoy parties in the scope of the universe"
test_b2 = "What are college parties like?"

# test_b1 = "I tom?"
# test_b2 = "I, Claudius?"
start_time = time.time()

tree_b1 = tb.tree()
tree_b2 = tb.tree()

# Generate raw tokens using Stanford Core NLP

toks_b1 = _getNLPToks_(test_b1)
toks_b2 = _getNLPToks_(test_b2)
print("--- %s seconds ---" % (time.time() - start_time)) # tokenize

# Generate a tree structure
tb._generateTree_(toks_b1, tree_b1)
tb._generateTree_(toks_b2, tree_b2)

print("--- %s seconds ---" % (time.time() - start_time)) # generate tree

# Flip the trees
tb._flipTree_(tree_b1)
tb._flipTree_(tree_b2)

for i in tree_b1.items():
    print(i)
    
print("--- %s seconds ---" % (time.time() - start_time)) # flip tree

(rawScore, normScore) = tk._MoschittiPT_(tree_b1, tree_b2, 0.8, 0.4, 1)
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel

print("Raw Score: %s" % (rawScore))
print("Norm Score: %s" % (normScore))
# Out:
# --- 0.04182696342468262 seconds ---
# --- 0.042407989501953125 seconds ---
# (0, {'indent': 0, 'curid': 0, 'childrenTok': 'SBARQ', 'parid': -1, 'posOrTok': 'ROOT', 'children': [1]})
# (1, {'indent': 2, 'curid': 1, 'childrenTok': ['WHADVP', 'SQ'], 'parid': 0, 'posOrTok': 'SBARQ', 'children': [2, 5]})
# (2, {'indent': 4, 'curid': 2, 'childrenTok': ['WRB'], 'parid': 1, 'posOrTok': 'WHADVP', 'children': [3]})
# (3, {'indent': 6, 'curid': 3, 'childrenTok': ['Why'], 'parid': 2, 'posOrTok': 'WRB', 'children': [4]})
# (4, {'indent': 6, 'curid': 4, 'childrenTok': [], 'parid': 3, 'posOrTok': 'Why', 'children': []})
# (5, {'indent': 4, 'curid': 5, 'childrenTok': ['VBP', 'NP', 'VP'], 'parid': 1, 'posOrTok': 'SQ', 'children': [6, 8, 11]})
# (6, {'indent': 6, 'curid': 6, 'childrenTok': ['do'], 'parid': 5, 'posOrTok': 'VBP', 'children': [7]})
# (7, {'indent': 6, 'curid': 7, 'childrenTok': [], 'parid': 6, 'posOrTok': 'do', 'children': []})
# (8, {'indent': 6, 'curid': 8, 'childrenTok': ['PRP'], 'parid': 5, 'posOrTok': 'NP', 'children': [9]})
# (9, {'indent': 8, 'curid': 9, 'childrenTok': ['we'], 'parid': 8, 'posOrTok': 'PRP', 'children': [10]})
# (10, {'indent': 8, 'curid': 10, 'childrenTok': [], 'parid': 9, 'posOrTok': 'we', 'children': []})
# (11, {'indent': 6, 'curid': 11, 'childrenTok': ['VB', 'NP', 'PP'], 'parid': 5, 'posOrTok': 'VP', 'children': [12, 14, 17]})
# (12, {'indent': 8, 'curid': 12, 'childrenTok': ['enjoy'], 'parid': 11, 'posOrTok': 'VB', 'children': [13]})
# (13, {'indent': 8, 'curid': 13, 'childrenTok': [], 'parid': 12, 'posOrTok': 'enjoy', 'children': []})
# (14, {'indent': 8, 'curid': 14, 'childrenTok': ['NNS'], 'parid': 11, 'posOrTok': 'NP', 'children': [15]})
# (15, {'indent': 10, 'curid': 15, 'childrenTok': ['parties'], 'parid': 14, 'posOrTok': 'NNS', 'children': [16]})
# (16, {'indent': 10, 'curid': 16, 'childrenTok': [], 'parid': 15, 'posOrTok': 'parties', 'children': []})
# (17, {'indent': 8, 'curid': 17, 'childrenTok': ['IN', 'NP'], 'parid': 11, 'posOrTok': 'PP', 'children': [18, 20]})
# (18, {'indent': 10, 'curid': 18, 'childrenTok': ['in'], 'parid': 17, 'posOrTok': 'IN', 'children': [19]})
# (19, {'indent': 10, 'curid': 19, 'childrenTok': [], 'parid': 18, 'posOrTok': 'in', 'children': []})
# (20, {'indent': 10, 'curid': 20, 'childrenTok': ['NP', 'PP'], 'parid': 17, 'posOrTok': 'NP', 'children': [21, 26]})
# (21, {'indent': 12, 'curid': 21, 'childrenTok': ['DT', 'NN'], 'parid': 20, 'posOrTok': 'NP', 'children': [22, 24]})
# (22, {'indent': 14, 'curid': 22, 'childrenTok': ['the'], 'parid': 21, 'posOrTok': 'DT', 'children': [23]})
# (23, {'indent': 14, 'curid': 23, 'childrenTok': [], 'parid': 22, 'posOrTok': 'the', 'children': []})
# (24, {'indent': 14, 'curid': 24, 'childrenTok': ['scope'], 'parid': 21, 'posOrTok': 'NN', 'children': [25]})
# (25, {'indent': 14, 'curid': 25, 'childrenTok': [], 'parid': 24, 'posOrTok': 'scope', 'children': []})
# (26, {'indent': 12, 'curid': 26, 'childrenTok': ['IN', 'NP'], 'parid': 20, 'posOrTok': 'PP', 'children': [27, 29]})
# (27, {'indent': 14, 'curid': 27, 'childrenTok': ['of'], 'parid': 26, 'posOrTok': 'IN', 'children': [28]})
# (28, {'indent': 14, 'curid': 28, 'childrenTok': [], 'parid': 27, 'posOrTok': 'of', 'children': []})
# (29, {'indent': 14, 'curid': 29, 'childrenTok': ['DT', 'NN'], 'parid': 26, 'posOrTok': 'NP', 'children': [30, 32]})
# (30, {'indent': 16, 'curid': 30, 'childrenTok': ['the'], 'parid': 29, 'posOrTok': 'DT', 'children': [31]})
# (31, {'indent': 16, 'curid': 31, 'childrenTok': [], 'parid': 30, 'posOrTok': 'the', 'children': []})
# (32, {'indent': 16, 'curid': 32, 'childrenTok': ['universe'], 'parid': 29, 'posOrTok': 'NN', 'children': [33]})
# (33, {'indent': 16, 'curid': 33, 'childrenTok': [], 'parid': 32, 'posOrTok': 'universe', 'children': []})
# --- 0.04301595687866211 seconds ---
# --- 0.04678487777709961 seconds ---
# Raw Score: 3.36
# Norm Score: 0.326722528894

# %% [markdown]
# ## Test: Tree Kernels on Training Data

# %%
from random import randint

def read_data(path_to_file):
    df = pd.read_csv(path_to_file)
    print ("Shape of base training File = ", df.shape)
    # Remove missing values and duplicates from training data
    df.drop_duplicates(inplace=True)
    df.dropna(inplace=True)
    print("Shape of base training data after cleaning = ", df.shape)
    return df

df_train = read_data("input/train.csv")
# Out:
# Shape of base training File =  (404290, 6)
# Shape of base training data after cleaning =  (404288, 6)

# %%
## SET UP TEST INDICES TO SELECT RANDOM ROWS

TEST_SAMPLES = 100
indices = np.arange(TEST_SAMPLES)
for i in range(len(indices)):
    indices[i] = randint(0,df_train.shape[0])

# %%
start_time = time.time()

for ind in indices:
    
    tree_1 = tb.tree()
    tree_2 = tb.tree()

    toks_1 = _getNLPToks_(df_train.get_value(ind,'question1'))
    toks_2 = _getNLPToks_(df_train.get_value(ind,'question2'))

    # Generate a tree structure
    tb._generateTree_(toks_1, tree_1)
    tb._generateTree_(toks_2, tree_2)

    # Flip the trees
    tb._flipTree_(tree_1)
    tb._flipTree_(tree_2)

    
    print("%s\n%s" % (df_train.get_value(ind,'question1'), df_train.get_value(ind,'question2')))
    
    for lamb in [1, 0.8, 0.4, 0.2, 0.1]:
        (scoreRaw_cd, scoreNorm_cd) = tk._CollinsDuffy_(tree_1, tree_2, lamb, 1, 1)
        print("Collins-Duffy | Norm: %f | Raw: %f | Lambda: %3f" % (scoreNorm_cd, scoreRaw_cd, lamb))
    
print("--- %s seconds ---" % (time.time() - start_time)) # tree kernel
# Out:
# 21 years old male.Gynecomastia patient.Smoke 3–4 ciggarettes a day.Have to go through a surgery.Safe in current circumstances?
# Would I put a 1-3 year old cat under too much stress if I moved to a new house five or six months after adopting it?
# Collins-Duffy | Norm: 0.219265 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.219265 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.219265 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.219265 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.219265 | Raw: 0.500000 | Lambda: 0.100000
# Which companies hire the students who have less than 60%?
# Does MDI Gurgaon have sectional cut offs?
# Collins-Duffy | Norm: 0.119523 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.119523 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.119523 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.119523 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.119523 | Raw: 0.100000 | Lambda: 0.100000
# Is there a fictional character with whom you could fall in love?
# Did you ever fall in love with a fictional character?
# Collins-Duffy | Norm: 0.639010 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.639010 | Raw: 5.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.639010 | Raw: 2.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.639010 | Raw: 1.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.639010 | Raw: 0.700000 | Lambda: 0.100000
# When will Amritsar be totally upgraded?
# What kind of support India recieve from international monetary fund for liberalisation, globalisation and privatisation?
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.000000 | Raw: 0.000000 | Lambda: 0.100000
# How would it affect the election if Trump said "I want to be a better person. Let me start by apologizing for making an issue of Obama's birth"?
# What is the main difference between Indian Schooling and European schooling?
# Collins-Duffy | Norm: 0.075378 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.075378 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.075378 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.075378 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.075378 | Raw: 0.100000 | Lambda: 0.100000
# What is the scope of medical microbiology?
# Does medical microbiology have a good scope?
# Collins-Duffy | Norm: 0.428571 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.428571 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.428571 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.428571 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.428571 | Raw: 0.300000 | Lambda: 0.100000
# While living in Norway is there any way to reduce the time you have to live in Norway to get citizenship?
# How can I live and work in USA/Canada without having TOEFL or IELTS score?
# Collins-Duffy | Norm: 0.155543 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.155543 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.155543 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.155543 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.155543 | Raw: 0.300000 | Lambda: 0.100000
# What can be the best house design for Indian standard for sides 52 X 22 feet. door can be on either 52 or 22 side?
# Do Eastern Catholic and Western Catholics have the same theology, doctrine and tradition?
# Collins-Duffy | Norm: 0.060858 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.060858 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.060858 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.060858 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.060858 | Raw: 0.100000 | Lambda: 0.100000
# How much money did Chetan Bhagat pay to Times of India for promoting his novel "Half Girlfriend" on the front page?
# What do you think about Chetan Bagat's book "Half Girlfriend"?
# Collins-Duffy | Norm: 0.080845 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.080845 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.080845 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.080845 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.080845 | Raw: 0.100000 | Lambda: 0.100000
# What Do I Do About My Boyfriend Ignoring Me?
# What should I do when my boyfriend is ignoring me?
# Collins-Duffy | Norm: 0.117851 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.117851 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.117851 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.117851 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.117851 | Raw: 0.100000 | Lambda: 0.100000
# What is the difference between yoghurt and curd?
# What is the exact difference between a curd and a yogurt?
# Collins-Duffy | Norm: 0.686406 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.686406 | Raw: 5.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.686406 | Raw: 2.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.686406 | Raw: 1.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.686406 | Raw: 0.700000 | Lambda: 0.100000
# How do I get started in freelancing?
# How did you start freelancing?
# Collins-Duffy | Norm: 0.338062 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.338062 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.338062 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.338062 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.338062 | Raw: 0.200000 | Lambda: 0.100000
# What are some great short stories of one-sided love?
# What is the greatest love story of all time?
# Collins-Duffy | Norm: 0.251976 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.251976 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.251976 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.251976 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.251976 | Raw: 0.200000 | Lambda: 0.100000
# This guy I barely know is making me very anxious, sad and hopeless. What is wrong with me?
# How I control friends phone using my smartphone?
# Collins-Duffy | Norm: 0.113228 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.113228 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.113228 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.113228 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.113228 | Raw: 0.100000 | Lambda: 0.100000
# What are the ways to host Android apps?
# Is there a way to adjust the playback speed in the YouTube Android app?
# Collins-Duffy | Norm: 0.265165 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.265165 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.265165 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.265165 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.265165 | Raw: 0.300000 | Lambda: 0.100000
# What are the best sites to buy Custom and Branded T-Shirts in India?
# What is the best website to buy customized T-shirts in India?
# Collins-Duffy | Norm: 0.639010 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.639010 | Raw: 5.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.639010 | Raw: 2.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.639010 | Raw: 1.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.639010 | Raw: 0.700000 | Lambda: 0.100000
# How electric earthing is carried out?
# How is the earthing procedure carried out?
# Collins-Duffy | Norm: 0.462910 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.462910 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.462910 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.462910 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.462910 | Raw: 0.300000 | Lambda: 0.100000
# How do people make new friends on IRC?
# Who makes the IRC BOOKZ torrent online?
# Collins-Duffy | Norm: 0.133631 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.133631 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.133631 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.133631 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.133631 | Raw: 0.100000 | Lambda: 0.100000
# What comes next 4,6,2,12,18,14?
# What comes next? 49,6,25,4,36,5,81,5?
# Collins-Duffy | Norm: 0.577350 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.577350 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.577350 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.577350 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.577350 | Raw: 0.200000 | Lambda: 0.100000
# Is it normal to talk to yourself a lot?
# Is it normal to talk to yourself?
# Collins-Duffy | Norm: 0.904534 | Raw: 9.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.904534 | Raw: 7.200000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.904534 | Raw: 3.600000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.904534 | Raw: 1.800000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.904534 | Raw: 0.900000 | Lambda: 0.100000
# Do we have any trick to know who see your whatsapp profile?
# Is it possible to know if someone saw my WhatsApp profile?
# Collins-Duffy | Norm: 0.235702 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.235702 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.235702 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.235702 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.235702 | Raw: 0.200000 | Lambda: 0.100000
# What is the relation between culture and civilization?
# What is the relation between the culture and morality?
# Collins-Duffy | Norm: 0.852803 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.852803 | Raw: 6.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.852803 | Raw: 3.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.852803 | Raw: 1.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.852803 | Raw: 0.800000 | Lambda: 0.100000
# Why is Java not considered a pure object-oriented programming language?
# Is Java a pure object-oriented programming language?
# Collins-Duffy | Norm: 0.566947 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.566947 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.566947 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.566947 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.566947 | Raw: 0.300000 | Lambda: 0.100000
# What are some of the best ways to break out my comfort zone?
# How can I make myself to get out of my super comfort zone?
# Collins-Duffy | Norm: 0.210819 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.210819 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.210819 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.210819 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.210819 | Raw: 0.200000 | Lambda: 0.100000
# What is The Elder's Scroll?
# What are the best Elder Scrolls games?
# Collins-Duffy | Norm: 0.308607 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.308607 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.308607 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.308607 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.308607 | Raw: 0.200000 | Lambda: 0.100000
# How do I convince my parents to buy a dog for us?
# How do you convince your parents that you’re responsible enough to get a dog?
# Collins-Duffy | Norm: 0.489898 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.489898 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.489898 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.489898 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.489898 | Raw: 0.600000 | Lambda: 0.100000
# How do I hack shadow fight 2 on android?
# How do I hack Shadow Fight 2?
# Collins-Duffy | Norm: 0.629941 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.629941 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.629941 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.629941 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.629941 | Raw: 0.500000 | Lambda: 0.100000
# What are the symptoms of chikungunya?
# What are the symptoms of tuberculosis?
# Collins-Duffy | Norm: 0.833333 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.833333 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.833333 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.833333 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.833333 | Raw: 0.500000 | Lambda: 0.100000
# Who's your favourite Walking Dead character?
# Who is your favourite character in the TV series The Walking Dead? Why?
# Collins-Duffy | Norm: 0.333333 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.333333 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.333333 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.333333 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.333333 | Raw: 0.200000 | Lambda: 0.100000
# What movie should I watch?
# What are some recommended movies a person should watch?
# Collins-Duffy | Norm: 0.298142 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.298142 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.298142 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.298142 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.298142 | Raw: 0.200000 | Lambda: 0.100000
# What is your opinion on PM Narendra Modi's decision to ban INR 500 and INR 1000 notes?
# What do you think about the Modi's sudden decision to scrap 500 and 1000 rs denomination?
# Collins-Duffy | Norm: 0.437500 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.437500 | Raw: 5.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.437500 | Raw: 2.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.437500 | Raw: 1.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.437500 | Raw: 0.700000 | Lambda: 0.100000
# What are some of the best New Years resolutions for 2017?
# What are some meaningful new year resolutions for 2017?
# Collins-Duffy | Norm: 0.603023 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.603023 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.603023 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.603023 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.603023 | Raw: 0.600000 | Lambda: 0.100000
# What would be the possible impact on Indian economy after cancellation of 500 and 1000 Rs notes?
# What will be the impact in the Indian economy of sudden 500 & 1000 rupee notes withdrawal of by the government?
# Collins-Duffy | Norm: 0.588348 | Raw: 12.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.588348 | Raw: 9.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.588348 | Raw: 4.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.588348 | Raw: 2.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.588348 | Raw: 1.200000 | Lambda: 0.100000
# CAT or GMAT which one is tougher?
# Which one is a better option: 1. appearing for CAT or 2. appearing for GMAT?
# Collins-Duffy | Norm: 0.142857 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.142857 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.142857 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.142857 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.142857 | Raw: 0.100000 | Lambda: 0.100000
# What is stenography?
# What is stenography exam?
# Collins-Duffy | Norm: 0.866025 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.866025 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.866025 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.866025 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.866025 | Raw: 0.300000 | Lambda: 0.100000
# What are some animal names that have 7 letters?
# What are some good foods for pets?
# Collins-Duffy | Norm: 0.377964 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.377964 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.377964 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.377964 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.377964 | Raw: 0.300000 | Lambda: 0.100000
# What are the advantages and disadvantages of GST bill?
# What is GST bill? What are it's advantages and disadvantages?
# Collins-Duffy | Norm: 0.500000 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.500000 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.500000 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.500000 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.500000 | Raw: 0.300000 | Lambda: 0.100000
# How is cocaine made?
# What is cocaine made of?
# Collins-Duffy | Norm: 0.670820 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.670820 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.670820 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.670820 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.670820 | Raw: 0.300000 | Lambda: 0.100000
# I feel like I’m trapped in the sexual world. Should I even bother escaping?
# There's too many unanswered questions, I feel like I'm trapped on earth in an experiment. Is this because I don't fully believe in God?
# Collins-Duffy | Norm: 0.612372 | Raw: 9.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.612372 | Raw: 7.200000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.612372 | Raw: 3.600000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.612372 | Raw: 1.800000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.612372 | Raw: 0.900000 | Lambda: 0.100000
# Why wasn't I using Quora before?
# Why should I not use Quora?
# Collins-Duffy | Norm: 0.462910 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.462910 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.462910 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.462910 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.462910 | Raw: 0.300000 | Lambda: 0.100000
# What is the best/coolest wallet?
# Which is the best wallet?
# Collins-Duffy | Norm: 0.516398 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.516398 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.516398 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.516398 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.516398 | Raw: 0.200000 | Lambda: 0.100000
# Which car services are available in Sacramento? How good are they compared to taxis and relative to each other?
# Which car services are available in Houston? How good are they compared to taxis and relative to each other?
# Collins-Duffy | Norm: 0.857143 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.857143 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.857143 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.857143 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.857143 | Raw: 0.600000 | Lambda: 0.100000
# What is the best tool for site analysis?
# Which tool is the best for website analysis?
# Collins-Duffy | Norm: 0.750000 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.750000 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.750000 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.750000 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.750000 | Raw: 0.600000 | Lambda: 0.100000
# What does "Que chafa!" mean in Spanish?
# What does "vuestro" mean in Spanish?
# Collins-Duffy | Norm: 0.377964 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.377964 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.377964 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.377964 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.377964 | Raw: 0.200000 | Lambda: 0.100000
# Why shouldn't we vote for Donald Trump?
# Why shouldn't I vote for Donald Trump?
# Collins-Duffy | Norm: 0.875000 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.875000 | Raw: 5.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.875000 | Raw: 2.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.875000 | Raw: 1.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.875000 | Raw: 0.700000 | Lambda: 0.100000
# How do I change my SBI register mobile number?
# How do I register my mobile number in SBI?
# Collins-Duffy | Norm: 0.612372 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.612372 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.612372 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.612372 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.612372 | Raw: 0.300000 | Lambda: 0.100000
# What is the best and safest way to clean a Samsung flat screen TV?
# What is the best way to clean a Samsung LED TV screen?
# Collins-Duffy | Norm: 0.848668 | Raw: 11.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.848668 | Raw: 8.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.848668 | Raw: 4.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.848668 | Raw: 2.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.848668 | Raw: 1.100000 | Lambda: 0.100000
# How can I have gay sex?
# How can I be gay and dislike gay sex?
# Collins-Duffy | Norm: 0.645497 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.645497 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.645497 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.645497 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.645497 | Raw: 0.500000 | Lambda: 0.100000
# Can a power engineer get a job abroad?
# How can a instrumentation engineer get a job abroad?
# Collins-Duffy | Norm: 0.762770 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.762770 | Raw: 6.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.762770 | Raw: 3.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.762770 | Raw: 1.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.762770 | Raw: 0.800000 | Lambda: 0.100000
# Could Donald Trump be a great president?
# Why could Donald Trump be a great president?
# Collins-Duffy | Norm: 0.801784 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.801784 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.801784 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.801784 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.801784 | Raw: 0.600000 | Lambda: 0.100000
# Who invented the distributive property?
# Who invented the light bulb?
# Collins-Duffy | Norm: 0.600000 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.600000 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.600000 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.600000 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.600000 | Raw: 0.300000 | Lambda: 0.100000
# Why is it shut "up"?
# Why does A tell G to shut up.
# Collins-Duffy | Norm: 0.144338 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.144338 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.144338 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.144338 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.144338 | Raw: 0.100000 | Lambda: 0.100000
# How much do women masturbate?
# What percentage of women masturbate? On average, how often?
# Collins-Duffy | Norm: 0.200000 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.200000 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.200000 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.200000 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.200000 | Raw: 0.100000 | Lambda: 0.100000
# How do you know if someone is following you back on Snapchat?
# How do you check if someone is following you on Snapchat if you don't follow them?
# Collins-Duffy | Norm: 0.822951 | Raw: 16.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.822951 | Raw: 12.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.822951 | Raw: 6.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.822951 | Raw: 3.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.822951 | Raw: 1.600000 | Lambda: 0.100000
# How good is nmmu's computer science department?
# How good is UMBC's computer science department?
# Collins-Duffy | Norm: 0.833333 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.833333 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.833333 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.833333 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.833333 | Raw: 0.500000 | Lambda: 0.100000
# How do you use a drone?
# How can we use drones in security?
# Collins-Duffy | Norm: 0.308607 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.308607 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.308607 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.308607 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.308607 | Raw: 0.200000 | Lambda: 0.100000
# How do you fix a 403 Forbidden error?
# How do I fix a 403 forbidden error?
# Collins-Duffy | Norm: 0.750000 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.750000 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.750000 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.750000 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.750000 | Raw: 0.600000 | Lambda: 0.100000
# Should we support Kiss of Love or not?
# Do you support the 'Kiss of Love' campaign?
# Collins-Duffy | Norm: 0.375000 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.375000 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.375000 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.375000 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.375000 | Raw: 0.300000 | Lambda: 0.100000
# How do I say hello in Spanish?
# How do you say 'blender' in Spanish?
# Collins-Duffy | Norm: 0.668153 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.668153 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.668153 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.668153 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.668153 | Raw: 0.500000 | Lambda: 0.100000
# How common is prostitution in Saudi Arabia?
# Does prostitution thrive in Saudi Arabia?
# Collins-Duffy | Norm: 0.617213 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.617213 | Raw: 3.200000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.617213 | Raw: 1.600000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.617213 | Raw: 0.800000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.617213 | Raw: 0.400000 | Lambda: 0.100000
# What is your favorite Quora cliché?
# What are some favorite Quora hacks?
# Collins-Duffy | Norm: 0.288675 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.288675 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.288675 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.288675 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.288675 | Raw: 0.100000 | Lambda: 0.100000
# Are Jews descended from the Israelites?
# Is the modern Jewish people directly descended from the original Israelites?
# Collins-Duffy | Norm: 0.566139 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.566139 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.566139 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.566139 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.566139 | Raw: 0.500000 | Lambda: 0.100000
# How do the Jews perceive, feel, understand, view, believe, and opine, about the Dalits, Shudras, and Dasa?
# How do the Jains perceive, feel, understand, view, believe, and/or opine, about Dalits, Shudras, and Dasa?
# Collins-Duffy | Norm: 0.896421 | Raw: 15.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.896421 | Raw: 12.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.896421 | Raw: 6.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.896421 | Raw: 3.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.896421 | Raw: 1.500000 | Lambda: 0.100000
# Are the lenses in "high end" (eg Oakley, Rayban) sunglasses better than normal sunglasses?
# How much better are expensive sunglasses than cheap ones?
# Collins-Duffy | Norm: 0.333333 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.333333 | Raw: 3.200000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.333333 | Raw: 1.600000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.333333 | Raw: 0.800000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.333333 | Raw: 0.400000 | Lambda: 0.100000
# I don't have a proof of address, how do I apply for pan card?
# How do I apply for PAN Card?
# Collins-Duffy | Norm: 0.520266 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.520266 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.520266 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.520266 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.520266 | Raw: 0.600000 | Lambda: 0.100000
# Which is the best romantic fiction novel you have read?
# Which is the best fiction novel you have ever read?
# Collins-Duffy | Norm: 0.843274 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.843274 | Raw: 6.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.843274 | Raw: 3.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.843274 | Raw: 1.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.843274 | Raw: 0.800000 | Lambda: 0.100000
# What is the answer to this mathematics question?
# What is the answer of this mathematics questions of functions?
# Collins-Duffy | Norm: 0.612372 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.612372 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.612372 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.612372 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.612372 | Raw: 0.600000 | Lambda: 0.100000
# What are the best tools for building a HTML email?
# What are good tools or practices for automatically inlining CSS styles for HTML emails?
# Collins-Duffy | Norm: 0.474342 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.474342 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.474342 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.474342 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.474342 | Raw: 0.600000 | Lambda: 0.100000
# What will happen if I don't pay my educational loan?
# What will happen if I did not pay educational loan?
# Collins-Duffy | Norm: 0.670820 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.670820 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.670820 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.670820 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.670820 | Raw: 0.600000 | Lambda: 0.100000
# Should people over 91 not be allowed to vote?
# Should people over 96 not be allowed to vote?
# Collins-Duffy | Norm: 0.888889 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.888889 | Raw: 6.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.888889 | Raw: 3.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.888889 | Raw: 1.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.888889 | Raw: 0.800000 | Lambda: 0.100000
# Why are so many questions posted to Quora that are so easily answered by using Google?
# Why do so many people ask things on Quora that they could just as easily Google?
# Collins-Duffy | Norm: 0.391312 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.391312 | Raw: 5.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.391312 | Raw: 2.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.391312 | Raw: 1.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.391312 | Raw: 0.700000 | Lambda: 0.100000
# Are most people who follow astrology also religious?
# Does astrology conflict with religion?
# Collins-Duffy | Norm: 0.158114 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.158114 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.158114 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.158114 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.158114 | Raw: 0.100000 | Lambda: 0.100000
# I was just walking around in a red light area at 10PM, didn't do anything but got caught by Police, what will happen in Pune India?
# What could be the reason behind the fact that > 90% of people in the USA (especially the Bay Area) follow traffic rules, while > 90% people in India do not even stop at a red light?
# Collins-Duffy | Norm: 0.212223 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.212223 | Raw: 6.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.212223 | Raw: 3.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.212223 | Raw: 1.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.212223 | Raw: 0.800000 | Lambda: 0.100000
# If I ate a can of sardines everyday and ran for an hour, would this make me lose weight fast?
# What would happen if I ate a can of sardines and jogged two miles everyday?
# Collins-Duffy | Norm: 0.519615 | Raw: 9.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.519615 | Raw: 7.200000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.519615 | Raw: 3.600000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.519615 | Raw: 1.800000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.519615 | Raw: 0.900000 | Lambda: 0.100000
# How is the Lewis dot structure for Br2 determined?
# What is the Lewis dot structure for br2?
# Collins-Duffy | Norm: 0.707107 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.707107 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.707107 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.707107 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.707107 | Raw: 0.600000 | Lambda: 0.100000
# What are the best way to learn hacking?
# What is the best way to start learning hacking?
# Collins-Duffy | Norm: 0.707107 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.707107 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.707107 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.707107 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.707107 | Raw: 0.600000 | Lambda: 0.100000
# How do I find someone that can hack a website?
# How can I learn to hack a website?
# Collins-Duffy | Norm: 0.670820 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.670820 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.670820 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.670820 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.670820 | Raw: 0.600000 | Lambda: 0.100000
# How do I personal message someone on Quora?
# Quora: How do you message someone through their profile?
# Collins-Duffy | Norm: 0.668153 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.668153 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.668153 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.668153 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.668153 | Raw: 0.500000 | Lambda: 0.100000
# What is the best hotel in Baga Beach, Goa for couples?
# What are some hotels in Goa where unmarried couples are allowed to stay?
# Collins-Duffy | Norm: 0.311400 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.311400 | Raw: 3.200000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.311400 | Raw: 1.600000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.311400 | Raw: 0.800000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.311400 | Raw: 0.400000 | Lambda: 0.100000
# Where can you buy Bob Ross' original paintings?
# Are Bob Ross' paintings worth anything?
# Collins-Duffy | Norm: 0.474342 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.474342 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.474342 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.474342 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.474342 | Raw: 0.300000 | Lambda: 0.100000
# How do you mail to a PO box?
# How can I mail to PO box?
# Collins-Duffy | Norm: 0.534522 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.534522 | Raw: 3.200000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.534522 | Raw: 1.600000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.534522 | Raw: 0.800000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.534522 | Raw: 0.400000 | Lambda: 0.100000
# What's the worst thing you been threw
# What's the worst thing you've seen?
# Collins-Duffy | Norm: 0.750000 | Raw: 6.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.750000 | Raw: 4.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.750000 | Raw: 2.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.750000 | Raw: 1.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.750000 | Raw: 0.600000 | Lambda: 0.100000
# Which technologies will kill the call center?
# What are some good overviews of the technologies used in call centers?
# Collins-Duffy | Norm: 0.327327 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.327327 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.327327 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.327327 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.327327 | Raw: 0.300000 | Lambda: 0.100000
# How can I protect my ideas from being stolen?
# How do I protect a business idea from being stolen from VC? How do I protect the idea from being copied?
# Collins-Duffy | Norm: 0.707107 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.707107 | Raw: 5.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.707107 | Raw: 2.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.707107 | Raw: 1.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.707107 | Raw: 0.700000 | Lambda: 0.100000
# Why wasn't John Williams hired to write the soundtrack to Rogue One?
# Why didn't John Williams compose the music for Rogue One?
# Collins-Duffy | Norm: 0.544949 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.544949 | Raw: 5.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.544949 | Raw: 2.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.544949 | Raw: 1.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.544949 | Raw: 0.700000 | Lambda: 0.100000
# What is federation and why it is important?
# What is federalism? Why is it important?
# Collins-Duffy | Norm: 0.547723 | Raw: 3.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.547723 | Raw: 2.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.547723 | Raw: 1.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.547723 | Raw: 0.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.547723 | Raw: 0.300000 | Lambda: 0.100000
# Why can't I create a blog on Quora?
# Why can't I make a blog on Quora?
# Collins-Duffy | Norm: 0.888889 | Raw: 8.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.888889 | Raw: 6.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.888889 | Raw: 3.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.888889 | Raw: 1.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.888889 | Raw: 0.800000 | Lambda: 0.100000
# Which cameras DSLR or Mirrorless available below $600 that can take background blur (depth of field) photos? Can you please list them?
# How do you take a photo of a backlit subject with a DSLR without blowing out the background or over-darkening the subject?
# Collins-Duffy | Norm: 0.231869 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.231869 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.231869 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.231869 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.231869 | Raw: 0.500000 | Lambda: 0.100000
# Should I remove the fat from the top of the cold chicken soup? Is the soup any different in taste or nutrients without that fat?
# Do duck eggs taste different from chicken eggs if so why?
# Collins-Duffy | Norm: 0.127257 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.127257 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.127257 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.127257 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.127257 | Raw: 0.200000 | Lambda: 0.100000
# How should I tackle this?
# What's the best way to tackle depression?
# Collins-Duffy | Norm: 0.158114 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.158114 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.158114 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.158114 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.158114 | Raw: 0.100000 | Lambda: 0.100000
# Do people treat you differently when you wear hijab, even if you are white?
# Do people treat you differently after you have started wearing the hijab, even if you are white?
# Collins-Duffy | Norm: 0.839254 | Raw: 18.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.839254 | Raw: 14.400000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.839254 | Raw: 7.200000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.839254 | Raw: 3.600000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.839254 | Raw: 1.800000 | Lambda: 0.100000
# What's the difference between Dominica and the Dominican Republic?
# Is it safe to drink water in the Dominican Republic?
# Collins-Duffy | Norm: 0.365148 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.365148 | Raw: 3.200000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.365148 | Raw: 1.600000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.365148 | Raw: 0.800000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.365148 | Raw: 0.400000 | Lambda: 0.100000
# What is hard disk drive failure?
# What does a hard disk drive do in a computer?
# Collins-Duffy | Norm: 0.471405 | Raw: 4.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.471405 | Raw: 3.200000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.471405 | Raw: 1.600000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.471405 | Raw: 0.800000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.471405 | Raw: 0.400000 | Lambda: 0.100000
# Which are some of the best performing penny stocks in India?
# Are penny stocks good to invest in?
# Collins-Duffy | Norm: 0.239046 | Raw: 2.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.239046 | Raw: 1.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.239046 | Raw: 0.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.239046 | Raw: 0.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.239046 | Raw: 0.200000 | Lambda: 0.100000
# What is the coolest thing you have done in your dreams?
# What insurance does the Florida Hospital accept?
# Collins-Duffy | Norm: 0.125988 | Raw: 1.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.125988 | Raw: 0.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.125988 | Raw: 0.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.125988 | Raw: 0.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.125988 | Raw: 0.100000 | Lambda: 0.100000
# What are the types of cache memory?
# What are the different types of caching?
# Collins-Duffy | Norm: 0.714286 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.714286 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.714286 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.714286 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.714286 | Raw: 0.500000 | Lambda: 0.100000
# What should I do if a girl doesn't respond to a text?
# What should I do when a girl doesn't respond to my texts?
# Collins-Duffy | Norm: 0.856349 | Raw: 11.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.856349 | Raw: 8.800000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.856349 | Raw: 4.400000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.856349 | Raw: 2.200000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.856349 | Raw: 1.100000 | Lambda: 0.100000
# What are the safety precautions on handling shotguns proposed by the NRA in Utah?
# What are the safety precautions on handling shotguns proposed by the NRA in Alaska?
# Collins-Duffy | Norm: 0.937500 | Raw: 15.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.937500 | Raw: 12.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.937500 | Raw: 6.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.937500 | Raw: 3.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.937500 | Raw: 1.500000 | Lambda: 0.100000
# What if Quora would have been a country?
# What if Quora were a country?
# Collins-Duffy | Norm: 0.721688 | Raw: 5.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.721688 | Raw: 4.000000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.721688 | Raw: 2.000000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.721688 | Raw: 1.000000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.721688 | Raw: 0.500000 | Lambda: 0.100000
# What are some mind-blowing inventions tools that most people don't know about?
# What are some mind blowing things that people don't know exist?
# Collins-Duffy | Norm: 0.639010 | Raw: 7.000000 | Lambda: 1.000000
# Collins-Duffy | Norm: 0.639010 | Raw: 5.600000 | Lambda: 0.800000
# Collins-Duffy | Norm: 0.639010 | Raw: 2.800000 | Lambda: 0.400000
# Collins-Duffy | Norm: 0.639010 | Raw: 1.400000 | Lambda: 0.200000
# Collins-Duffy | Norm: 0.639010 | Raw: 0.700000 | Lambda: 0.100000
# --- 4.493399143218994 seconds ---

# %%
tree_1
# Out:
# defaultdict(<function TreeBuild.tree>,
#             {0: {'children': [1],
#               'childrenTok': 'SBARQ',
#               'curid': 0,
#               'indent': 0,
#               'parid': -1,
#               'posOrTok': 'ROOT'},
#              1: {'children': [2, 5],
#               'childrenTok': ['WHNP', 'SQ'],
#               'curid': 1,
#               'indent': 2,
#               'parid': 0,
#               'posOrTok': 'SBARQ'},
#              2: {'children': [3],
#               'childrenTok': ['WP'],
#               'curid': 2,
#               'indent': 4,
#               'parid': 1,
#               'posOrTok': 'WHNP'},
#              3: {'children': [4],
#               'childrenTok': ['What'],
#               'curid': 3,
#               'indent': 6,
#               'parid': 2,
#               'posOrTok': 'WP'},
#              4: {'children': [],
#               'childrenTok': [],
#               'curid': 4,
#               'indent': 6,
#               'parid': 3,
#               'posOrTok': 'What'},
#              5: {'children': [6, 8],
#               'childrenTok': ['VBP', 'NP'],
#               'curid': 5,
#               'indent': 4,
#               'parid': 1,
#               'posOrTok': 'SQ'},
#              6: {'children': [7],
#               'childrenTok': ['are'],
#               'curid': 6,
#               'indent': 6,
#               'parid': 5,
#               'posOrTok': 'VBP'},
#              7: {'children': [],
#               'childrenTok': [],
#               'curid': 7,
#               'indent': 6,
#               'parid': 6,
#               'posOrTok': 'are'},
#              8: {'children': [9, 12],
#               'childrenTok': ['NP', 'SBAR'],
#               'curid': 8,
#               'indent': 6,
#               'parid': 5,
#               'posOrTok': 'NP'},
#              9: {'children': [10],
#               'childrenTok': ['DT'],
#               'curid': 9,
#               'indent': 8,
#               'parid': 8,
#               'posOrTok': 'NP'},
#              10: {'children': [11],
#               'childrenTok': ['some'],
#               'curid': 10,
#               'indent': 10,
#               'parid': 9,
#               'posOrTok': 'DT'},
#              11: {'children': [],
#               'childrenTok': [],
#               'curid': 11,
#               'indent': 10,
#               'parid': 10,
#               'posOrTok': 'some'},
#              12: {'children': [13, 16],
#               'childrenTok': ['WHNP', 'S'],
#               'curid': 12,
#               'indent': 8,
#               'parid': 8,
#               'posOrTok': 'SBAR'},
#              13: {'children': [14],
#               'childrenTok': ['IN'],
#               'curid': 13,
#               'indent': 10,
#               'parid': 12,
#               'posOrTok': 'WHNP'},
#              14: {'children': [15],
#               'childrenTok': ['that'],
#               'curid': 14,
#               'indent': 12,
#               'parid': 13,
#               'posOrTok': 'IN'},
#              15: {'children': [],
#               'childrenTok': [],
#               'curid': 15,
#               'indent': 12,
#               'parid': 14,
#               'posOrTok': 'that'},
#              16: {'children': [17, 22],
#               'childrenTok': ['NP', 'VP'],
#               'curid': 16,
#               'indent': 10,
#               'parid': 12,
#               'posOrTok': 'S'},
#              17: {'children': [18, 20],
#               'childrenTok': ['JJS', 'NNS'],
#               'curid': 17,
#               'indent': 12,
#               'parid': 16,
#               'posOrTok': 'NP'},
#              18: {'children': [19],
#               'childrenTok': ['most'],
#               'curid': 18,
#               'indent': 14,
#               'parid': 17,
#               'posOrTok': 'JJS'},
#              19: {'children': [],
#               'childrenTok': [],
#               'curid': 19,
#               'indent': 14,
#               'parid': 18,
#               'posOrTok': 'most'},
#              20: {'children': [21],
#               'childrenTok': ['people'],
#               'curid': 20,
#               'indent': 14,
#               'parid': 17,
#               'posOrTok': 'NNS'},
#              21: {'children': [],
#               'childrenTok': [],
#               'curid': 21,
#               'indent': 14,
#               'parid': 20,
#               'posOrTok': 'people'},
#              22: {'children': [23, 25, 27],
#               'childrenTok': ['VBP', 'RB', 'VP'],
#               'curid': 22,
#               'indent': 12,
#               'parid': 16,
#               'posOrTok': 'VP'},
#              23: {'children': [24],
#               'childrenTok': ['do'],
#               'curid': 23,
#               'indent': 14,
#               'parid': 22,
#               'posOrTok': 'VBP'},
#              24: {'children': [],
#               'childrenTok': [],
#               'curid': 24,
#               'indent': 14,
#               'parid': 23,
#               'posOrTok': 'do'},
#              25: {'children': [26],
#               'childrenTok': ["n't"],
#               'curid': 25,
#               'indent': 14,
#               'parid': 22,
#               'posOrTok': 'RB'},
#              26: {'children': [],
#               'childrenTok': [],
#               'curid': 26,
#               'indent': 14,
#               'parid': 25,
#               'posOrTok': "n't"},
#              27: {'children': [28, 30],
#               'childrenTok': ['VB', 'PP'],
#               'curid': 27,
#               'indent': 14,
#               'parid': 22,
#               'posOrTok': 'VP'},
#              28: {'children': [29],
#               'childrenTok': ['know'],
#               'curid': 28,
#               'indent': 16,
#               'parid': 27,
#               'posOrTok': 'VB'},
#              29: {'children': [],
#               'childrenTok': [],
#               'curid': 29,
#               'indent': 16,
#               'parid': 28,
#               'posOrTok': 'know'},
#              30: {'children': [31],
#               'childrenTok': ['IN'],
#               'curid': 30,
#               'indent': 16,
#               'parid': 27,
#               'posOrTok': 'PP'},
#              31: {'children': [32],
#               'childrenTok': ['about'],
#               'curid': 31,
#               'indent': 18,
#               'parid': 30,
#               'posOrTok': 'IN'},
#              32: {'children': [],
#               'childrenTok': [],
#               'curid': 32,
#               'indent': 18,
#               'parid': 31,
#               'posOrTok': 'about'}})

# %%
import pickle

# with open('filename.pickle', 'wb') as handle:
#     pickle.dump(a, handle, protocol=pickle.HIGHEST_PROTOCOL)

# with open('filename.pickle', 'rb') as handle:
#     b = pickle.load(handle)

# print a == b

import json, os
with open('testoutput', 'ab') as fout:
    count = 0
    for row in df_train.iterrows():
        count+=1
        if count > 100:
            break
    
        tree_1 = tb.tree()
        tree_2 = tb.tree()

        toks_1 = _getNLPToks_(row[1]['question1'])
        toks_2 = _getNLPToks_(row[1]['question2'])

        # Generate a tree structure
        tb._generateTree_(toks_1, tree_1)
        tb._generateTree_(toks_2, tree_2)

        # Flip the trees
        tb._flipTree_(tree_1)
        tb._flipTree_(tree_2)

        tmp = {'q1':tree_1, 'q2':tree_2}

        pickle.dump(tmp, fout, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('testoutput', 'rb') as handle:
    a = pickle.load(handle)
    print(a['q1'][10])
    b = pickle.load(handle)
    print(b['q1'][10])
# Out:
# {'children': [11], 'indent': 10, 'childrenTok': ['the'], 'posOrTok': 'DT', 'curid': 10, 'parid': 9}
# {'children': [11], 'indent': 10, 'childrenTok': ['the'], 'posOrTok': 'DT', 'curid': 10, 'parid': 9}

# %%
print(a)
# Out:
# {'q1': defaultdict(<function tree at 0x10fa7a620>, {0: {'children': [1], 'indent': 0, 'childrenTok': 'SBARQ', 'posOrTok': 'ROOT', 'curid': 0, 'parid': -1}, 1: {'children': [2, 5], 'indent': 2, 'childrenTok': ['WHNP', 'SQ'], 'posOrTok': 'SBARQ', 'curid': 1, 'parid': 0}, 2: {'children': [3], 'indent': 4, 'childrenTok': ['WP'], 'posOrTok': 'WHNP', 'curid': 2, 'parid': 1}, 3: {'children': [4], 'indent': 6, 'childrenTok': ['What'], 'posOrTok': 'WP', 'curid': 3, 'parid': 2}, 4: {'children': [], 'indent': 6, 'childrenTok': [], 'posOrTok': 'What', 'curid': 4, 'parid': 3}, 5: {'children': [6, 8], 'indent': 4, 'childrenTok': ['VBZ', 'NP'], 'posOrTok': 'SQ', 'curid': 5, 'parid': 1}, 6: {'children': [7], 'indent': 6, 'childrenTok': ['is'], 'posOrTok': 'VBZ', 'curid': 6, 'parid': 5}, 7: {'children': [], 'indent': 6, 'childrenTok': [], 'posOrTok': 'is', 'curid': 7, 'parid': 6}, 8: {'children': [9, 14, 22], 'indent': 6, 'childrenTok': ['NP', 'PP', 'S'], 'posOrTok': 'NP', 'curid': 8, 'parid': 5}, 9: {'children': [10, 12], 'indent': 8, 'childrenTok': ['DT', 'NN'], 'posOrTok': 'NP', 'curid': 9, 'parid': 8}, 10: {'children': [11], 'indent': 10, 'childrenTok': ['the'], 'posOrTok': 'DT', 'curid': 10, 'parid': 9}, 11: {'children': [], 'indent': 10, 'childrenTok': [], 'posOrTok': 'the', 'curid': 11, 'parid': 10}, 12: {'children': [13], 'indent': 10, 'childrenTok': ['step'], 'posOrTok': 'NN', 'curid': 12, 'parid': 9}, 13: {'children': [], 'indent': 10, 'childrenTok': [], 'posOrTok': 'step', 'curid': 13, 'parid': 12}, 14: {'children': [15, 17], 'indent': 8, 'childrenTok': ['IN', 'NP'], 'posOrTok': 'PP', 'curid': 14, 'parid': 8}, 15: {'children': [16], 'indent': 10, 'childrenTok': ['by'], 'posOrTok': 'IN', 'curid': 15, 'parid': 14}, 16: {'children': [], 'indent': 10, 'childrenTok': [], 'posOrTok': 'by', 'curid': 16, 'parid': 15}, 17: {'children': [18, 20], 'indent': 10, 'childrenTok': ['NN', 'NN'], 'posOrTok': 'NP', 'curid': 17, 'parid': 14}, 18: {'children': [19], 'indent': 12, 'childrenTok': ['step'], 'posOrTok': 'NN', 'curid': 18, 'parid': 17}, 19: {'children': [], 'indent': 12, 'childrenTok': [], 'posOrTok': 'step', 'curid': 19, 'parid': 18}, 20: {'children': [21], 'indent': 12, 'childrenTok': ['guide'], 'posOrTok': 'NN', 'curid': 20, 'parid': 17}, 21: {'children': [], 'indent': 12, 'childrenTok': [], 'posOrTok': 'guide', 'curid': 21, 'parid': 20}, 22: {'children': [23], 'indent': 8, 'childrenTok': ['VP'], 'posOrTok': 'S', 'curid': 22, 'parid': 8}, 23: {'children': [24, 26], 'indent': 10, 'childrenTok': ['TO', 'VP'], 'posOrTok': 'VP', 'curid': 23, 'parid': 22}, 24: {'children': [25], 'indent': 12, 'childrenTok': ['to'], 'posOrTok': 'TO', 'curid': 24, 'parid': 23}, 25: {'children': [], 'indent': 12, 'childrenTok': [], 'posOrTok': 'to', 'curid': 25, 'parid': 24}, 26: {'children': [27, 29, 37], 'indent': 12, 'childrenTok': ['VB', 'PP', 'PP'], 'posOrTok': 'VP', 'curid': 26, 'parid': 23}, 27: {'children': [28], 'indent': 14, 'childrenTok': ['invest'], 'posOrTok': 'VB', 'curid': 27, 'parid': 26}, 28: {'children': [], 'indent': 14, 'childrenTok': [], 'posOrTok': 'invest', 'curid': 28, 'parid': 27}, 29: {'children': [30, 32], 'indent': 14, 'childrenTok': ['IN', 'NP'], 'posOrTok': 'PP', 'curid': 29, 'parid': 26}, 30: {'children': [31], 'indent': 16, 'childrenTok': ['in'], 'posOrTok': 'IN', 'curid': 30, 'parid': 29}, 31: {'children': [], 'indent': 16, 'childrenTok': [], 'posOrTok': 'in', 'curid': 31, 'parid': 30}, 32: {'children': [33, 35], 'indent': 16, 'childrenTok': ['NN', 'NN'], 'posOrTok': 'NP', 'curid': 32, 'parid': 29}, 33: {'children': [34], 'indent': 18, 'childrenTok': ['share'], 'posOrTok': 'NN', 'curid': 33, 'parid': 32}, 34: {'children': [], 'indent': 18, 'childrenTok': [], 'posOrTok': 'share', 'curid': 34, 'parid': 33}, 35: {'children': [36], 'indent': 18, 'childrenTok': ['market'], 'posOrTok': 'NN', 'curid': 35, 'parid': 32}, 36: {'children': [], 'indent': 18, 'childrenTok': [], 'posOrTok': 'market', 'curid': 36, 'parid': 35}, 37: {'children':  ...

# %%
print(b)
# Out:
# {'q1': defaultdict(<function tree at 0x10fa7a620>, {0: {'children': [1], 'indent': 0, 'childrenTok': 'SBARQ', 'posOrTok': 'ROOT', 'curid': 0, 'parid': -1}, 1: {'children': [2, 5], 'indent': 2, 'childrenTok': ['WHNP', 'SQ'], 'posOrTok': 'SBARQ', 'curid': 1, 'parid': 0}, 2: {'children': [3], 'indent': 4, 'childrenTok': ['WP'], 'posOrTok': 'WHNP', 'curid': 2, 'parid': 1}, 3: {'children': [4], 'indent': 6, 'childrenTok': ['What'], 'posOrTok': 'WP', 'curid': 3, 'parid': 2}, 4: {'children': [], 'indent': 6, 'childrenTok': [], 'posOrTok': 'What', 'curid': 4, 'parid': 3}, 5: {'children': [6, 8], 'indent': 4, 'childrenTok': ['VBZ', 'NP'], 'posOrTok': 'SQ', 'curid': 5, 'parid': 1}, 6: {'children': [7], 'indent': 6, 'childrenTok': ['is'], 'posOrTok': 'VBZ', 'curid': 6, 'parid': 5}, 7: {'children': [], 'indent': 6, 'childrenTok': [], 'posOrTok': 'is', 'curid': 7, 'parid': 6}, 8: {'children': [9, 14], 'indent': 6, 'childrenTok': ['NP', 'PP'], 'posOrTok': 'NP', 'curid': 8, 'parid': 5}, 9: {'children': [10, 12], 'indent': 8, 'childrenTok': ['DT', 'NN'], 'posOrTok': 'NP', 'curid': 9, 'parid': 8}, 10: {'children': [11], 'indent': 10, 'childrenTok': ['the'], 'posOrTok': 'DT', 'curid': 10, 'parid': 9}, 11: {'children': [], 'indent': 10, 'childrenTok': [], 'posOrTok': 'the', 'curid': 11, 'parid': 10}, 12: {'children': [13], 'indent': 10, 'childrenTok': ['story'], 'posOrTok': 'NN', 'curid': 12, 'parid': 9}, 13: {'children': [], 'indent': 10, 'childrenTok': [], 'posOrTok': 'story', 'curid': 13, 'parid': 12}, 14: {'children': [15, 17], 'indent': 8, 'childrenTok': ['IN', 'NP'], 'posOrTok': 'PP', 'curid': 14, 'parid': 8}, 15: {'children': [16], 'indent': 10, 'childrenTok': ['of'], 'posOrTok': 'IN', 'curid': 15, 'parid': 14}, 16: {'children': [], 'indent': 10, 'childrenTok': [], 'posOrTok': 'of', 'curid': 16, 'parid': 15}, 17: {'children': [18, 22], 'indent': 10, 'childrenTok': ['NP', 'NP'], 'posOrTok': 'NP', 'curid': 17, 'parid': 14}, 18: {'children': [19], 'indent': 12, 'childrenTok': ['NP'], 'posOrTok': 'NP', 'curid': 18, 'parid': 17}, 19: {'children': [20], 'indent': 14, 'childrenTok': ['NNP'], 'posOrTok': 'NP', 'curid': 19, 'parid': 18}, 20: {'children': [21], 'indent': 16, 'childrenTok': ['Kohinoor'], 'posOrTok': 'NNP', 'curid': 20, 'parid': 19}, 21: {'children': [], 'indent': 16, 'childrenTok': [], 'posOrTok': 'Kohinoor', 'curid': 21, 'parid': 20}, 22: {'children': [23], 'indent': 12, 'childrenTok': ['NNP'], 'posOrTok': 'NP', 'curid': 22, 'parid': 17}, 23: {'children': [24], 'indent': 14, 'childrenTok': ['Diamond'], 'posOrTok': 'NNP', 'curid': 23, 'parid': 22}, 24: {'children': [], 'indent': 14, 'childrenTok': [], 'posOrTok': 'Diamond', 'curid': 24, 'parid': 23}}), 'q2': defaultdict(<function tree at 0x10fa7a620>, {0: {'children': [1], 'indent': 0, 'childrenTok': 'SBARQ', 'posOrTok': 'ROOT', 'curid': 0, 'parid': -1}, 1: {'children': [2, 5], 'indent': 2, 'childrenTok': ['WHNP', 'SQ'], 'posOrTok': 'SBARQ', 'curid': 1, 'parid': 0}, 2: {'children': [3], 'indent': 4, 'childrenTok': ['WP'], 'posOrTok': 'WHNP', 'curid': 2, 'parid': 1}, 3: {'children': [4], 'indent': 6, 'childrenTok': ['What'], 'posOrTok': 'WP', 'curid': 3, 'parid': 2}, 4: {'children': [], 'indent': 6, 'childrenTok': [], 'posOrTok': 'What', 'curid': 4, 'parid': 3}, 5: {'children': [6], 'indent': 4, 'childrenTok': ['VP'], 'posOrTok': 'SQ', 'curid': 5, 'parid': 1}, 6: {'children': [7, 9], 'indent': 6, 'childrenTok': ['MD', 'VP'], 'posOrTok': 'VP', 'curid': 6, 'parid': 5}, 7: {'children': [8], 'indent': 8, 'childrenTok': ['would'], 'posOrTok': 'MD', 'curid': 7, 'parid': 6}, 8: {'children': [], 'indent': 8, 'childrenTok': [], 'posOrTok': 'would', 'curid': 8, 'parid': 7}, 9: {'children': [10, 12], 'indent': 8, 'childrenTok': ['VB', 'SBAR'], 'posOrTok': 'VP', 'curid': 9, 'parid': 6}, 10: {'children': [11], 'indent': 10, 'childrenTok': ['happen'], 'posOrTok': 'VB', 'curid': 10, 'parid': 9}, 11: {'children': [], 'indent': 10, 'childrenTok': [], 'posOrTok': 'happen', 'curid': 11, 'parid': 10}, 1 ...
